# %%
import numpy as np
import shutil
import os

import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *
from argparse import Namespace
from catboost import CatBoostRegressor, CatBoostClassifier

# %reload_ext autoreload
# %autoreload 2

# %%
def get_baseline_metric():
    args = Namespace()
    args.verbose = True
    args.first_feature = 0
    args.last_feature = -1
    args.data_folder = "../../../data/best_features_days_data/"
    args.out_folder = "res"
    args.type = "regression"
    args.need_position_feature = True
    args.labels_to_substruct = None
    args.metric_folder = "metrics"
    args.model_constructor = lambda verbose: CatBoostRegressor(verbose=False)
    args.additional_features = None
    args.add_base_features = True
    args.train_days = [3]
    args.validation_day = None
    args.test_days = [6]
    
    def clear(folder):
        if os.path.exists(folder):
            shutil.rmtree(folder)
        os.mkdir(folder)
    
    clear(args.out_folder)
    clear(args.metric_folder)
    
    calculate_predictions(args)
    evaluate(args.out_folder, args.data_folder, args.metric_folder, argmax_positions)
    
    with open("metrics/metrics.txt") as handler:
        metric = float(next(handler).strip().split()[0])
        return metric

# %%
# %%time
metrics = [get_baseline_metric() for i in range(15)]
# Out:
# "2018-06-21 21:18:34.388884": preprocesing started
# "2018-06-21 21:18:35.172799":     base features shape: (20203, 81)
# "2018-06-21 21:18:35.175488":     0 features added
# "2018-06-21 21:18:35.175541":     base features not included
# "2018-06-21 21:18:35.175634":     result shape: (20203, 81)
# "2018-06-21 21:18:35.176694": train features shape: (20203, 81)
# "2018-06-21 21:18:35.790138": preprocesing finished
# "2018-06-21 21:18:35.790215": start training on days [3]
# "2018-06-21 21:18:35.790368": using fit without validation
# "2018-06-21 21:18:58.192787": built 1000 trees
# "2018-06-21 21:19:00.448281":     base features shape: (247423, 81)
# "2018-06-21 21:19:00.513481":     0 features added
# "2018-06-21 21:19:00.513567":     base features not included
# "2018-06-21 21:19:00.513613":     result shape: (247423, 81)
# "2018-06-21 21:19:00.517993": days to predict: [6]
# "2018-06-21 21:19:00.518165": features shape: (247423, 81)
# "2018-06-21 21:19:00.518238": start predicting on day 6
# "2018-06-21 21:19:02.011298": predictions shape: (22493, 11)
# "2018-06-21 21:19:02.011403": saveing results to res/train_3_test_6
# "2018-06-21 21:19:02.013161": results saved
# "2018-06-21 21:19:04.046348": preprocesing started
# "2018-06-21 21:19:04.790880":     base features shape: (20203, 81)
# "2018-06-21 21:19:04.792144":     0 features added
# "2018-06-21 21:19:04.792174":     base features not included
# "2018-06-21 21:19:04.792249":     result shape: (20203, 81)
# "2018-06-21 21:19:04.793357": train features shape: (20203, 81)
# "2018-06-21 21:19:05.429753": preprocesing finished
# "2018-06-21 21:19:05.429840": start training on days [3]
# "2018-06-21 21:19:05.429949": using fit without validation
# "2018-06-21 21:19:28.748649": built 1000 trees
# "2018-06-21 21:19:31.044925":     base features shape: (247423, 81)
# "2018-06-21 21:19:31.113404":     0 features added
# "2018-06-21 21:19:31.113500":     base features not included
# "2018-06-21 21:19:31.113531":     result shape: (247423, 81)
# "2018-06-21 21:19:31.118317": days to predict: [6]
# "2018-06-21 21:19:31.118503": features shape: (247423, 81)
# "2018-06-21 21:19:31.118522": start predicting on day 6
# "2018-06-21 21:19:32.694585": predictions shape: (22493, 11)
# "2018-06-21 21:19:32.694802": saveing results to res/train_3_test_6
# "2018-06-21 21:19:32.696701": results saved
# "2018-06-21 21:19:34.856678": preprocesing started
# "2018-06-21 21:19:35.664414":     base features shape: (20203, 81)
# "2018-06-21 21:19:35.665604":     0 features added
# "2018-06-21 21:19:35.665642":     base features not included
# "2018-06-21 21:19:35.665743":     result shape: (20203, 81)
# "2018-06-21 21:19:35.666887": train features shape: (20203, 81)
# "2018-06-21 21:19:36.284708": preprocesing finished
# "2018-06-21 21:19:36.284785": start training on days [3]
# "2018-06-21 21:19:36.284940": using fit without validation
# "2018-06-21 21:20:01.034755": built 1000 trees
# "2018-06-21 21:20:03.344234":     base features shape: (247423, 81)
# "2018-06-21 21:20:03.417015":     0 features added
# "2018-06-21 21:20:03.417091":     base features not included
# "2018-06-21 21:20:03.417115":     result shape: (247423, 81)
# "2018-06-21 21:20:03.424220": days to predict: [6]
# "2018-06-21 21:20:03.424360": features shape: (247423, 81)
# "2018-06-21 21:20:03.424386": start predicting on day 6
# "2018-06-21 21:20:04.921223": predictions shape: (22493, 11)
# "2018-06-21 21:20:04.921318": saveing results to res/train_3_test_6
# "2018-06-21 21:20:04.923600": results saved
# "2018-06-21 21:20:07.051768": preprocesing started
# "2018-06-21 21:20:07.862878":     base features shape: (20203, 81)
# "2018-06-21 21:20:07.864408":     0 features added
# "2018-06-21 21:20:07.864460":     base features not included
# "2018-06-21 21:20:07.864482":     result shape: (20203, 81)
# "2018-06-21 21:20:07.865853": train features shape: (20203, 81)
# "2018-06-21 21:20:08.481467": preprocesing finished
# "2018-06-21 21:20:08.481562": start training on days [3]
# "2018-06-21 21:20:08.481586": using fit without validation
# "2018-06-21 21:20:32.922945": built 1000 trees
# "2018-06-21 21:20:35.174646":     base features shape: (247423, 81)
# "2018-06-21 21:20:35.246846":     0 features added
# "2018-06-21 21:20:35.246928":     base features not included
# "2018-06-21 21:20:35.247054":     result shape: (247423, 81)
# "2018-06-21 21:20:35.254361": days to predict: [6]
# "2018-06-21 21:20:35.254435": features shape: (247423, 81)
# "2018-06-21 21:20:35.254456": start predicting on day 6
# "2018-06-21 21:20:36.768482": predictions shape: (22493, 11)
# "2018-06-21 21:20:36.768698": saveing results to res/train_3_test_6
# "2018-06-21 21:20:36.770440": results saved
# "2018-06-21 21:20:38.904228": preprocesing started
# "2018-06-21 21:20:39.696758":     base features shape: (20203, 81)
# "2018-06-21 21:20:39.698161":     0 features added
# "2018-06-21 21:20:39.698194":     base features not included
# "2018-06-21 21:20:39.698214":     result shape: (20203, 81)
# "2018-06-21 21:20:39.700048": train features shape: (20203, 81)
# "2018-06-21 21:20:40.364657": preprocesing finished
# "2018-06-21 21:20:40.364734": start training on days [3]
# "2018-06-21 21:20:40.364754": using fit without validation
# "2018-06-21 21:21:03.275611": built 1000 trees
# "2018-06-21 21:21:05.451543":     base features shape: (247423, 81)
# "2018-06-21 21:21:05.518925":     0 features added
# "2018-06-21 21:21:05.518993":     base features not included
# "2018-06-21 21:21:05.519115":     result shape: (247423, 81)
# "2018-06-21 21:21:05.523700": days to predict: [6]
# "2018-06-21 21:21:05.523948": features shape: (247423, 81)
# "2018-06-21 21:21:05.524128": start predicting on day 6
# "2018-06-21 21:21:07.007238": predictions shape: (22493, 11)
# "2018-06-21 21:21:07.007298": saveing results to res/train_3_test_6
# "2018-06-21 21:21:07.008818": results saved
# "2018-06-21 21:21:09.228708": preprocesing started
# "2018-06-21 21:21:10.147531":     base features shape: (20203, 81)
# "2018-06-21 21:21:10.148944":     0 features added
# "2018-06-21 21:21:10.148979":     base features not included
# "2018-06-21 21:21:10.149000":     result shape: (20203, 81)
# "2018-06-21 21:21:10.150281": train features shape: (20203, 81)
# "2018-06-21 21:21:10.840624": preprocesing finished
# "2018-06-21 21:21:10.840701": start training on days [3]
# "2018-06-21 21:21:10.840719": using fit without validation
# "2018-06-21 21:21:34.097120": built 1000 trees
# "2018-06-21 21:21:36.537097":     base features shape: (247423, 81)
# "2018-06-21 21:21:36.615181":     0 features added
# "2018-06-21 21:21:36.615264":     base features not included
# "2018-06-21 21:21:36.615292":     result shape: (247423, 81)
# "2018-06-21 21:21:36.620569": days to predict: [6]
# "2018-06-21 21:21:36.620644": features shape: (247423, 81)
# "2018-06-21 21:21:36.620666": start predicting on day 6
# "2018-06-21 21:21:38.300323": predictions shape: (22493, 11)
# "2018-06-21 21:21:38.300388": saveing results to res/train_3_test_6
# "2018-06-21 21:21:38.301989": results saved
# "2018-06-21 21:21:40.665919": preprocesing started
# "2018-06-21 21:21:41.579451":     base features shape: (20203, 81)
# "2018-06-21 21:21:41.580884":     0 features added
# "2018-06-21 21:21:41.580932":     base features not included
# "2018-06-21 21:21:41.581061":     result shape: (20203, 81)
# "2018-06-21 21:21:41.582448": train features shape: (20203, 81)
# "2018-06-21 21:21:42.303441": preprocesing finished
# "2018-06-21 21:21:42.303614": start training on days [3]
# "2018-06-21 21:21:42.303731": using fit without validation
# "2018-06-21 21:22:06.051182": built 1000 trees
# "2018-06-21 21:22:08.634600":     base features shape: (247423, 81)
# "2018-06-21 21:22:08.712349":     0 features added
# "2018-06-21 21:22:08.712423":     base features not included
# "2018-06-21 21:22:08.712450":     result shape: (247423, 81)
# "2018-06-21 21:22:08.718079": days to predict: [6]
# "2018-06-21 21:22:08.718137": features shape: (247423, 81)
# "2018-06-21 21:22:08.718161": start predicting on day 6
# "2018-06-21 21:22:10.287140": predictions shape: (22493, 11)
# "2018-06-21 21:22:10.287327": saveing results to res/train_3_test_6
# "2018-06-21 21:22:10.289201": results saved
# "2018-06-21 21:22:12.589994": preprocesing started
# "2018-06-21 21:22:13.552576":     base features shape: (20203, 81)
# "2018-06-21 21:22:13.553971":     0 features added
# "2018-06-21 21:22:13.554004":     base features not included
# "2018-06-21 21:22:13.554026":     result shape: (20203, 81)
# "2018-06-21 21:22:13.555467": train features shape: (20203, 81)
# "2018-06-21 21:22:14.254833": preprocesing finished
# "2018-06-21 21:22:14.254916": start training on days [3]
# "2018-06-21 21:22:14.254935": using fit without validation
# "2018-06-21 21:22:38.006000": built 1000 trees
# "2018-06-21 21:22:40.547003":     base features shape: (247423, 81)
# "2018-06-21 21:22:40.625429":     0 features added
# "2018-06-21 21:22:40.625507":     base features not included
# "2018-06-21 21:22:40.625534":     result shape: (247423, 81)
# "2018-06-21 21:22:40.630376": days to predict: [6]
# "2018-06-21 21:22:40.630438": features shape: (247423, 81)
# "2018-06-21 21:22:40.630556": start predicting on day 6
# "2018-06-21 21:22:42.303068": predictions shape: (22493, 11)
# "2018-06-21 21:22:42.303136": saveing results to res/train_3_test_6
# "2018-06-21 21:22:42.304968": results saved
# "2018-06-21 21:22:44.474125": preprocesing started
# "2018-06-21 21:22:45.232185":     base features shape: (20203, 81)
# "2018-06-21 21:22:45.233368":     0 features added
# "2018-06-21 21:22:45.233416":     base features not included
# "2018-06-21 21:22:45.233492":     result shape: (20203, 81)
# "2018-06-21 21:22:45.234563": train features shape: (20203, 81)
# "2018-06-21 21:22:45.833299": preprocesing finished
# "2018-06-21 21:22:45.833405": start training on days [3]
# "2018-06-21 21:22:45.833514": using fit without validation
# "2018-06-21 21:23:09.017301": built 1000 trees
# "2018-06-21 21:23:11.640626":     base features shape: (247423, 81)
# "2018-06-21 21:23:11.719442":     0 features added
# "2018-06-21 21:23:11.719531":     base features not included
# "2018-06-21 21:23:11.719667":     result shape: (247423, 81)
# "2018-06-21 21:23:11.725405": days to predict: [6]
# "2018-06-21 21:23:11.725546": features shape: (247423, 81)
# "2018-06-21 21:23:11.725662": start predicting on day 6
# "2018-06-21 21:23:13.434654": predictions shape: (22493, 11)
# "2018-06-21 21:23:13.434853": saveing results to res/train_3_test_6
# "2018-06-21 21:23:13.436609": results saved
# "2018-06-21 21:23:15.812630": preprocesing started
# "2018-06-21 21:23:16.703111":     base features shape: (20203, 81)
# "2018-06-21 21:23:16.704401":     0 features added
# "2018-06-21 21:23:16.704449":     base features not included
# "2018-06-21 21:23:16.704545":     result shape: (20203, 81)
# "2018-06-21 21:23:16.706104": train features shape: (20203, 81)
# "2018-06-21 21:23:17.406757": preprocesing finished
# "2018-06-21 21:23:17.406850": start training on days [3]
# "2018-06-21 21:23:17.406964": using fit without validation
# "2018-06-21 21:23:41.439735": built 1000 trees
# "2018-06-21 21:23:43.713307":     base features shape: (247423, 81)
# "2018-06-21 21:23:43.782601":     0 features added
# "2018-06-21 21:23:43.782668":     base features not included
# "2018-06-21 21:23:43.782693":     result shape: (247423, 81)
# "2018-06-21 21:23:43.789393": days to predict: [6]
# "2018-06-21 21:23:43.789455": features shape: (247423, 81)
# "2018-06-21 21:23:43.789480": start predicting on day 6
# "2018-06-21 21:23:45.296977": predictions shape: (22493, 11)
# "2018-06-21 21:23:45.297037": saveing results to res/train_3_test_6
# "2018-06-21 21:23:45.298605": results saved
# "2018-06-21 21:23:47.377054": preprocesing started
# "2018-06-21 21:23:48.180958":     base features shape: (20203, 81)
# "2018-06-21 21:23:48.182205":     0 features added
# "2018-06-21 21:23:48.182238":     base features not included
# "2018-06-21 21:23:48.182257":     result shape: (20203, 81)
# "2018-06-21 21:23:48.183278": train features shape: (20203, 81)
# "2018-06-21 21:23:48.791049": preprocesing finished
# "2018-06-21 21:23:48.791118": start training on days [3]
# "2018-06-21 21:23:48.791134": using fit without validation
# "2018-06-21 21:24:12.530301": built 1000 trees
# "2018-06-21 21:24:14.710981":     base features shape: (247423, 81)
# "2018-06-21 21:24:14.778676":     0 features added
# "2018-06-21 21:24:14.778742":     base features not included
# "2018-06-21 21:24:14.778767":     result shape: (247423, 81)
# "2018-06-21 21:24:14.784379": days to predict: [6]
# "2018-06-21 21:24:14.784501": features shape: (247423, 81)
# "2018-06-21 21:24:14.784519": start predicting on day 6
# "2018-06-21 21:24:16.297294": predictions shape: (22493, 11)
# "2018-06-21 21:24:16.297361": saveing results to res/train_3_test_6
# "2018-06-21 21:24:16.298970": results saved
# "2018-06-21 21:24:18.363126": preprocesing started
# "2018-06-21 21:24:19.142890":     base features shape: (20203, 81)
# "2018-06-21 21:24:19.144389":     0 features added
# "2018-06-21 21:24:19.144440":     base features not included
# "2018-06-21 21:24:19.144466":     result shape: (20203, 81)
# "2018-06-21 21:24:19.145935": train features shape: (20203, 81)
# "2018-06-21 21:24:19.762882": preprocesing finished
# "2018-06-21 21:24:19.762995": start training on days [3]
# "2018-06-21 21:24:19.763016": using fit without validation
# "2018-06-21 21:24:42.905111": built 1000 trees
# "2018-06-21 21:24:45.125733":     base features shape: (247423, 81)
# "2018-06-21 21:24:45.198111":     0 features added
# "2018-06-21 21:24:45.198180":     base features not included
# "2018-06-21 21:24:45.198296":     result shape: (247423, 81)
# "2018-06-21 21:24:45.204916": days to predict: [6]
# "2018-06-21 21:24:45.205019": features shape: (247423, 81)
# "2018-06-21 21:24:45.205115": start predicting on day 6
# "2018-06-21 21:24:46.664120": predictions shape: (22493, 11)
# "2018-06-21 21:24:46.664262": saveing results to res/train_3_test_6
# "2018-06-21 21:24:46.665649": results saved
# "2018-06-21 21:24:48.680282": preprocesing started
# "2018-06-21 21:24:49.457622":     base features shape: (20203, 81)
# "2018-06-21 21:24:49.458783":     0 features added
# "2018-06-21 21:24:49.458810":     base features not included
# "2018-06-21 21:24:49.458848":     result shape: (20203, 81)
# "2018-06-21 21:24:49.459919": train features shape: (20203, 81)
# "2018-06-21 21:24:50.063630": preprocesing finished
# "2018-06-21 21:24:50.063731": start training on days [3]
# "2018-06-21 21:24:50.063750": using fit without validation
# "2018-06-21 21:25:13.482086": built 1000 trees
# "2018-06-21 21:25:15.634851":     base features shape: (247423, 81)
# "2018-06-21 21:25:15.701730":     0 features added
# "2018-06-21 21:25:15.701798":     base features not included
# "2018-06-21 21:25:15.701913":     result shape: (247423, 81)
# "2018-06-21 21:25:15.708971": days to predict: [6]
# "2018-06-21 21:25:15.709127": features shape: (247423, 81)
# "2018-06-21 21:25:15.709195": start predicting on day 6
# "2018-06-21 21:25:17.205311": predictions shape: (22493, 11)
# "2018-06-21 21:25:17.205436": saveing results to res/train_3_test_6
# "2018-06-21 21:25:17.207355": results saved
# "2018-06-21 21:25:19.214351": preprocesing started
# "2018-06-21 21:25:20.014859":     base features shape: (20203, 81)
# "2018-06-21 21:25:20.016057":     0 features added
# "2018-06-21 21:25:20.016093":     base features not included
# "2018-06-21 21:25:20.016192":     result shape: (20203, 81)
# "2018-06-21 21:25:20.017279": train features shape: (20203, 81)
# "2018-06-21 21:25:20.625395": preprocesing finished
# "2018-06-21 21:25:20.625468": start training on days [3]
# "2018-06-21 21:25:20.625565": using fit without validation
# "2018-06-21 21:25:43.958361": built 1000 trees
# "2018-06-21 21:25:46.196364":     base features shape: (247423, 81)
# "2018-06-21 21:25:46.262992":     0 features added
# "2018-06-21 21:25:46.263060":     base features not included
# "2018-06-21 21:25:46.263179":     result shape: (247423, 81)
# "2018-06-21 21:25:46.269565": days to predict: [6]
# "2018-06-21 21:25:46.269675": features shape: (247423, 81)
# "2018-06-21 21:25:46.269813": start predicting on day 6
# "2018-06-21 21:25:47.798827": predictions shape: (22493, 11)
# "2018-06-21 21:25:47.798959": saveing results to res/train_3_test_6
# "2018-06-21 21:25:47.800751": results saved
# "2018-06-21 21:25:49.876657": preprocesing started
# "2018-06-21 21:25:50.662881":     base features shape: (20203, 81)
# "2018-06-21 21:25:50.664013":     0 features added
# "2018-06-21 21:25:50.664046":     base features not included
# "2018-06-21 21:25:50.664150":     result shape: (20203, 81)
# "2018-06-21 21:25:50.665481": train features shape: (20203, 81)
# "2018-06-21 21:25:51.277634": preprocesing finished
# "2018-06-21 21:25:51.277715": start training on days [3]
# "2018-06-21 21:25:51.277815": using fit without validation
# "2018-06-21 21:26:14.518721": built 1000 trees
# "2018-06-21 21:26:16.794976":     base features shape: (247423, 81)
# "2018-06-21 21:26:16.861285":     0 features added
# "2018-06-21 21:26:16.861372":     base features not included
# "2018-06-21 21:26:16.861498":     result shape: (247423, 81)
# "2018-06-21 21:26:16.868005": days to predict: [6]
# "2018-06-21 21:26:16.868137": features shape: (247423, 81)
# "2018-06-21 21:26:16.868198": start predicting on day 6
# "2018-06-21 21:26:18.398886": predictions shape: (22493, 11)
# "2018-06-21 21:26:18.399012": saveing results to res/train_3_test_6
# "2018-06-21 21:26:18.401212": results saved
# CPU times: user 37min 8s, sys: 1min 18s, total: 38min 27s
# Wall time: 7min 46s

# %%
print(metrics)
print(np.mean(metrics))
print(np.std(metrics) / np.sqrt(15))
# Out:
# [0.6151258954509214, 0.6214447105349333, 0.605708517387299, 0.5921477096082469, 0.6395085730852217, 0.6265452837596254, 0.6209911104586073, 0.6239194625397643, 0.5973835119448839, 0.6369614547500089, 0.6202054766702059, 0.6170991908440882, 0.6251285396260383, 0.6055082962994239, 0.6162554566862585]
# 0.6175955459763685
# 0.003277448665366997
