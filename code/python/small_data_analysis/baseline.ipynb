# %%
import numpy as np
import shutil
import os

import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *
from argparse import Namespace
from catboost import CatBoostRegressor, CatBoostClassifier

# %reload_ext autoreload
# %autoreload 2

# %%
def get_baseline_metric(need_validation):
    args = Namespace()
    args.verbose = False
    args.first_feature = 0
    args.last_feature = -1
    args.data_folder = "../../../data/best_features_days_data/"
    args.out_folder = "res"
    args.type = "regression"
    args.metric_folder = "metrics"
    args.model_constructor=lambda verbose: CatBoostRegressor(verbose=verbose)
    args.additional_features = None
    args.train_days = [0, 1, 2]
    if need_validation:
        args.validation_day = 3
    else:
        args.validation_day = None
    args.test_day = 6
    
    def clear(folder):
        if os.path.exists(folder):
            shutil.rmtree(folder)
        os.mkdir(folder)
    
    clear(args.out_folder)
    clear(args.metric_folder)
    
    calculate_predictions(args)
    evaluate(args.out_folder, args.data_folder, args.metric_folder, argmax_positions)
    
    with open("metrics/metrics.txt") as handler:
        metric = float(next(handler).strip().split()[0])
        return metric

# %%
print(no_val_metrics)
print(np.mean(no_val_metrics))
print(np.std(no_val_metrics))
# Out:
# [0.622552224779459, 0.6084019246234298, 0.6001719741512457, 0.6035806440807945, 0.6410533974448633, 0.635420558829577, 0.6387686172565953, 0.6080499032464564, 0.6055790911555483, 0.6386901600445535, 0.6724322107183247, 0.619606495315432, 0.6275450725643599, 0.6082089581695699, 0.6151517057685155]
# 0.6230141958765816
# 0.018920250879526538

# %%
print(val_metrics)
print(np.mean(val_metrics))
print(np.std(val_metrics))
# Out:
# [0.6361418544809591, 0.6109498263235139, 0.5756743203725229, 0.6606114715258377, 0.6322742158854051, 0.6070590707340403, 0.629777940796023, 0.6299392332497199, 0.5950429452486984, 0.6074039085046664, 0.610024716177584, 0.6446146106102801, 0.6186540187640717, 0.6250432260994494, 0.6128655233957128]
# 0.6197384588112324
# 0.02005503270737271

# %%
# %%time
no_val_metrics = [get_baseline_metric(False) for i in range(15)]
# Out:
# "2018-06-18 01:08:29.839216": preprocesing started
# "2018-06-18 01:08:39.337453": train features shape: (67567, 80)
# "2018-06-18 01:08:39.337559": preprocesing finished
# "2018-06-18 01:08:39.337660": start training on days [0, 1, 2]
# "2018-06-18 01:08:39.337676": using fit without validation
# "2018-06-18 01:09:02.477044": built 1000 trees
# "2018-06-18 01:09:02.477153": start predicting on day 6
# "2018-06-18 01:09:18.271295": saveing results
# "2018-06-18 01:09:18.279102": results saved
# "2018-06-18 01:09:18.282971": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:09:18.283016": will evaluate days: [6]
# "2018-06-18 01:09:18.283149": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:09:20.238268": calculating metric
# "2018-06-18 01:09:20.239491": preprocesing started
# "2018-06-18 01:09:29.180509": train features shape: (67567, 80)
# "2018-06-18 01:09:29.180599": preprocesing finished
# "2018-06-18 01:09:29.180712": start training on days [0, 1, 2]
# "2018-06-18 01:09:29.180727": using fit without validation
# "2018-06-18 01:10:03.127750": built 1000 trees
# "2018-06-18 01:10:03.127853": start predicting on day 6
# "2018-06-18 01:10:36.239549": saveing results
# "2018-06-18 01:10:36.250308": results saved
# "2018-06-18 01:10:36.256185": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:10:36.256243": will evaluate days: [6]
# "2018-06-18 01:10:36.256447": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:10:38.590242": calculating metric
# "2018-06-18 01:10:38.591247": preprocesing started
# "2018-06-18 01:10:49.575089": train features shape: (67567, 80)
# "2018-06-18 01:10:49.575184": preprocesing finished
# "2018-06-18 01:10:49.575369": start training on days [0, 1, 2]
# "2018-06-18 01:10:49.575386": using fit without validation
# "2018-06-18 01:11:13.151119": built 1000 trees
# "2018-06-18 01:11:13.151207": start predicting on day 6
# "2018-06-18 01:11:27.500942": saveing results
# "2018-06-18 01:11:27.509039": results saved
# "2018-06-18 01:11:27.513020": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:11:27.513093": will evaluate days: [6]
# "2018-06-18 01:11:27.513331": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:11:29.473065": calculating metric
# "2018-06-18 01:11:29.474355": preprocesing started
# "2018-06-18 01:11:38.653797": train features shape: (67567, 80)
# "2018-06-18 01:11:38.653902": preprocesing finished
# "2018-06-18 01:11:38.654004": start training on days [0, 1, 2]
# "2018-06-18 01:11:38.654019": using fit without validation
# "2018-06-18 01:12:01.558263": built 1000 trees
# "2018-06-18 01:12:01.558630": start predicting on day 6
# "2018-06-18 01:12:16.719184": saveing results
# "2018-06-18 01:12:16.727246": results saved
# "2018-06-18 01:12:16.731136": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:12:16.731191": will evaluate days: [6]
# "2018-06-18 01:12:16.731464": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:12:18.768969": calculating metric
# "2018-06-18 01:12:18.770050": preprocesing started
# "2018-06-18 01:12:27.898297": train features shape: (67567, 80)
# "2018-06-18 01:12:27.898395": preprocesing finished
# "2018-06-18 01:12:27.898508": start training on days [0, 1, 2]
# "2018-06-18 01:12:27.898524": using fit without validation
# "2018-06-18 01:12:50.863133": built 1000 trees
# "2018-06-18 01:12:50.863220": start predicting on day 6
# "2018-06-18 01:13:05.550262": saveing results
# "2018-06-18 01:13:05.558642": results saved
# "2018-06-18 01:13:05.562615": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:13:05.562663": will evaluate days: [6]
# "2018-06-18 01:13:05.562809": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:13:07.606711": calculating metric
# "2018-06-18 01:13:07.607925": preprocesing started
# "2018-06-18 01:13:16.819137": train features shape: (67567, 80)
# "2018-06-18 01:13:16.819227": preprocesing finished
# "2018-06-18 01:13:16.819402": start training on days [0, 1, 2]
# "2018-06-18 01:13:16.819418": using fit without validation
# "2018-06-18 01:13:39.779182": built 1000 trees
# "2018-06-18 01:13:39.779284": start predicting on day 6
# "2018-06-18 01:13:54.662814": saveing results
# "2018-06-18 01:13:54.671249": results saved
# "2018-06-18 01:13:54.675186": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:13:54.675235": will evaluate days: [6]
# "2018-06-18 01:13:54.675426": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:13:56.622683": calculating metric
# "2018-06-18 01:13:56.623901": preprocesing started
# "2018-06-18 01:14:05.861468": train features shape: (67567, 80)
# "2018-06-18 01:14:05.861558": preprocesing finished
# "2018-06-18 01:14:05.861671": start training on days [0, 1, 2]
# "2018-06-18 01:14:05.861686": using fit without validation
# "2018-06-18 01:14:28.803743": built 1000 trees
# "2018-06-18 01:14:28.803862": start predicting on day 6
# "2018-06-18 01:14:43.590622": saveing results
# "2018-06-18 01:14:43.598527": results saved
# "2018-06-18 01:14:43.602828": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:14:43.602880": will evaluate days: [6]
# "2018-06-18 01:14:43.603282": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:14:45.598431": calculating metric
# "2018-06-18 01:14:45.599619": preprocesing started
# "2018-06-18 01:14:54.776216": train features shape: (67567, 80)
# "2018-06-18 01:14:54.776306": preprocesing finished
# "2018-06-18 01:14:54.776508": start training on days [0, 1, 2]
# "2018-06-18 01:14:54.776525": using fit without validation
# "2018-06-18 01:15:17.739689": built 1000 trees
# "2018-06-18 01:15:17.739781": start predicting on day 6
# "2018-06-18 01:15:32.585957": saveing results
# "2018-06-18 01:15:32.594263": results saved
# "2018-06-18 01:15:32.598095": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:15:32.598141": will evaluate days: [6]
# "2018-06-18 01:15:32.598381": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:15:34.566838": calculating metric
# "2018-06-18 01:15:34.567955": preprocesing started
# "2018-06-18 01:15:43.791555": train features shape: (67567, 80)
# "2018-06-18 01:15:43.791644": preprocesing finished
# "2018-06-18 01:15:43.791857": start training on days [0, 1, 2]
# "2018-06-18 01:15:43.791878": using fit without validation
# "2018-06-18 01:16:06.943228": built 1000 trees
# "2018-06-18 01:16:06.943337": start predicting on day 6
# "2018-06-18 01:16:21.795276": saveing results
# "2018-06-18 01:16:21.803260": results saved
# "2018-06-18 01:16:21.807060": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:16:21.807107": will evaluate days: [6]
# "2018-06-18 01:16:21.807248": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:16:23.762843": calculating metric
# "2018-06-18 01:16:23.763948": preprocesing started
# "2018-06-18 01:16:33.021050": train features shape: (67567, 80)
# "2018-06-18 01:16:33.021167": preprocesing finished
# "2018-06-18 01:16:33.021351": start training on days [0, 1, 2]
# "2018-06-18 01:16:33.021389": using fit without validation
# "2018-06-18 01:16:55.906932": built 1000 trees
# "2018-06-18 01:16:55.907021": start predicting on day 6
# "2018-06-18 01:17:10.786092": saveing results
# "2018-06-18 01:17:10.794365": results saved
# "2018-06-18 01:17:10.798234": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:17:10.798280": will evaluate days: [6]
# "2018-06-18 01:17:10.798426": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:17:12.735603": calculating metric
# "2018-06-18 01:17:12.736658": preprocesing started
# "2018-06-18 01:17:21.928928": train features shape: (67567, 80)
# "2018-06-18 01:17:21.929014": preprocesing finished
# "2018-06-18 01:17:21.929144": start training on days [0, 1, 2]
# "2018-06-18 01:17:21.929159": using fit without validation
# "2018-06-18 01:17:44.833129": built 1000 trees
# "2018-06-18 01:17:44.833229": start predicting on day 6
# "2018-06-18 01:17:59.552068": saveing results
# "2018-06-18 01:17:59.560229": results saved
# "2018-06-18 01:17:59.564148": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:17:59.564197": will evaluate days: [6]
# "2018-06-18 01:17:59.564392": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:18:01.574600": calculating metric
# "2018-06-18 01:18:01.575682": preprocesing started
# "2018-06-18 01:18:10.761389": train features shape: (67567, 80)
# "2018-06-18 01:18:10.761494": preprocesing finished
# "2018-06-18 01:18:10.761663": start training on days [0, 1, 2]
# "2018-06-18 01:18:10.761678": using fit without validation
# "2018-06-18 01:18:33.675940": built 1000 trees
# "2018-06-18 01:18:33.676015": start predicting on day 6
# "2018-06-18 01:18:48.619415": saveing results
# "2018-06-18 01:18:48.627822": results saved
# "2018-06-18 01:18:48.631695": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:18:48.631742": will evaluate days: [6]
# "2018-06-18 01:18:48.631895": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:18:50.624009": calculating metric
# "2018-06-18 01:18:50.625427": preprocesing started
# "2018-06-18 01:18:59.840004": train features shape: (67567, 80)
# "2018-06-18 01:18:59.840098": preprocesing finished
# "2018-06-18 01:18:59.840215": start training on days [0, 1, 2]
# "2018-06-18 01:18:59.840231": using fit without validation
# "2018-06-18 01:19:22.788368": built 1000 trees
# "2018-06-18 01:19:22.788457": start predicting on day 6
# "2018-06-18 01:19:37.211417": saveing results
# "2018-06-18 01:19:37.219495": results saved
# "2018-06-18 01:19:37.223806": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:19:37.223858": will evaluate days: [6]
# "2018-06-18 01:19:37.224024": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:19:39.246078": calculating metric
# "2018-06-18 01:19:39.247251": preprocesing started
# "2018-06-18 01:19:48.412436": train features shape: (67567, 80)
# "2018-06-18 01:19:48.412525": preprocesing finished
# "2018-06-18 01:19:48.412695": start training on days [0, 1, 2]
# "2018-06-18 01:19:48.412711": using fit without validation
# "2018-06-18 01:20:11.405387": built 1000 trees
# "2018-06-18 01:20:11.405477": start predicting on day 6
# "2018-06-18 01:20:26.198645": saveing results
# "2018-06-18 01:20:26.207775": results saved
# "2018-06-18 01:20:26.211728": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:20:26.211777": will evaluate days: [6]
# "2018-06-18 01:20:26.211890": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:20:28.252229": calculating metric
# "2018-06-18 01:20:28.253340": preprocesing started
# "2018-06-18 01:20:37.342303": train features shape: (67567, 80)
# "2018-06-18 01:20:37.342409": preprocesing finished
# "2018-06-18 01:20:37.342579": start training on days [0, 1, 2]
# "2018-06-18 01:20:37.342595": using fit without validation
# "2018-06-18 01:21:00.241885": built 1000 trees
# "2018-06-18 01:21:00.241971": start predicting on day 6
# "2018-06-18 01:21:15.497672": saveing results
# "2018-06-18 01:21:15.505750": results saved
# "2018-06-18 01:21:15.509693": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:21:15.509745": will evaluate days: [6]
# "2018-06-18 01:21:15.509952": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:21:17.446380": calculating metric
# CPU times: user 51min 19s, sys: 3min 31s, total: 54min 50s
# Wall time: 12min 47s

# %%
# %%time
val_metrics = [get_baseline_metric(True) for i in range(15)]
# Out:
# "2018-06-18 01:21:17.458705": preprocesing started
# "2018-06-18 01:21:26.793120": train features shape: (67567, 80)
# "2018-06-18 01:21:26.906248": preprocesing finished
# "2018-06-18 01:21:26.906408": start training on days [0, 1, 2]
# "2018-06-18 01:21:26.906427": using fit with validation
# "2018-06-18 01:22:12.383705": built 1371 trees
# "2018-06-18 01:22:12.383794": start predicting on day 6
# "2018-06-18 01:22:27.375829": saveing results
# "2018-06-18 01:22:27.383983": results saved
# "2018-06-18 01:22:27.388465": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:22:27.388521": will evaluate days: [6]
# "2018-06-18 01:22:27.388686": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:22:29.346735": calculating metric
# "2018-06-18 01:22:29.347693": preprocesing started
# "2018-06-18 01:22:38.554234": train features shape: (67567, 80)
# "2018-06-18 01:22:38.668936": preprocesing finished
# "2018-06-18 01:22:38.668998": start training on days [0, 1, 2]
# "2018-06-18 01:22:38.669053": using fit with validation
# "2018-06-18 01:23:24.098350": built 1053 trees
# "2018-06-18 01:23:24.098570": start predicting on day 6
# "2018-06-18 01:23:38.970673": saveing results
# "2018-06-18 01:23:38.978843": results saved
# "2018-06-18 01:23:38.983617": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:23:38.983673": will evaluate days: [6]
# "2018-06-18 01:23:38.983790": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:23:40.948876": calculating metric
# "2018-06-18 01:23:40.950111": preprocesing started
# "2018-06-18 01:23:50.072189": train features shape: (67567, 80)
# "2018-06-18 01:23:50.186284": preprocesing finished
# "2018-06-18 01:23:50.186441": start training on days [0, 1, 2]
# "2018-06-18 01:23:50.186460": using fit with validation
# "2018-06-18 01:24:35.572217": built 969 trees
# "2018-06-18 01:24:35.572305": start predicting on day 6
# "2018-06-18 01:24:49.930881": saveing results
# "2018-06-18 01:24:49.939153": results saved
# "2018-06-18 01:24:49.943597": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:24:49.943652": will evaluate days: [6]
# "2018-06-18 01:24:49.943873": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:24:51.924849": calculating metric
# "2018-06-18 01:24:51.926035": preprocesing started
# "2018-06-18 01:25:01.089672": train features shape: (67567, 80)
# "2018-06-18 01:25:01.199980": preprocesing finished
# "2018-06-18 01:25:01.200038": start training on days [0, 1, 2]
# "2018-06-18 01:25:01.200058": using fit with validation
# "2018-06-18 01:25:46.686009": built 1260 trees
# "2018-06-18 01:25:46.686119": start predicting on day 6
# "2018-06-18 01:26:01.917596": saveing results
# "2018-06-18 01:26:01.925503": results saved
# "2018-06-18 01:26:01.929830": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:26:01.929907": will evaluate days: [6]
# "2018-06-18 01:26:01.930115": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:26:03.887554": calculating metric
# "2018-06-18 01:26:03.888546": preprocesing started
# "2018-06-18 01:26:13.109187": train features shape: (67567, 80)
# "2018-06-18 01:26:13.217076": preprocesing finished
# "2018-06-18 01:26:13.217230": start training on days [0, 1, 2]
# "2018-06-18 01:26:13.217252": using fit with validation
# "2018-06-18 01:26:58.700177": built 1254 trees
# "2018-06-18 01:26:58.700282": start predicting on day 6
# "2018-06-18 01:27:15.373894": saveing results
# "2018-06-18 01:27:15.381934": results saved
# "2018-06-18 01:27:15.387491": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:27:15.387545": will evaluate days: [6]
# "2018-06-18 01:27:15.387685": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:27:17.504271": calculating metric
# "2018-06-18 01:27:17.505353": preprocesing started
# "2018-06-18 01:27:27.073940": train features shape: (67567, 80)
# "2018-06-18 01:27:27.186663": preprocesing finished
# "2018-06-18 01:27:27.186753": start training on days [0, 1, 2]
# "2018-06-18 01:27:27.186796": using fit with validation
# "2018-06-18 01:28:13.670903": built 1137 trees
# "2018-06-18 01:28:13.671037": start predicting on day 6
# "2018-06-18 01:28:28.660476": saveing results
# "2018-06-18 01:28:28.668814": results saved
# "2018-06-18 01:28:28.673363": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:28:28.673458": will evaluate days: [6]
# "2018-06-18 01:28:28.673825": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:28:30.647239": calculating metric
# "2018-06-18 01:28:30.648594": preprocesing started
# "2018-06-18 01:28:39.805007": train features shape: (67567, 80)
# "2018-06-18 01:28:39.913209": preprocesing finished
# "2018-06-18 01:28:39.913378": start training on days [0, 1, 2]
# "2018-06-18 01:28:39.913395": using fit with validation
# "2018-06-18 01:29:25.275979": built 1336 trees
# "2018-06-18 01:29:25.276070": start predicting on day 6
# "2018-06-18 01:29:40.812373": saveing results
# "2018-06-18 01:29:40.820762": results saved
# "2018-06-18 01:29:40.825369": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:29:40.825420": will evaluate days: [6]
# "2018-06-18 01:29:40.825577": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:29:42.809663": calculating metric
# "2018-06-18 01:29:42.810722": preprocesing started
# "2018-06-18 01:29:52.060724": train features shape: (67567, 80)
# "2018-06-18 01:29:52.182163": preprocesing finished
# "2018-06-18 01:29:52.182356": start training on days [0, 1, 2]
# "2018-06-18 01:29:52.182461": using fit with validation
# "2018-06-18 01:30:37.872958": built 1310 trees
# "2018-06-18 01:30:37.873048": start predicting on day 6
# "2018-06-18 01:30:53.056748": saveing results
# "2018-06-18 01:30:53.064714": results saved
# "2018-06-18 01:30:53.069580": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:30:53.069680": will evaluate days: [6]
# "2018-06-18 01:30:53.069871": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:30:55.053944": calculating metric
# "2018-06-18 01:30:55.054975": preprocesing started
# "2018-06-18 01:31:04.410106": train features shape: (67567, 80)
# "2018-06-18 01:31:04.521529": preprocesing finished
# "2018-06-18 01:31:04.521658": start training on days [0, 1, 2]
# "2018-06-18 01:31:04.521724": using fit with validation
# "2018-06-18 01:31:50.084026": built 1037 trees
# "2018-06-18 01:31:50.084195": start predicting on day 6
# "2018-06-18 01:32:04.912997": saveing results
# "2018-06-18 01:32:04.921244": results saved
# "2018-06-18 01:32:04.925699": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:32:04.925791": will evaluate days: [6]
# "2018-06-18 01:32:04.925874": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:32:06.889113": calculating metric
# "2018-06-18 01:32:06.890339": preprocesing started
# "2018-06-18 01:32:16.160874": train features shape: (67567, 80)
# "2018-06-18 01:32:16.277741": preprocesing finished
# "2018-06-18 01:32:16.277832": start training on days [0, 1, 2]
# "2018-06-18 01:32:16.277916": using fit with validation
# "2018-06-18 01:33:02.032566": built 1200 trees
# "2018-06-18 01:33:02.032664": start predicting on day 6
# "2018-06-18 01:33:17.250508": saveing results
# "2018-06-18 01:33:17.258633": results saved
# "2018-06-18 01:33:17.263198": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:33:17.263249": will evaluate days: [6]
# "2018-06-18 01:33:17.263377": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:33:19.254716": calculating metric
# "2018-06-18 01:33:19.255883": preprocesing started
# "2018-06-18 01:33:28.531573": train features shape: (67567, 80)
# "2018-06-18 01:33:28.637703": preprocesing finished
# "2018-06-18 01:33:28.637832": start training on days [0, 1, 2]
# "2018-06-18 01:33:28.637896": using fit with validation
# "2018-06-18 01:34:14.258959": built 1026 trees
# "2018-06-18 01:34:14.259051": start predicting on day 6
# "2018-06-18 01:34:29.362610": saveing results
# "2018-06-18 01:34:29.370832": results saved
# "2018-06-18 01:34:29.375361": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:34:29.375410": will evaluate days: [6]
# "2018-06-18 01:34:29.375526": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:34:31.370575": calculating metric
# "2018-06-18 01:34:31.371750": preprocesing started
# "2018-06-18 01:34:40.689764": train features shape: (67567, 80)
# "2018-06-18 01:34:40.801205": preprocesing finished
# "2018-06-18 01:34:40.801316": start training on days [0, 1, 2]
# "2018-06-18 01:34:40.801341": using fit with validation
# "2018-06-18 01:35:26.396704": built 1475 trees
# "2018-06-18 01:35:26.396776": start predicting on day 6
# "2018-06-18 01:35:42.186739": saveing results
# "2018-06-18 01:35:42.195478": results saved
# "2018-06-18 01:35:42.200174": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:35:42.200228": will evaluate days: [6]
# "2018-06-18 01:35:42.200311": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:35:44.165225": calculating metric
# "2018-06-18 01:35:44.166482": preprocesing started
# "2018-06-18 01:35:53.281604": train features shape: (67567, 80)
# "2018-06-18 01:35:53.389248": preprocesing finished
# "2018-06-18 01:35:53.389399": start training on days [0, 1, 2]
# "2018-06-18 01:35:53.389416": using fit with validation
# "2018-06-18 01:36:39.626787": built 1236 trees
# "2018-06-18 01:36:39.626891": start predicting on day 6
# "2018-06-18 01:36:55.487996": saveing results
# "2018-06-18 01:36:55.496410": results saved
# "2018-06-18 01:36:55.501314": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:36:55.501541": will evaluate days: [6]
# "2018-06-18 01:36:55.501796": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:36:57.475732": calculating metric
# "2018-06-18 01:36:57.476896": preprocesing started
# "2018-06-18 01:37:07.173955": train features shape: (67567, 80)
# "2018-06-18 01:37:07.301542": preprocesing finished
# "2018-06-18 01:37:07.301679": start training on days [0, 1, 2]
# "2018-06-18 01:37:07.301791": using fit with validation
# "2018-06-18 01:37:53.557276": built 1172 trees
# "2018-06-18 01:37:53.557366": start predicting on day 6
# "2018-06-18 01:38:08.295540": saveing results
# "2018-06-18 01:38:08.303477": results saved
# "2018-06-18 01:38:08.307938": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:38:08.307988": will evaluate days: [6]
# "2018-06-18 01:38:08.308221": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:38:10.240556": calculating metric
# "2018-06-18 01:38:10.241649": preprocesing started
# "2018-06-18 01:38:19.065587": train features shape: (67567, 80)
# "2018-06-18 01:38:19.168224": preprocesing finished
# "2018-06-18 01:38:19.168280": start training on days [0, 1, 2]
# "2018-06-18 01:38:19.168377": using fit with validation
# "2018-06-18 01:39:05.503848": built 1068 trees
# "2018-06-18 01:39:05.503960": start predicting on day 6
# "2018-06-18 01:39:19.667692": saveing results
# "2018-06-18 01:39:19.675821": results saved
# "2018-06-18 01:39:19.680187": predictions_filenames: ['res/train_0_1_2_test_6.npy']
# "2018-06-18 01:39:19.680235": will evaluate days: [6]
# "2018-06-18 01:39:19.680428": predict on file "res/train_0_1_2_test_6.npy"
# "2018-06-18 01:39:21.606597": calculating metric
# CPU times: user 1h 31min 35s, sys: 4min 4s, total: 1h 35min 40s
# Wall time: 18min 4s
