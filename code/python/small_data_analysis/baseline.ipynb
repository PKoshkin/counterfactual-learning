# %%
import numpy as np
import shutil
import os

import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *
from argparse import Namespace
from catboost import CatBoostRegressor, CatBoostClassifier

# %reload_ext autoreload
# %autoreload 2

# %%
def get_baseline_metric():
    args = Namespace()
    args.verbose = True
    args.first_feature = 0
    args.last_feature = -1
    args.data_folder = "../../../data/best_features_days_data/"
    args.out_folder = "res"
    args.type = "regression"
    args.need_position_feature = True
    args.labels_to_substruct = None
    args.metric_folder = "metrics"
    args.model_constructor = lambda verbose: CatBoostRegressor(verbose=False)
    args.additional_features = None
    args.train_days = [3]
    args.validation_day = None
    args.test_days = [6]
    
    def clear(folder):
        if os.path.exists(folder):
            shutil.rmtree(folder)
        os.mkdir(folder)
    
    clear(args.out_folder)
    clear(args.metric_folder)
    
    calculate_predictions(args)
    evaluate(args.out_folder, args.data_folder, args.metric_folder, argmax_positions)
    
    with open("metrics/metrics.txt") as handler:
        metric = float(next(handler).strip().split()[0])
        return metric

# %%
# %%time
metrics = [get_baseline_metric() for i in range(15)]
# Out:
# "2018-06-21 02:07:47.153959": preprocesing started
# "2018-06-21 02:07:47.922908":     base features shape: (20203, 81)
# "2018-06-21 02:07:47.926252":     0 features added
# "2018-06-21 02:07:47.926348":     result shape: (20203, 81)
# "2018-06-21 02:07:47.928801": train features shape: (20203, 81)
# "2018-06-21 02:07:48.527565": preprocesing finished
# "2018-06-21 02:07:48.527652": start training on days [3]
# "2018-06-21 02:07:48.527683": using fit without validation
# "2018-06-21 02:08:11.079379": built 1000 trees
# "2018-06-21 02:08:13.203091":     base features shape: (247423, 81)
# "2018-06-21 02:08:13.227094":     0 features added
# "2018-06-21 02:08:13.227218":     result shape: (247423, 81)
# "2018-06-21 02:08:13.227529": days to predict: [6]
# "2018-06-21 02:08:13.227778": features shape: (247423, 81)
# "2018-06-21 02:08:13.227812": start predicting on day 6
# "2018-06-21 02:08:14.946725": predictions shape: (22493, 11)
# "2018-06-21 02:08:14.946875": saveing results to res/train_3_test_6
# "2018-06-21 02:08:14.948991": results saved
# "2018-06-21 02:08:16.955178": preprocesing started
# "2018-06-21 02:08:17.694588":     base features shape: (20203, 81)
# "2018-06-21 02:08:17.697785":     0 features added
# "2018-06-21 02:08:17.697884":     result shape: (20203, 81)
# "2018-06-21 02:08:17.699140": train features shape: (20203, 81)
# "2018-06-21 02:08:18.290476": preprocesing finished
# "2018-06-21 02:08:18.290562": start training on days [3]
# "2018-06-21 02:08:18.290660": using fit without validation
# "2018-06-21 02:08:40.103372": built 1000 trees
# "2018-06-21 02:08:42.169015":     base features shape: (247423, 81)
# "2018-06-21 02:08:42.192065":     0 features added
# "2018-06-21 02:08:42.192153":     result shape: (247423, 81)
# "2018-06-21 02:08:42.192533": days to predict: [6]
# "2018-06-21 02:08:42.192649": features shape: (247423, 81)
# "2018-06-21 02:08:42.192682": start predicting on day 6
# "2018-06-21 02:08:43.819608": predictions shape: (22493, 11)
# "2018-06-21 02:08:43.819781": saveing results to res/train_3_test_6
# "2018-06-21 02:08:43.821608": results saved
# "2018-06-21 02:08:45.734704": preprocesing started
# "2018-06-21 02:08:46.439406":     base features shape: (20203, 81)
# "2018-06-21 02:08:46.442133":     0 features added
# "2018-06-21 02:08:46.442199":     result shape: (20203, 81)
# "2018-06-21 02:08:46.443292": train features shape: (20203, 81)
# "2018-06-21 02:08:47.016915": preprocesing finished
# "2018-06-21 02:08:47.017010": start training on days [3]
# "2018-06-21 02:08:47.017122": using fit without validation
# "2018-06-21 02:09:08.691734": built 1000 trees
# "2018-06-21 02:09:10.838420":     base features shape: (247423, 81)
# "2018-06-21 02:09:10.865401":     0 features added
# "2018-06-21 02:09:10.865538":     result shape: (247423, 81)
# "2018-06-21 02:09:10.865883": days to predict: [6]
# "2018-06-21 02:09:10.865931": features shape: (247423, 81)
# "2018-06-21 02:09:10.865964": start predicting on day 6
# "2018-06-21 02:09:12.583083": predictions shape: (22493, 11)
# "2018-06-21 02:09:12.583130": saveing results to res/train_3_test_6
# "2018-06-21 02:09:12.585184": results saved
# "2018-06-21 02:09:14.531709": preprocesing started
# "2018-06-21 02:09:15.286377":     base features shape: (20203, 81)
# "2018-06-21 02:09:15.289281":     0 features added
# "2018-06-21 02:09:15.289378":     result shape: (20203, 81)
# "2018-06-21 02:09:15.290611": train features shape: (20203, 81)
# "2018-06-21 02:09:15.876153": preprocesing finished
# "2018-06-21 02:09:15.876220": start training on days [3]
# "2018-06-21 02:09:15.876234": using fit without validation
# "2018-06-21 02:09:37.613565": built 1000 trees
# "2018-06-21 02:09:39.867259":     base features shape: (247423, 81)
# "2018-06-21 02:09:39.891140":     0 features added
# "2018-06-21 02:09:39.891229":     result shape: (247423, 81)
# "2018-06-21 02:09:39.891542": days to predict: [6]
# "2018-06-21 02:09:39.891705": features shape: (247423, 81)
# "2018-06-21 02:09:39.891774": start predicting on day 6
# "2018-06-21 02:09:41.641903": predictions shape: (22493, 11)
# "2018-06-21 02:09:41.642030": saveing results to res/train_3_test_6
# "2018-06-21 02:09:41.643825": results saved
# "2018-06-21 02:09:43.742149": preprocesing started
# "2018-06-21 02:09:44.482013":     base features shape: (20203, 81)
# "2018-06-21 02:09:44.484684":     0 features added
# "2018-06-21 02:09:44.484737":     result shape: (20203, 81)
# "2018-06-21 02:09:44.485883": train features shape: (20203, 81)
# "2018-06-21 02:09:45.089834": preprocesing finished
# "2018-06-21 02:09:45.089905": start training on days [3]
# "2018-06-21 02:09:45.089920": using fit without validation
# "2018-06-21 02:10:08.702752": built 1000 trees
# "2018-06-21 02:10:10.987256":     base features shape: (247423, 81)
# "2018-06-21 02:10:11.012706":     0 features added
# "2018-06-21 02:10:11.012800":     result shape: (247423, 81)
# "2018-06-21 02:10:11.013222": days to predict: [6]
# "2018-06-21 02:10:11.013266": features shape: (247423, 81)
# "2018-06-21 02:10:11.013285": start predicting on day 6
# "2018-06-21 02:10:12.869487": predictions shape: (22493, 11)
# "2018-06-21 02:10:12.869595": saveing results to res/train_3_test_6
# "2018-06-21 02:10:12.871904": results saved
# "2018-06-21 02:10:14.929006": preprocesing started
# "2018-06-21 02:10:15.663840":     base features shape: (20203, 81)
# "2018-06-21 02:10:15.666549":     0 features added
# "2018-06-21 02:10:15.666600":     result shape: (20203, 81)
# "2018-06-21 02:10:15.667779": train features shape: (20203, 81)
# "2018-06-21 02:10:16.291405": preprocesing finished
# "2018-06-21 02:10:16.291494": start training on days [3]
# "2018-06-21 02:10:16.291615": using fit without validation
# "2018-06-21 02:10:39.147908": built 1000 trees
# "2018-06-21 02:10:41.329387":     base features shape: (247423, 81)
# "2018-06-21 02:10:41.353686":     0 features added
# "2018-06-21 02:10:41.353771":     result shape: (247423, 81)
# "2018-06-21 02:10:41.354182": days to predict: [6]
# "2018-06-21 02:10:41.354290": features shape: (247423, 81)
# "2018-06-21 02:10:41.354375": start predicting on day 6
# "2018-06-21 02:10:43.028702": predictions shape: (22493, 11)
# "2018-06-21 02:10:43.028808": saveing results to res/train_3_test_6
# "2018-06-21 02:10:43.030652": results saved
# "2018-06-21 02:10:45.093533": preprocesing started
# "2018-06-21 02:10:45.864915":     base features shape: (20203, 81)
# "2018-06-21 02:10:45.867609":     0 features added
# "2018-06-21 02:10:45.867666":     result shape: (20203, 81)
# "2018-06-21 02:10:45.868724": train features shape: (20203, 81)
# "2018-06-21 02:10:46.475044": preprocesing finished
# "2018-06-21 02:10:46.475131": start training on days [3]
# "2018-06-21 02:10:46.475295": using fit without validation
# "2018-06-21 02:11:09.867748": built 1000 trees
# "2018-06-21 02:11:12.043707":     base features shape: (247423, 81)
# "2018-06-21 02:11:12.067576":     0 features added
# "2018-06-21 02:11:12.067649":     result shape: (247423, 81)
# "2018-06-21 02:11:12.068029": days to predict: [6]
# "2018-06-21 02:11:12.068072": features shape: (247423, 81)
# "2018-06-21 02:11:12.068106": start predicting on day 6
# "2018-06-21 02:11:13.896394": predictions shape: (22493, 11)
# "2018-06-21 02:11:13.896555": saveing results to res/train_3_test_6
# "2018-06-21 02:11:13.898315": results saved
# "2018-06-21 02:11:15.944230": preprocesing started
# "2018-06-21 02:11:16.673846":     base features shape: (20203, 81)
# "2018-06-21 02:11:16.676451":     0 features added
# "2018-06-21 02:11:16.676507":     result shape: (20203, 81)
# "2018-06-21 02:11:16.677654": train features shape: (20203, 81)
# "2018-06-21 02:11:17.277517": preprocesing finished
# "2018-06-21 02:11:17.277620": start training on days [3]
# "2018-06-21 02:11:17.277685": using fit without validation
# "2018-06-21 02:11:41.098295": built 1000 trees
# "2018-06-21 02:11:43.241444":     base features shape: (247423, 81)
# "2018-06-21 02:11:43.266441":     0 features added
# "2018-06-21 02:11:43.266538":     result shape: (247423, 81)
# "2018-06-21 02:11:43.267014": days to predict: [6]
# "2018-06-21 02:11:43.267058": features shape: (247423, 81)
# "2018-06-21 02:11:43.267134": start predicting on day 6
# "2018-06-21 02:11:44.938539": predictions shape: (22493, 11)
# "2018-06-21 02:11:44.938698": saveing results to res/train_3_test_6
# "2018-06-21 02:11:44.941089": results saved
# "2018-06-21 02:11:46.950995": preprocesing started
# "2018-06-21 02:11:47.716818":     base features shape: (20203, 81)
# "2018-06-21 02:11:47.719823":     0 features added
# "2018-06-21 02:11:47.719899":     result shape: (20203, 81)
# "2018-06-21 02:11:47.721097": train features shape: (20203, 81)
# "2018-06-21 02:11:48.302482": preprocesing finished
# "2018-06-21 02:11:48.302597": start training on days [3]
# "2018-06-21 02:11:48.302719": using fit without validation
# "2018-06-21 02:12:11.056970": built 1000 trees
# "2018-06-21 02:12:13.260755":     base features shape: (247423, 81)
# "2018-06-21 02:12:13.285901":     0 features added
# "2018-06-21 02:12:13.285980":     result shape: (247423, 81)
# "2018-06-21 02:12:13.286290": days to predict: [6]
# "2018-06-21 02:12:13.286490": features shape: (247423, 81)
# "2018-06-21 02:12:13.286626": start predicting on day 6
# "2018-06-21 02:12:15.013801": predictions shape: (22493, 11)
# "2018-06-21 02:12:15.014147": saveing results to res/train_3_test_6
# "2018-06-21 02:12:15.016034": results saved
# "2018-06-21 02:12:17.203512": preprocesing started
# "2018-06-21 02:12:17.973093":     base features shape: (20203, 81)
# "2018-06-21 02:12:17.975914":     0 features added
# "2018-06-21 02:12:17.975970":     result shape: (20203, 81)
# "2018-06-21 02:12:17.977098": train features shape: (20203, 81)
# "2018-06-21 02:12:18.575768": preprocesing finished
# "2018-06-21 02:12:18.575836": start training on days [3]
# "2018-06-21 02:12:18.575851": using fit without validation
# "2018-06-21 02:12:42.827687": built 1000 trees
# "2018-06-21 02:12:44.974548":     base features shape: (247423, 81)
# "2018-06-21 02:12:44.998013":     0 features added
# "2018-06-21 02:12:44.998100":     result shape: (247423, 81)
# "2018-06-21 02:12:44.998446": days to predict: [6]
# "2018-06-21 02:12:44.998561": features shape: (247423, 81)
# "2018-06-21 02:12:44.998578": start predicting on day 6
# "2018-06-21 02:12:46.843175": predictions shape: (22493, 11)
# "2018-06-21 02:12:46.843277": saveing results to res/train_3_test_6
# "2018-06-21 02:12:46.845241": results saved
# "2018-06-21 02:12:48.874649": preprocesing started
# "2018-06-21 02:12:49.656589":     base features shape: (20203, 81)
# "2018-06-21 02:12:49.659375":     0 features added
# "2018-06-21 02:12:49.659417":     result shape: (20203, 81)
# "2018-06-21 02:12:49.660425": train features shape: (20203, 81)
# "2018-06-21 02:12:50.270525": preprocesing finished
# "2018-06-21 02:12:50.270594": start training on days [3]
# "2018-06-21 02:12:50.270610": using fit without validation
# "2018-06-21 02:13:14.720529": built 1000 trees
# "2018-06-21 02:13:16.900455":     base features shape: (247423, 81)
# "2018-06-21 02:13:16.924909":     0 features added
# "2018-06-21 02:13:16.924995":     result shape: (247423, 81)
# "2018-06-21 02:13:16.925436": days to predict: [6]
# "2018-06-21 02:13:16.925490": features shape: (247423, 81)
# "2018-06-21 02:13:16.925539": start predicting on day 6
# "2018-06-21 02:13:18.688083": predictions shape: (22493, 11)
# "2018-06-21 02:13:18.688195": saveing results to res/train_3_test_6
# "2018-06-21 02:13:18.690086": results saved
# "2018-06-21 02:13:20.787901": preprocesing started
# "2018-06-21 02:13:21.613839":     base features shape: (20203, 81)
# "2018-06-21 02:13:21.616518":     0 features added
# "2018-06-21 02:13:21.616587":     result shape: (20203, 81)
# "2018-06-21 02:13:21.618073": train features shape: (20203, 81)
# "2018-06-21 02:13:22.234384": preprocesing finished
# "2018-06-21 02:13:22.234455": start training on days [3]
# "2018-06-21 02:13:22.234470": using fit without validation
# "2018-06-21 02:13:44.009231": built 1000 trees
# "2018-06-21 02:13:46.123456":     base features shape: (247423, 81)
# "2018-06-21 02:13:46.146219":     0 features added
# "2018-06-21 02:13:46.146271":     result shape: (247423, 81)
# "2018-06-21 02:13:46.146631": days to predict: [6]
# "2018-06-21 02:13:46.146732": features shape: (247423, 81)
# "2018-06-21 02:13:46.146836": start predicting on day 6
# "2018-06-21 02:13:47.865675": predictions shape: (22493, 11)
# "2018-06-21 02:13:47.865783": saveing results to res/train_3_test_6
# "2018-06-21 02:13:47.867573": results saved
# "2018-06-21 02:13:49.949160": preprocesing started
# "2018-06-21 02:13:50.707008":     base features shape: (20203, 81)
# "2018-06-21 02:13:50.709721":     0 features added
# "2018-06-21 02:13:50.709776":     result shape: (20203, 81)
# "2018-06-21 02:13:50.710922": train features shape: (20203, 81)
# "2018-06-21 02:13:51.308641": preprocesing finished
# "2018-06-21 02:13:51.308714": start training on days [3]
# "2018-06-21 02:13:51.308733": using fit without validation
# "2018-06-21 02:14:13.090191": built 1000 trees
# "2018-06-21 02:14:15.300452":     base features shape: (247423, 81)
# "2018-06-21 02:14:15.326180":     0 features added
# "2018-06-21 02:14:15.326255":     result shape: (247423, 81)
# "2018-06-21 02:14:15.326645": days to predict: [6]
# "2018-06-21 02:14:15.326739": features shape: (247423, 81)
# "2018-06-21 02:14:15.326806": start predicting on day 6
# "2018-06-21 02:14:17.050795": predictions shape: (22493, 11)
# "2018-06-21 02:14:17.051036": saveing results to res/train_3_test_6
# "2018-06-21 02:14:17.052902": results saved
# "2018-06-21 02:14:19.059160": preprocesing started
# "2018-06-21 02:14:19.792961":     base features shape: (20203, 81)
# "2018-06-21 02:14:19.795679":     0 features added
# "2018-06-21 02:14:19.795757":     result shape: (20203, 81)
# "2018-06-21 02:14:19.796878": train features shape: (20203, 81)
# "2018-06-21 02:14:20.359416": preprocesing finished
# "2018-06-21 02:14:20.359501": start training on days [3]
# "2018-06-21 02:14:20.359611": using fit without validation
# "2018-06-21 02:14:42.607983": built 1000 trees
# "2018-06-21 02:14:44.856664":     base features shape: (247423, 81)
# "2018-06-21 02:14:44.879864":     0 features added
# "2018-06-21 02:14:44.879935":     result shape: (247423, 81)
# "2018-06-21 02:14:44.880278": days to predict: [6]
# "2018-06-21 02:14:44.880396": features shape: (247423, 81)
# "2018-06-21 02:14:44.880466": start predicting on day 6
# "2018-06-21 02:14:46.630329": predictions shape: (22493, 11)
# "2018-06-21 02:14:46.630452": saveing results to res/train_3_test_6
# "2018-06-21 02:14:46.632106": results saved
# "2018-06-21 02:14:48.691955": preprocesing started
# "2018-06-21 02:14:49.419816":     base features shape: (20203, 81)
# "2018-06-21 02:14:49.422441":     0 features added
# "2018-06-21 02:14:49.422497":     result shape: (20203, 81)
# "2018-06-21 02:14:49.423674": train features shape: (20203, 81)
# "2018-06-21 02:14:49.993146": preprocesing finished
# "2018-06-21 02:14:49.993233": start training on days [3]
# "2018-06-21 02:14:49.993356": using fit without validation
# "2018-06-21 02:15:13.107488": built 1000 trees
# "2018-06-21 02:15:15.418454":     base features shape: (247423, 81)
# "2018-06-21 02:15:15.441609":     0 features added
# "2018-06-21 02:15:15.441715":     result shape: (247423, 81)
# "2018-06-21 02:15:15.442145": days to predict: [6]
# "2018-06-21 02:15:15.442271": features shape: (247423, 81)
# "2018-06-21 02:15:15.442327": start predicting on day 6
# "2018-06-21 02:15:17.186323": predictions shape: (22493, 11)
# "2018-06-21 02:15:17.186446": saveing results to res/train_3_test_6
# "2018-06-21 02:15:17.188349": results saved
# CPU times: user 38min 43s, sys: 1min 27s, total: 40min 10s
# Wall time: 7min 32s

# %%
print(metrics)
print(np.mean(metrics))
print(np.std(metrics) / np.sqrt(15))
# Out:
# [0.6076812665695607, 0.6170799499156694, 0.5914034069750512, 0.6251670250610566, 0.6120500178485521, 0.6096602012012595, 0.6250358344524832, 0.6289067538108394, 0.6461730738875195, 0.6256324027044039, 0.5967641357883737, 0.6014225090866928, 0.6373644371537843, 0.5931218897927142, 0.6333450300500335]
# 0.6167205289531996
# 0.004175084501066948

# %%
print(metrics)
print(np.mean(metrics))
print(np.std(metrics) / np.sqrt(15))
# Out:
# [0.5947323020013656, 0.6184693903505851, 0.6332397275528542, 0.6103790857697263, 0.6323361314139331, 0.6303575321762455, 0.5977653631284916, 0.6451872692549164, 0.6321760924113515, 0.5902067972182128, 0.6125002142022201, 0.6367441812313784, 0.5843774930782693, 0.6104630742765856, 0.6067624375232427]
# 0.6157131394392918
# 0.0046804016376627575
