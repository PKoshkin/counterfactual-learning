# %%
import numpy as np
import shutil
import os

from argparse import Namespace
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.svm import LinearSVR
from sklearn.linear_model import Lars, ElasticNet, Perceptron, SGDRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor

import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *

FEATURES_NUMBER = 79

# %reload_ext autoreload
# %autoreload 2

# %%
def calculate_targets_to_substruct(i):
    args = Namespace()
    args.verbose = False
    args.first_feature = 0
    args.last_feature = -1
    args.data_folder = "../../../data/best_features_days_data/"
    args.out_folder = "targets_to_substruct"
    args.model_constructor=lambda verbose: CatBoostRegressor(verbose=verbose)
    args.type = "binary_regression"
    args.additional_features = {
        day: [
            os.path.join("res", folder, "train_1_test_{}.npy".format(day))
            for folder in os.listdir("res")
            if folder.startswith(str(i))
        ] for day in [2, 3, 6]
    }
    args.train_days = [2]
    args.validation_day = None
    args.test_days = [3, 6]

    def clear(folder):
        if os.path.exists(folder):
            shutil.rmtree(folder)
        os.mkdir(folder)

    args.out_folder = os.path.join(args.out_folder, str(i))
    os.mkdir(args.out_folder)
    
    calculate_predictions(args)

# %%
for i in range(16):
    calculate_targets_to_substruct(i)
# Out:
# "2018-06-19 00:38:01.565966": preprocesing started
# "2018-06-19 00:38:04.410281": train features shape: (22314, 107)
# "2018-06-19 00:38:08.443446": preprocesing finished
# "2018-06-19 00:38:08.443533": start training on days [2]
# "2018-06-19 00:38:08.443641": using fit without validation
# "2018-06-19 00:38:31.260978": built 1000 trees
# "2018-06-19 00:38:31.261075": start predicting on day 3
# "2018-06-19 00:38:31.410313": saveing results
# "2018-06-19 00:38:31.410943": results saved
# "2018-06-19 00:38:31.410991": start predicting on day 6
# "2018-06-19 00:38:31.572729": saveing results
# "2018-06-19 00:38:31.573526": results saved
# "2018-06-19 00:38:31.576017": preprocesing started
# "2018-06-19 00:38:36.683829": train features shape: (22314, 275)
# "2018-06-19 00:38:40.859776": preprocesing finished
# "2018-06-19 00:38:40.859866": start training on days [2]
# "2018-06-19 00:38:40.859899": using fit without validation
# "2018-06-19 00:39:30.311379": built 1000 trees
# "2018-06-19 00:39:30.311498": start predicting on day 3
# "2018-06-19 00:39:30.668995": saveing results
# "2018-06-19 00:39:30.669702": results saved
# "2018-06-19 00:39:30.669751": start predicting on day 6
# "2018-06-19 00:39:31.087728": saveing results
# "2018-06-19 00:39:31.088539": results saved
# "2018-06-19 00:39:31.091282": preprocesing started
# "2018-06-19 00:39:33.950008": train features shape: (22314, 107)
# "2018-06-19 00:39:37.959353": preprocesing finished
# "2018-06-19 00:39:37.959453": start training on days [2]
# "2018-06-19 00:39:37.959473": using fit without validation
# "2018-06-19 00:40:01.729949": built 1000 trees
# "2018-06-19 00:40:01.730072": start predicting on day 3
# "2018-06-19 00:40:01.873292": saveing results
# "2018-06-19 00:40:01.874066": results saved
# "2018-06-19 00:40:01.874118": start predicting on day 6
# "2018-06-19 00:40:02.043107": saveing results
# "2018-06-19 00:40:02.043685": results saved
# "2018-06-19 00:40:02.045338": preprocesing started
# "2018-06-19 00:40:04.887249": train features shape: (22314, 107)
# "2018-06-19 00:40:09.047014": preprocesing finished
# "2018-06-19 00:40:09.047084": start training on days [2]
# "2018-06-19 00:40:09.047101": using fit without validation
# "2018-06-19 00:40:32.773318": built 1000 trees
# "2018-06-19 00:40:32.773423": start predicting on day 3
# "2018-06-19 00:40:32.922830": saveing results
# "2018-06-19 00:40:32.923411": results saved
# "2018-06-19 00:40:32.923444": start predicting on day 6
# "2018-06-19 00:40:33.087616": saveing results
# "2018-06-19 00:40:33.088150": results saved
# "2018-06-19 00:40:33.089824": preprocesing started
# "2018-06-19 00:40:35.918899": train features shape: (22314, 107)
# "2018-06-19 00:40:40.052840": preprocesing finished
# "2018-06-19 00:40:40.052928": start training on days [2]
# "2018-06-19 00:40:40.053040": using fit without validation
# "2018-06-19 00:41:03.756748": built 1000 trees
# "2018-06-19 00:41:03.756906": start predicting on day 3
# "2018-06-19 00:41:03.905380": saveing results
# "2018-06-19 00:41:03.906051": results saved
# "2018-06-19 00:41:03.906101": start predicting on day 6
# "2018-06-19 00:41:04.078173": saveing results
# "2018-06-19 00:41:04.079110": results saved
# "2018-06-19 00:41:04.081037": preprocesing started
# "2018-06-19 00:41:06.911628": train features shape: (22314, 107)
# "2018-06-19 00:41:11.152375": preprocesing finished
# "2018-06-19 00:41:11.152466": start training on days [2]
# "2018-06-19 00:41:11.152484": using fit without validation
# "2018-06-19 00:41:34.866592": built 1000 trees
# "2018-06-19 00:41:34.866726": start predicting on day 3
# "2018-06-19 00:41:35.012274": saveing results
# "2018-06-19 00:41:35.013006": results saved
# "2018-06-19 00:41:35.013053": start predicting on day 6
# "2018-06-19 00:41:35.173447": saveing results
# "2018-06-19 00:41:35.174249": results saved
# "2018-06-19 00:41:35.176585": preprocesing started
# "2018-06-19 00:41:37.959175": train features shape: (22314, 107)
# "2018-06-19 00:41:41.992132": preprocesing finished
# "2018-06-19 00:41:41.992218": start training on days [2]
# "2018-06-19 00:41:41.992249": using fit without validation
# "2018-06-19 00:42:05.543872": built 1000 trees
# "2018-06-19 00:42:05.543977": start predicting on day 3
# "2018-06-19 00:42:05.693035": saveing results
# "2018-06-19 00:42:05.693793": results saved
# "2018-06-19 00:42:05.693841": start predicting on day 6
# "2018-06-19 00:42:05.859158": saveing results
# "2018-06-19 00:42:05.859708": results saved
# "2018-06-19 00:42:05.861388": preprocesing started
# "2018-06-19 00:42:09.085308": train features shape: (22314, 107)
# "2018-06-19 00:42:13.093833": preprocesing finished
# "2018-06-19 00:42:13.093920": start training on days [2]
# "2018-06-19 00:42:13.094218": using fit without validation
# "2018-06-19 00:42:36.665718": built 1000 trees
# "2018-06-19 00:42:36.665854": start predicting on day 3
# "2018-06-19 00:42:36.812722": saveing results
# "2018-06-19 00:42:36.813359": results saved
# "2018-06-19 00:42:36.813408": start predicting on day 6
# "2018-06-19 00:42:36.977812": saveing results
# "2018-06-19 00:42:36.978425": results saved
# "2018-06-19 00:42:36.980011": preprocesing started
# "2018-06-19 00:42:40.106958": train features shape: (22314, 107)
# "2018-06-19 00:42:44.127577": preprocesing finished
# "2018-06-19 00:42:44.127694": start training on days [2]
# "2018-06-19 00:42:44.127718": using fit without validation
# "2018-06-19 00:43:07.771949": built 1000 trees
# "2018-06-19 00:43:07.772052": start predicting on day 3
# "2018-06-19 00:43:07.914111": saveing results
# "2018-06-19 00:43:07.915067": results saved
# "2018-06-19 00:43:07.915118": start predicting on day 6
# "2018-06-19 00:43:08.080541": saveing results
# "2018-06-19 00:43:08.081419": results saved
# "2018-06-19 00:43:08.083358": preprocesing started
# "2018-06-19 00:43:11.536883": train features shape: (22314, 107)
# "2018-06-19 00:43:15.738561": preprocesing finished
# "2018-06-19 00:43:15.738648": start training on days [2]
# "2018-06-19 00:43:15.738898": using fit without validation
# "2018-06-19 00:43:39.587010": built 1000 trees
# "2018-06-19 00:43:39.587114": start predicting on day 3
# "2018-06-19 00:43:39.738473": saveing results
# "2018-06-19 00:43:39.739138": results saved
# "2018-06-19 00:43:39.739168": start predicting on day 6
# "2018-06-19 00:43:39.906334": saveing results
# "2018-06-19 00:43:39.907136": results saved
# "2018-06-19 00:43:39.909286": preprocesing started
# "2018-06-19 00:43:42.762467": train features shape: (22314, 107)
# "2018-06-19 00:43:47.166096": preprocesing finished
# "2018-06-19 00:43:47.166216": start training on days [2]
# "2018-06-19 00:43:47.166362": using fit without validation
# "2018-06-19 00:44:12.996595": built 1000 trees
# "2018-06-19 00:44:12.996717": start predicting on day 3
# "2018-06-19 00:44:13.147954": saveing results
# "2018-06-19 00:44:13.148799": results saved
# "2018-06-19 00:44:13.148864": start predicting on day 6
# "2018-06-19 00:44:13.323944": saveing results
# "2018-06-19 00:44:13.324695": results saved
# "2018-06-19 00:44:13.326442": preprocesing started
# "2018-06-19 00:44:16.210040": train features shape: (22314, 107)
# "2018-06-19 00:44:20.454163": preprocesing finished
# "2018-06-19 00:44:20.454270": start training on days [2]
# "2018-06-19 00:44:20.454285": using fit without validation
# "2018-06-19 00:44:44.314269": built 1000 trees
# "2018-06-19 00:44:44.314373": start predicting on day 3
# "2018-06-19 00:44:44.467124": saveing results
# "2018-06-19 00:44:44.467863": results saved
# "2018-06-19 00:44:44.467947": start predicting on day 6
# "2018-06-19 00:44:44.639303": saveing results
# "2018-06-19 00:44:44.640168": results saved
# "2018-06-19 00:44:44.642042": preprocesing started
# "2018-06-19 00:44:47.574883": train features shape: (22314, 107)
# "2018-06-19 00:44:51.975602": preprocesing finished
# "2018-06-19 00:44:51.975672": start training on days [2]
# "2018-06-19 00:44:51.975687": using fit without validation
# "2018-06-19 00:45:16.885796": built 1000 trees
# "2018-06-19 00:45:16.885899": start predicting on day 3
# "2018-06-19 00:45:17.032468": saveing results
# "2018-06-19 00:45:17.033292": results saved
# "2018-06-19 00:45:17.033340": start predicting on day 6
# "2018-06-19 00:45:17.205151": saveing results
# "2018-06-19 00:45:17.205920": results saved
# "2018-06-19 00:45:17.207520": preprocesing started
# "2018-06-19 00:45:20.094982": train features shape: (22314, 107)
# "2018-06-19 00:45:24.292858": preprocesing finished
# "2018-06-19 00:45:24.292945": start training on days [2]
# "2018-06-19 00:45:24.292977": using fit without validation
# "2018-06-19 00:45:48.950574": built 1000 trees
# "2018-06-19 00:45:48.950713": start predicting on day 3
# "2018-06-19 00:45:49.108314": saveing results
# "2018-06-19 00:45:49.109138": results saved
# "2018-06-19 00:45:49.109186": start predicting on day 6
# "2018-06-19 00:45:49.269359": saveing results
# "2018-06-19 00:45:49.270121": results saved
# "2018-06-19 00:45:49.272012": preprocesing started
# "2018-06-19 00:45:52.005133": train features shape: (22314, 107)
# "2018-06-19 00:45:56.086618": preprocesing finished
# "2018-06-19 00:45:56.086723": start training on days [2]
# "2018-06-19 00:45:56.086743": using fit without validation
# "2018-06-19 00:46:21.034825": built 1000 trees
# "2018-06-19 00:46:21.034944": start predicting on day 3
# "2018-06-19 00:46:21.180851": saveing results
# "2018-06-19 00:46:21.181435": results saved
# "2018-06-19 00:46:21.181482": start predicting on day 6
# "2018-06-19 00:46:21.346230": saveing results
# "2018-06-19 00:46:21.346876": results saved
# "2018-06-19 00:46:21.348526": preprocesing started
# "2018-06-19 00:46:24.163703": train features shape: (22314, 107)
# "2018-06-19 00:46:28.287947": preprocesing finished
# "2018-06-19 00:46:28.288034": start training on days [2]
# "2018-06-19 00:46:28.288065": using fit without validation
# "2018-06-19 00:46:51.602326": built 1000 trees
# "2018-06-19 00:46:51.602429": start predicting on day 3
# "2018-06-19 00:46:51.750034": saveing results
# "2018-06-19 00:46:51.750843": results saved
# "2018-06-19 00:46:51.750887": start predicting on day 6
# "2018-06-19 00:46:51.914951": saveing results
# "2018-06-19 00:46:51.915676": results saved
