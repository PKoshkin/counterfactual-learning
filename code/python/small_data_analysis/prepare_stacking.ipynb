# %%
import numpy as np
import shutil
import os

from argparse import Namespace
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.svm import LinearSVR
from sklearn.linear_model import Lars, ElasticNet, Perceptron, SGDRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor

import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *

FEATURES_NUMBER = 79

# %reload_ext autoreload
# %autoreload 2

# %%
def prepare_features(i):
    args = Namespace()
    args.verbose = False
    args.data_folder = "../../../data/best_features_days_data/"
    args.out_folder = "res"
    args.type = "binary_regression"
    args.additional_features = None
    args.train_days = [1]
    args.validation_day = None
    args.test_days = [3]

    model_constructors = [
        lambda verbose: LinearSVR(),
        lambda verbose: Lars(),
        lambda verbose: ElasticNet(),
        lambda verbose: Perceptron(),
        lambda verbose: AdaBoostRegressor(),
        lambda verbose: GradientBoostingRegressor(),
        lambda verbose: RandomForestRegressor()
    ]
    model_names = [
        "svr",
        "lars",
        "elastic",
        "preceptron",
        "ada_boost",
        "gradient_boost",
        "random_forest"
    ]

    def clear(folder):
        if os.path.exists(folder):
            shutil.rmtree(folder)
        os.mkdir(folder)
    
    out_folder = args.out_folder

    args.step = 30
    for model_name, model_constructor in zip(model_names, model_constructors):
        args.first_feature = 0
        args.last_feature = args.step
        args.model_constructor = model_constructor
        while args.first_feature < FEATURES_NUMBER:
            args.last_feature = min(args.last_feature, FEATURES_NUMBER)
            args.out_folder = os.path.join(
                out_folder,
                str(i) + '_' + model_name + "_features_from_{}_to_{}".format(
                    args.first_feature, args.last_feature
                )
            )
            #if not os.path.exists(args.out_folder):
                #clear(args.out_folder)
            calculate_predictions(args)
            args.first_feature += args.step
            args.last_feature += args.step

    args.first_feature = 0
    args.last_feature = -1
            
    for model_name, model_constructor in zip(model_names, model_constructors):
        args.out_folder = os.path.join(out_folder, str(i) + '_' + model_name + "_all_features")
        args.model_constructor = model_constructor
        #if not os.path.exists(args.out_folder):
            #clear(args.out_folder)
        calculate_predictions(args)

# %%
for i in range(14, 16):
    prepare_features(i)
# Out:
# "2018-06-19 00:14:57.684789": preprocesing started
# "2018-06-19 00:14:59.113559": train features shape: (22452, 30)
# "2018-06-19 00:15:03.128605": preprocesing finished
# "2018-06-19 00:15:03.128693": start training on days [1]
# "2018-06-19 00:15:03.128800": using fit without validation
# "2018-06-19 00:15:06.861271": start predicting on day 3
# "2018-06-19 00:15:06.862295": saveing results
# "2018-06-19 00:15:06.862929": results saved
# "2018-06-19 00:15:06.863069": preprocesing started
# "2018-06-19 00:15:08.211513": train features shape: (22452, 30)
# "2018-06-19 00:15:12.322905": preprocesing finished
# "2018-06-19 00:15:12.323008": start training on days [1]
# "2018-06-19 00:15:12.323027": using fit without validation
# "2018-06-19 00:15:14.977824": start predicting on day 3
# "2018-06-19 00:15:14.978740": saveing results
# "2018-06-19 00:15:14.979294": results saved
# "2018-06-19 00:15:14.979396": preprocesing started
# "2018-06-19 00:15:16.254962": train features shape: (22452, 19)
# "2018-06-19 00:17:01.516757": start predicting on day 3
# "2018-06-19 00:17:01.538983": saveing results
# "2018-06-19 00:17:01.539642": results saved
# "2018-06-19 00:17:01.539791": preprocesing started
# "2018-06-19 00:17:02.903048": train features shape: (22452, 30)
# "2018-06-19 00:17:06.872358": preprocesing finished
# "2018-06-19 00:17:06.872445": start training on days [1]
# "2018-06-19 00:17:06.872554": using fit without validation
# "2018-06-19 00:17:10.352683": start predicting on day 3
# "2018-06-19 00:17:10.388544": saveing results
# "2018-06-19 00:17:10.389294": results saved
# "2018-06-19 00:17:10.389409": preprocesing started
# "2018-06-19 00:17:11.751614": train features shape: (22452, 30)
# "2018-06-19 00:17:15.800699": preprocesing finished
# "2018-06-19 00:17:15.800840": start training on days [1]
# "2018-06-19 00:17:15.800858": using fit without validation
# "2018-06-19 00:17:21.209824": start predicting on day 3
# "2018-06-19 00:17:21.247901": saveing results
# "2018-06-19 00:17:21.248682": results saved
# "2018-06-19 00:17:21.248781": preprocesing started
# "2018-06-19 00:17:22.610383": train features shape: (22452, 19)
# "2018-06-19 00:17:26.628146": preprocesing finished
# "2018-06-19 00:17:26.628232": start training on days [1]
# "2018-06-19 00:17:26.628250": using fit without validation
# "2018-06-19 00:17:29.101998": start predicting on day 3
# "2018-06-19 00:17:29.138494": saveing results
# "2018-06-19 00:17:29.139083": results saved
# "2018-06-19 00:17:29.139171": preprocesing started
# "2018-06-19 00:17:30.599038": train features shape: (22452, 79)
# "2018-06-19 00:17:34.609163": preprocesing finished
# "2018-06-19 00:17:34.609268": start training on days [1]
# "2018-06-19 00:17:34.609287": using fit without validation
# "2018-06-19 00:17:40.921217": start predicting on day 3
# "2018-06-19 00:17:40.923788": saveing results
# "2018-06-19 00:17:40.924385": results saved
# "2018-06-19 00:17:40.924559": preprocesing started
# "2018-06-19 00:17:42.353630": train features shape: (22452, 79)
# "2018-06-19 00:17:46.326327": preprocesing finished
# "2018-06-19 00:17:46.326414": start training on days [1]
# "2018-06-19 00:17:46.326434": using fit without validation
# "2018-06-19 00:17:46.417555": start predicting on day 3
# "2018-06-19 00:17:46.420136": saveing results
# "2018-06-19 00:17:46.420701": results saved
# "2018-06-19 00:17:46.421393": preprocesing started
# "2018-06-19 00:17:47.934214": train features shape: (22452, 79)
# "2018-06-19 00:17:52.266115": preprocesing finished
# "2018-06-19 00:17:52.266213": start training on days [1]
# "2018-06-19 00:17:52.266405": using fit without validation
# "2018-06-19 00:17:52.290029": start predicting on day 3
# "2018-06-19 00:17:52.292445": saveing results
# "2018-06-19 00:17:52.293049": results saved
# "2018-06-19 00:17:52.293506": preprocesing started
# "2018-06-19 00:17:53.793263": train features shape: (22452, 79)
# "2018-06-19 00:17:58.285533": preprocesing finished
# "2018-06-19 00:17:58.285637": start training on days [1]
# "2018-06-19 00:17:58.285655": using fit without validation
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-19 00:17:58.513583": start predicting on day 3
# "2018-06-19 00:17:58.528470": saveing results
# "2018-06-19 00:17:58.529137": results saved
# "2018-06-19 00:17:58.529477": preprocesing started
# "2018-06-19 00:18:00.060981": train features shape: (22452, 79)
# "2018-06-19 00:18:04.501592": preprocesing finished
# "2018-06-19 00:18:04.501680": start training on days [1]
# "2018-06-19 00:18:04.501698": using fit without validation
# "2018-06-19 00:18:10.094912": start predicting on day 3
# "2018-06-19 00:18:10.132744": saveing results
# "2018-06-19 00:18:10.133374": results saved
# "2018-06-19 00:18:10.133718": preprocesing started
# "2018-06-19 00:18:11.676762": train features shape: (22452, 79)
# "2018-06-19 00:18:16.040531": preprocesing finished
# "2018-06-19 00:18:16.040608": start training on days [1]
# "2018-06-19 00:18:16.040707": using fit without validation
# "2018-06-19 00:18:27.530971": start predicting on day 3
# "2018-06-19 00:18:27.564707": saveing results
# "2018-06-19 00:18:27.565306": results saved
# "2018-06-19 00:18:27.565778": preprocesing started
# "2018-06-19 00:18:28.980235": train features shape: (22452, 79)
# "2018-06-19 00:18:32.975492": preprocesing finished
# "2018-06-19 00:18:32.975566": start training on days [1]
# "2018-06-19 00:18:32.975717": using fit without validation
# "2018-06-19 00:18:45.330405": start predicting on day 3
# "2018-06-19 00:18:45.367329": saveing results
# "2018-06-19 00:18:45.367876": results saved
# "2018-06-19 00:18:45.368334": preprocesing started
# "2018-06-19 00:18:46.659966": train features shape: (22452, 30)
# "2018-06-19 00:18:50.515356": preprocesing finished
# "2018-06-19 00:18:50.515450": start training on days [1]
# "2018-06-19 00:18:50.515468": using fit without validation
# "2018-06-19 00:18:54.155050": start predicting on day 3
# "2018-06-19 00:18:54.156084": saveing results
# "2018-06-19 00:18:54.156577": results saved
# "2018-06-19 00:18:54.156637": preprocesing started
# "2018-06-19 00:18:55.491164": train features shape: (22452, 30)
# "2018-06-19 00:18:59.568283": preprocesing finished
# "2018-06-19 00:18:59.568356": start training on days [1]
# "2018-06-19 00:18:59.568484": using fit without validation
# "2018-06-19 00:19:02.148227": start predicting on day 3
# "2018-06-19 00:19:02.149229": saveing results
# "2018-06-19 00:19:02.149737": results saved
# "2018-06-19 00:19:02.149829": preprocesing started
# "2018-06-19 00:19:03.424212": train features shape: (22452, 19)
# "2018-06-19 00:19:07.215147": preprocesing finished
# "2018-06-19 00:19:07.215219": start training on days [1]
# "2018-06-19 00:19:07.215312": using fit without validation
# "2018-06-19 00:19:09.844760": start predicting on day 3
# "2018-06-19 00:19:09.845475": saveing results
# "2018-06-19 00:19:09.845927": results saved
# "2018-06-19 00:19:09.846003": preprocesing started
# "2018-06-19 00:19:11.176017": train features shape: (22452, 30)
# "2018-06-19 00:19:15.292330": preprocesing finished
# "2018-06-19 00:19:15.292430": start training on days [1]
# "2018-06-19 00:19:15.292448": using fit without validation
# "2018-06-19 00:19:15.308877": start predicting on day 3
# "2018-06-19 00:19:15.309763": saveing results
# "2018-06-19 00:19:15.310262": results saved
# "2018-06-19 00:19:15.310363": preprocesing started
# "2018-06-19 00:19:16.625349": train features shape: (22452, 30)
# "2018-06-19 00:19:20.739430": preprocesing finished
# "2018-06-19 00:19:20.739518": start training on days [1]
# "2018-06-19 00:19:20.739617": using fit without validation
# "2018-06-19 00:19:20.758867": start predicting on day 3
# "2018-06-19 00:19:20.760090": saveing results
# "2018-06-19 00:19:20.760557": results saved
# "2018-06-19 00:19:20.760683": preprocesing started
# "2018-06-19 00:19:22.245779": train features shape: (22452, 19)
# "2018-06-19 00:19:26.612507": preprocesing finished
# "2018-06-19 00:19:26.612602": start training on days [1]
# "2018-06-19 00:19:26.612717": using fit without validation
# "2018-06-19 00:19:26.626164": start predicting on day 3
# "2018-06-19 00:19:26.626841": saveing results
# "2018-06-19 00:19:26.627380": results saved
# "2018-06-19 00:19:26.627493": preprocesing started
# "2018-06-19 00:19:28.198520": train features shape: (22452, 30)
# "2018-06-19 00:19:32.776956": preprocesing finished
# "2018-06-19 00:19:32.777044": start training on days [1]
# "2018-06-19 00:19:32.777199": using fit without validation
# "2018-06-19 00:19:32.785219": start predicting on day 3
# "2018-06-19 00:19:32.786095": saveing results
# "2018-06-19 00:19:32.786693": results saved
# "2018-06-19 00:19:32.786761": preprocesing started
# "2018-06-19 00:19:34.297459": train features shape: (22452, 30)
# "2018-06-19 00:19:38.507528": preprocesing finished
# "2018-06-19 00:19:38.507607": start training on days [1]
# "2018-06-19 00:19:38.507709": using fit without validation
# "2018-06-19 00:19:38.516902": start predicting on day 3
# "2018-06-19 00:19:38.517793": saveing results
# "2018-06-19 00:19:38.518376": results saved
# "2018-06-19 00:19:38.518500": preprocesing started
# "2018-06-19 00:19:40.005916": train features shape: (22452, 19)
# "2018-06-19 00:19:44.136907": preprocesing finished
# "2018-06-19 00:19:44.137009": start training on days [1]
# "2018-06-19 00:19:44.137027": using fit without validation
# "2018-06-19 00:19:44.142616": start predicting on day 3
# "2018-06-19 00:19:44.143309": saveing results
# "2018-06-19 00:19:44.143823": results saved
# "2018-06-19 00:19:44.143930": preprocesing started
# "2018-06-19 00:19:45.522752": train features shape: (22452, 30)
# "2018-06-19 00:19:49.410659": preprocesing finished
# "2018-06-19 00:19:49.410751": start training on days [1]
# "2018-06-19 00:19:49.410916": using fit without validation
# "2018-06-19 00:19:49.498009": start predicting on day 3
# "2018-06-19 00:19:49.502977": saveing results
# "2018-06-19 00:19:49.503500": results saved
# "2018-06-19 00:19:49.503608": preprocesing started
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-19 00:19:50.809790": train features shape: (22452, 30)
# "2018-06-19 00:19:54.718448": preprocesing finished
# "2018-06-19 00:19:54.718553": start training on days [1]
# "2018-06-19 00:19:54.718572": using fit without validation
# "2018-06-19 00:19:54.806044": start predicting on day 3
# "2018-06-19 00:19:54.810953": saveing results
# "2018-06-19 00:19:54.811478": results saved
# "2018-06-19 00:19:54.811563": preprocesing started
# "2018-06-19 00:19:56.138897": train features shape: (22452, 19)
# "2018-06-19 00:19:59.983960": preprocesing finished
# "2018-06-19 00:19:59.984050": start training on days [1]
# "2018-06-19 00:19:59.984085": using fit without validation
# "2018-06-19 00:20:00.057701": start predicting on day 3
# "2018-06-19 00:20:00.061533": saveing results
# "2018-06-19 00:20:00.062090": results saved
# "2018-06-19 00:20:00.062220": preprocesing started
# "2018-06-19 00:20:01.355801": train features shape: (22452, 30)
# "2018-06-19 00:20:05.249285": preprocesing finished
# "2018-06-19 00:20:05.249358": start training on days [1]
# "2018-06-19 00:20:05.249460": using fit without validation
# "2018-06-19 00:20:06.313779": start predicting on day 3
# "2018-06-19 00:20:06.325407": saveing results
# "2018-06-19 00:20:06.325975": results saved
# "2018-06-19 00:20:06.326086": preprocesing started
# "2018-06-19 00:20:07.704318": train features shape: (22452, 30)
# "2018-06-19 00:20:11.655722": preprocesing finished
# "2018-06-19 00:20:11.655809": start training on days [1]
# "2018-06-19 00:20:11.655946": using fit without validation
# "2018-06-19 00:20:16.194959": start predicting on day 3
# "2018-06-19 00:20:16.259721": saveing results
# "2018-06-19 00:20:16.260408": results saved
# "2018-06-19 00:20:16.261359": preprocesing started
# "2018-06-19 00:20:17.598187": train features shape: (22452, 19)
# "2018-06-19 00:20:21.418715": preprocesing finished
# "2018-06-19 00:20:21.418814": start training on days [1]
# "2018-06-19 00:20:21.418831": using fit without validation
# "2018-06-19 00:20:22.857615": start predicting on day 3
# "2018-06-19 00:20:22.891235": saveing results
# "2018-06-19 00:20:22.891800": results saved
# "2018-06-19 00:20:22.891924": preprocesing started
# "2018-06-19 00:20:24.228987": train features shape: (22452, 30)
# "2018-06-19 00:20:28.295704": preprocesing finished
# "2018-06-19 00:20:28.295789": start training on days [1]
# "2018-06-19 00:20:28.295916": using fit without validation
# "2018-06-19 00:20:32.099771": start predicting on day 3
# "2018-06-19 00:20:32.132390": saveing results
# "2018-06-19 00:20:32.133204": results saved
# "2018-06-19 00:20:32.133442": preprocesing started
# "2018-06-19 00:20:33.661767": train features shape: (22452, 30)
# "2018-06-19 00:20:37.998959": preprocesing finished
# "2018-06-19 00:20:37.999048": start training on days [1]
# "2018-06-19 00:20:37.999080": using fit without validation
# "2018-06-19 00:20:43.316501": start predicting on day 3
# "2018-06-19 00:20:43.348485": saveing results
# "2018-06-19 00:20:43.349322": results saved
# "2018-06-19 00:20:43.349516": preprocesing started
# "2018-06-19 00:20:45.336441": train features shape: (22452, 19)
# "2018-06-19 00:20:49.591914": preprocesing finished
# "2018-06-19 00:20:49.591996": start training on days [1]
# "2018-06-19 00:20:49.592178": using fit without validation
# "2018-06-19 00:20:52.024852": start predicting on day 3
# "2018-06-19 00:20:52.052863": saveing results
# "2018-06-19 00:20:52.053723": results saved
# "2018-06-19 00:20:52.053923": preprocesing started
# "2018-06-19 00:20:53.527773": train features shape: (22452, 30)
# "2018-06-19 00:20:57.686917": preprocesing finished
# "2018-06-19 00:20:57.687003": start training on days [1]
# "2018-06-19 00:20:57.687098": using fit without validation
# "2018-06-19 00:21:01.359297": start predicting on day 3
# "2018-06-19 00:21:01.395188": saveing results
# "2018-06-19 00:21:01.395727": results saved
# "2018-06-19 00:21:01.395834": preprocesing started
# "2018-06-19 00:21:02.774438": train features shape: (22452, 30)
# "2018-06-19 00:21:06.912438": preprocesing finished
# "2018-06-19 00:21:06.912537": start training on days [1]
# "2018-06-19 00:21:06.912634": using fit without validation
# "2018-06-19 00:21:12.239435": start predicting on day 3
# "2018-06-19 00:21:12.276401": saveing results
# "2018-06-19 00:21:12.276924": results saved
# "2018-06-19 00:21:12.277000": preprocesing started
# "2018-06-19 00:21:13.564439": train features shape: (22452, 19)
# "2018-06-19 00:21:17.587639": preprocesing finished
# "2018-06-19 00:21:17.587744": start training on days [1]
# "2018-06-19 00:21:17.587846": using fit without validation
# "2018-06-19 00:21:20.253907": start predicting on day 3
# "2018-06-19 00:21:20.289979": saveing results
# "2018-06-19 00:21:20.290501": results saved
# "2018-06-19 00:21:20.290597": preprocesing started
# "2018-06-19 00:21:21.824438": train features shape: (22452, 79)
# "2018-06-19 00:21:26.078140": preprocesing finished
# "2018-06-19 00:21:26.078315": start training on days [1]
# "2018-06-19 00:21:26.078373": using fit without validation
# "2018-06-19 00:21:32.918932": start predicting on day 3
# "2018-06-19 00:21:32.921666": saveing results
# "2018-06-19 00:21:32.922213": results saved
# "2018-06-19 00:21:32.922976": preprocesing started
# "2018-06-19 00:21:34.565155": train features shape: (22452, 79)
# "2018-06-19 00:21:38.928457": preprocesing finished
# "2018-06-19 00:21:38.928543": start training on days [1]
# "2018-06-19 00:21:38.928576": using fit without validation
# "2018-06-19 00:21:39.022528": start predicting on day 3
# "2018-06-19 00:21:39.024772": saveing results
# "2018-06-19 00:21:39.025320": results saved
# "2018-06-19 00:21:39.025619": preprocesing started
# "2018-06-19 00:21:40.568281": train features shape: (22452, 79)
# "2018-06-19 00:21:44.693657": preprocesing finished
# "2018-06-19 00:21:44.693743": start training on days [1]
# "2018-06-19 00:21:44.693853": using fit without validation
# "2018-06-19 00:21:44.717855": start predicting on day 3
# "2018-06-19 00:21:44.720120": saveing results
# "2018-06-19 00:21:44.720711": results saved
# "2018-06-19 00:21:44.721018": preprocesing started
# "2018-06-19 00:21:46.214636": train features shape: (22452, 79)
# "2018-06-19 00:21:50.276567": preprocesing finished
# "2018-06-19 00:21:50.276653": start training on days [1]
# "2018-06-19 00:21:50.276674": using fit without validation
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-19 00:21:50.517025": start predicting on day 3
# "2018-06-19 00:21:50.533306": saveing results
# "2018-06-19 00:21:50.533859": results saved
# "2018-06-19 00:21:50.534176": preprocesing started
# "2018-06-19 00:21:52.056929": train features shape: (22452, 79)
# "2018-06-19 00:21:56.356909": preprocesing finished
# "2018-06-19 00:21:56.357010": start training on days [1]
# "2018-06-19 00:21:56.357027": using fit without validation
# "2018-06-19 00:22:08.457852": start predicting on day 3
# "2018-06-19 00:22:08.553371": saveing results
# "2018-06-19 00:22:08.554059": results saved
# "2018-06-19 00:22:08.554527": preprocesing started
# "2018-06-19 00:22:10.256811": train features shape: (22452, 79)
# "2018-06-19 00:22:14.704486": preprocesing finished
# "2018-06-19 00:22:14.704564": start training on days [1]
# "2018-06-19 00:22:14.704685": using fit without validation
# "2018-06-19 00:22:28.440282": start predicting on day 3
# "2018-06-19 00:22:28.480287": saveing results
# "2018-06-19 00:22:28.481124": results saved
# "2018-06-19 00:22:28.481608": preprocesing started
# "2018-06-19 00:22:30.023195": train features shape: (22452, 79)
# "2018-06-19 00:22:34.439312": preprocesing finished
# "2018-06-19 00:22:34.439403": start training on days [1]
# "2018-06-19 00:22:34.439438": using fit without validation
# "2018-06-19 00:22:47.668738": start predicting on day 3
# "2018-06-19 00:22:47.707858": saveing results
# "2018-06-19 00:22:47.708554": results saved
