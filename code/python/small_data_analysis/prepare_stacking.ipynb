# %%
import numpy as np
import shutil
import os

from argparse import Namespace
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.svm import LinearSVR
from sklearn.linear_model import Lars, ElasticNet, Perceptron, SGDRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor


import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *

FEATURES_NUMBER = 79


# %reload_ext autoreload
# %autoreload 2

# %%
def get_stacking_metric(i):
    args = Namespace()
    args.verbose = False
    args.data_folder = "../../../data/best_features_days_data/"
    args.out_folder = "res"
    args.type = "binary_regression"
    args.metric_folder = "metrics"
    args.additional_features = None
    args.train_days = [1]
    args.validation_day = None
    args.test_days = [2, 6]

    model_constructors = [
        lambda verbose: LinearSVR(),
        lambda verbose: Lars(),
        lambda verbose: ElasticNet(),
        lambda verbose: Perceptron(),
        lambda verbose: AdaBoostRegressor(),
        lambda verbose: GradientBoostingRegressor(),
        lambda verbose: RandomForestRegressor()
    ]
    model_names = [
        "svr",
        "lars",
        "elastic",
        "preceptron",
        "ada_boost",
        "gradient_boost",
        "random_forest"
    ]

    def clear(folder):
        if os.path.exists(folder):
            shutil.rmtree(folder)
        os.mkdir(folder)
    
    out_folder = args.out_folder

    args.step = 30
    for model_name, model_constructor in zip(model_names, model_constructors):
        args.first_feature = 0
        args.last_feature = args.step
        args.model_constructor = model_constructor
        while args.first_feature < FEATURES_NUMBER:
            args.last_feature = min(args.last_feature, FEATURES_NUMBER)
            args.out_folder = os.path.join(
                out_folder,
                str(i) + '_' + model_name + "_features_from_{}_to_{}".format(
                    args.first_feature, args.last_feature
                )
            )
            if not os.path.exists(args.out_folder):
                clear(args.out_folder)
                calculate_predictions(args)
            args.first_feature += args.step
            args.last_feature += args.step

    args.first_feature = 0
    args.last_feature = -1
            
    for model_name, model_constructor in zip(model_names, model_constructors):
        args.out_folder = os.path.join(out_folder, str(i) + '_' + model_name + "_all_features")
        args.model_constructor = model_constructor
        if not os.path.exists(args.out_folder):
            clear(args.out_folder)
            calculate_predictions(args)

# %%
for i in range(30):
    get_stacking_metric(i)
# Out:
# "2018-06-18 18:36:28.667862": preprocesing started
# "2018-06-18 18:36:37.259686": train features shape: (22452, 30)
# "2018-06-18 18:36:37.259811": preprocesing finished
# "2018-06-18 18:36:37.259834": start training on days [1]
# "2018-06-18 18:36:37.259863": using fit without validation
# "2018-06-18 18:36:37.276825": start predicting on day 2
# "2018-06-18 18:36:37.278118": saveing results
# "2018-06-18 18:36:37.278823": results saved
# "2018-06-18 18:36:37.278856": start predicting on day 6
# "2018-06-18 18:36:37.279710": saveing results
# "2018-06-18 18:36:37.280185": results saved
# "2018-06-18 18:36:37.280421": preprocesing started
# "2018-06-18 18:36:45.849768": train features shape: (22452, 30)
# "2018-06-18 18:36:45.849856": preprocesing finished
# "2018-06-18 18:36:45.849880": start training on days [1]
# "2018-06-18 18:36:45.849986": using fit without validation
# "2018-06-18 18:36:45.865159": start predicting on day 2
# "2018-06-18 18:36:45.866140": saveing results
# "2018-06-18 18:36:45.866621": results saved
# "2018-06-18 18:36:45.866681": start predicting on day 6
# "2018-06-18 18:36:45.868050": saveing results
# "2018-06-18 18:36:45.868643": results saved
# "2018-06-18 18:36:45.868854": preprocesing started
# "2018-06-18 18:36:54.458732": train features shape: (22452, 19)
# "2018-06-18 18:36:54.458821": preprocesing finished
# "2018-06-18 18:36:54.458858": start training on days [1]
# "2018-06-18 18:36:54.458872": using fit without validation
# "2018-06-18 18:36:54.467730": start predicting on day 2
# "2018-06-18 18:36:54.468479": saveing results
# "2018-06-18 18:36:54.468978": results saved
# "2018-06-18 18:36:54.469028": start predicting on day 6
# "2018-06-18 18:36:54.469706": saveing results
# "2018-06-18 18:36:54.470146": results saved
# "2018-06-18 18:36:54.470359": preprocesing started
# "2018-06-18 18:37:03.073149": train features shape: (22452, 30)
# "2018-06-18 18:37:03.073237": preprocesing finished
# "2018-06-18 18:37:03.073350": start training on days [1]
# "2018-06-18 18:37:03.073367": using fit without validation
# "2018-06-18 18:37:03.080781": start predicting on day 2
# "2018-06-18 18:37:03.082055": saveing results
# "2018-06-18 18:37:03.082612": results saved
# "2018-06-18 18:37:03.082664": start predicting on day 6
# "2018-06-18 18:37:03.083787": saveing results
# "2018-06-18 18:37:03.084625": results saved
# "2018-06-18 18:37:03.085045": preprocesing started
# "2018-06-18 18:37:11.638945": train features shape: (22452, 30)
# "2018-06-18 18:37:11.639035": preprocesing finished
# "2018-06-18 18:37:11.639070": start training on days [1]
# "2018-06-18 18:37:11.639085": using fit without validation
# "2018-06-18 18:37:11.646564": start predicting on day 2
# "2018-06-18 18:37:11.647609": saveing results
# "2018-06-18 18:37:11.648104": results saved
# "2018-06-18 18:37:11.648153": start predicting on day 6
# "2018-06-18 18:37:11.649423": saveing results
# "2018-06-18 18:37:11.649981": results saved
# "2018-06-18 18:37:11.650202": preprocesing started
# "2018-06-18 18:37:20.037946": train features shape: (22452, 19)
# "2018-06-18 18:37:20.038042": preprocesing finished
# "2018-06-18 18:37:20.038158": start training on days [1]
# "2018-06-18 18:37:20.038174": using fit without validation
# "2018-06-18 18:37:20.042821": start predicting on day 2
# "2018-06-18 18:37:20.043612": saveing results
# "2018-06-18 18:37:20.044140": results saved
# "2018-06-18 18:37:20.044191": start predicting on day 6
# "2018-06-18 18:37:20.044959": saveing results
# "2018-06-18 18:37:20.045419": results saved
# "2018-06-18 18:37:20.045573": preprocesing started
# "2018-06-18 18:37:28.709337": train features shape: (22452, 30)
# "2018-06-18 18:37:28.709643": preprocesing finished
# "2018-06-18 18:37:28.709762": start training on days [1]
# "2018-06-18 18:37:28.709857": using fit without validation
# "2018-06-18 18:37:28.803861": start predicting on day 2
# "2018-06-18 18:37:28.809212": saveing results
# "2018-06-18 18:37:28.809856": results saved
# "2018-06-18 18:37:28.809932": start predicting on day 6
# "2018-06-18 18:37:28.815416": saveing results
# "2018-06-18 18:37:28.815866": results saved
# "2018-06-18 18:37:28.816062": preprocesing started
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-18 18:37:37.422712": train features shape: (22452, 30)
# "2018-06-18 18:37:37.422798": preprocesing finished
# "2018-06-18 18:37:37.422833": start training on days [1]
# "2018-06-18 18:37:37.422926": using fit without validation
# "2018-06-18 18:37:37.528653": start predicting on day 2
# "2018-06-18 18:37:37.534674": saveing results
# "2018-06-18 18:37:37.535250": results saved
# "2018-06-18 18:37:37.535300": start predicting on day 6
# "2018-06-18 18:37:37.540684": saveing results
# "2018-06-18 18:37:37.541161": results saved
# "2018-06-18 18:37:37.541365": preprocesing started
# "2018-06-18 18:37:45.964475": train features shape: (22452, 19)
# "2018-06-18 18:37:45.964594": preprocesing finished
# "2018-06-18 18:37:45.964611": start training on days [1]
# "2018-06-18 18:37:45.964625": using fit without validation
# "2018-06-18 18:37:46.035211": start predicting on day 2
# "2018-06-18 18:37:46.039474": saveing results
# "2018-06-18 18:37:46.040065": results saved
# "2018-06-18 18:37:46.040118": start predicting on day 6
# "2018-06-18 18:37:46.044343": saveing results
# "2018-06-18 18:37:46.044887": results saved
# "2018-06-18 18:37:46.045141": preprocesing started
# "2018-06-18 18:37:54.632566": train features shape: (22452, 30)
# "2018-06-18 18:37:54.632652": preprocesing finished
# "2018-06-18 18:37:54.632672": start training on days [1]
# "2018-06-18 18:37:54.632704": using fit without validation
# "2018-06-18 18:37:55.577853": start predicting on day 2
# "2018-06-18 18:37:55.590321": saveing results
# "2018-06-18 18:37:55.591238": results saved
# "2018-06-18 18:37:55.591295": start predicting on day 6
# "2018-06-18 18:37:55.604501": saveing results
# "2018-06-18 18:37:55.605019": results saved
# "2018-06-18 18:37:55.605268": preprocesing started
# "2018-06-18 18:38:04.200097": train features shape: (22452, 30)
# "2018-06-18 18:38:04.200183": preprocesing finished
# "2018-06-18 18:38:04.200219": start training on days [1]
# "2018-06-18 18:38:04.200234": using fit without validation
# "2018-06-18 18:38:09.423552": start predicting on day 2
# "2018-06-18 18:38:09.498325": saveing results
# "2018-06-18 18:38:09.498989": results saved
# "2018-06-18 18:38:09.499041": start predicting on day 6
# "2018-06-18 18:38:09.576662": saveing results
# "2018-06-18 18:38:09.577344": results saved
# "2018-06-18 18:38:09.577598": preprocesing started
# "2018-06-18 18:38:18.111591": train features shape: (22452, 19)
# "2018-06-18 18:38:18.111685": preprocesing finished
# "2018-06-18 18:38:18.111707": start training on days [1]
# "2018-06-18 18:38:18.111736": using fit without validation
# "2018-06-18 18:38:19.297879": start predicting on day 2
# "2018-06-18 18:38:19.324457": saveing results
# "2018-06-18 18:38:19.325048": results saved
# "2018-06-18 18:38:19.325099": start predicting on day 6
# "2018-06-18 18:38:19.351792": saveing results
# "2018-06-18 18:38:19.352535": results saved
# "2018-06-18 18:38:19.352784": preprocesing started
# "2018-06-18 18:38:28.046193": train features shape: (22452, 30)
# "2018-06-18 18:38:28.046300": preprocesing finished
# "2018-06-18 18:38:28.046331": start training on days [1]
# "2018-06-18 18:38:28.046348": using fit without validation
# "2018-06-18 18:38:31.224701": start predicting on day 2
# "2018-06-18 18:38:31.252156": saveing results
# "2018-06-18 18:38:31.252764": results saved
# "2018-06-18 18:38:31.252816": start predicting on day 6
# "2018-06-18 18:38:31.279403": saveing results
# "2018-06-18 18:38:31.279996": results saved
# "2018-06-18 18:38:31.280380": preprocesing started
# "2018-06-18 18:38:39.452271": train features shape: (22452, 30)
# "2018-06-18 18:38:39.452356": preprocesing finished
# "2018-06-18 18:38:39.452389": start training on days [1]
# "2018-06-18 18:38:39.452482": using fit without validation
# "2018-06-18 18:38:43.819545": start predicting on day 2
# "2018-06-18 18:38:43.844224": saveing results
# "2018-06-18 18:38:43.844743": results saved
# "2018-06-18 18:38:43.844793": start predicting on day 6
# "2018-06-18 18:38:43.869660": saveing results
# "2018-06-18 18:38:43.870132": results saved
# "2018-06-18 18:38:43.870409": preprocesing started
# "2018-06-18 18:38:51.963802": train features shape: (22452, 19)
# "2018-06-18 18:38:51.963891": preprocesing finished
# "2018-06-18 18:38:51.964004": start training on days [1]
# "2018-06-18 18:38:51.964020": using fit without validation
# "2018-06-18 18:38:54.035342": start predicting on day 2
# "2018-06-18 18:38:54.060715": saveing results
# "2018-06-18 18:38:54.061294": results saved
# "2018-06-18 18:38:54.061333": start predicting on day 6
# "2018-06-18 18:38:54.086889": saveing results
# "2018-06-18 18:38:54.087456": results saved
# "2018-06-18 18:38:54.087680": preprocesing started
# "2018-06-18 18:39:02.272308": train features shape: (22452, 30)
# "2018-06-18 18:39:02.272392": preprocesing finished
# "2018-06-18 18:39:02.272554": start training on days [1]
# "2018-06-18 18:39:02.272570": using fit without validation
# "2018-06-18 18:39:05.606748": start predicting on day 2
# "2018-06-18 18:39:05.643121": saveing results
# "2018-06-18 18:39:05.643668": results saved
# "2018-06-18 18:39:05.643718": start predicting on day 6
# "2018-06-18 18:39:05.680789": saveing results
# "2018-06-18 18:39:05.681312": results saved
# "2018-06-18 18:39:05.681591": preprocesing started
# "2018-06-18 18:39:13.830054": train features shape: (22452, 30)
# "2018-06-18 18:39:13.830149": preprocesing finished
# "2018-06-18 18:39:13.830173": start training on days [1]
# "2018-06-18 18:39:13.830280": using fit without validation
# "2018-06-18 18:39:18.872615": start predicting on day 2
# "2018-06-18 18:39:18.910068": saveing results
# "2018-06-18 18:39:18.910645": results saved
# "2018-06-18 18:39:18.910702": start predicting on day 6
# "2018-06-18 18:39:18.948567": saveing results
# "2018-06-18 18:39:18.949092": results saved
# "2018-06-18 18:39:18.949273": preprocesing started
# "2018-06-18 18:39:27.014330": train features shape: (22452, 19)
# "2018-06-18 18:39:27.014432": preprocesing finished
# "2018-06-18 18:39:27.014583": start training on days [1]
# "2018-06-18 18:39:27.014600": using fit without validation
# "2018-06-18 18:39:29.357545": start predicting on day 2
# "2018-06-18 18:39:29.395485": saveing results
# "2018-06-18 18:39:29.396017": results saved
# "2018-06-18 18:39:29.396066": start predicting on day 6
# "2018-06-18 18:39:29.434387": saveing results
# "2018-06-18 18:39:29.434926": results saved
# "2018-06-18 18:39:29.435290": preprocesing started
# "2018-06-18 18:39:37.641811": train features shape: (22452, 30)
# "2018-06-18 18:39:37.641893": preprocesing finished
# "2018-06-18 18:39:37.642057": start training on days [1]
# "2018-06-18 18:39:37.642073": using fit without validation
# "2018-06-18 18:39:37.656887": start predicting on day 2
# "2018-06-18 18:39:37.657907": saveing results
# "2018-06-18 18:39:37.658425": results saved
# "2018-06-18 18:39:37.658474": start predicting on day 6
# "2018-06-18 18:39:37.659460": saveing results
# "2018-06-18 18:39:37.659901": results saved
# "2018-06-18 18:39:37.660080": preprocesing started
# "2018-06-18 18:39:45.748769": train features shape: (22452, 30)
# "2018-06-18 18:39:45.748852": preprocesing finished
# "2018-06-18 18:39:45.749029": start training on days [1]
# "2018-06-18 18:39:45.749045": using fit without validation
# "2018-06-18 18:39:45.763048": start predicting on day 2
# "2018-06-18 18:39:45.764014": saveing results
# "2018-06-18 18:39:45.764510": results saved
# "2018-06-18 18:39:45.764559": start predicting on day 6
# "2018-06-18 18:39:45.765485": saveing results
# "2018-06-18 18:39:45.765926": results saved
# "2018-06-18 18:39:45.766104": preprocesing started
# "2018-06-18 18:39:53.833109": train features shape: (22452, 19)
# "2018-06-18 18:39:53.833207": preprocesing finished
# "2018-06-18 18:39:53.833229": start training on days [1]
# "2018-06-18 18:39:53.833354": using fit without validation
# "2018-06-18 18:39:53.841119": start predicting on day 2
# "2018-06-18 18:39:53.841848": saveing results
# "2018-06-18 18:39:53.842340": results saved
# "2018-06-18 18:39:53.842390": start predicting on day 6
# "2018-06-18 18:39:53.842974": saveing results
# "2018-06-18 18:39:53.843388": results saved
# "2018-06-18 18:39:53.843612": preprocesing started
# "2018-06-18 18:40:02.010036": train features shape: (22452, 30)
# "2018-06-18 18:40:02.010122": preprocesing finished
# "2018-06-18 18:40:02.010289": start training on days [1]
# "2018-06-18 18:40:02.010305": using fit without validation
# "2018-06-18 18:40:02.016977": start predicting on day 2
# "2018-06-18 18:40:02.017956": saveing results
# "2018-06-18 18:40:02.018453": results saved
# "2018-06-18 18:40:02.018483": start predicting on day 6
# "2018-06-18 18:40:02.019384": saveing results
# "2018-06-18 18:40:02.019807": results saved
# "2018-06-18 18:40:02.020030": preprocesing started
# "2018-06-18 18:40:10.221050": train features shape: (22452, 30)
# "2018-06-18 18:40:10.221149": preprocesing finished
# "2018-06-18 18:40:10.221247": start training on days [1]
# "2018-06-18 18:40:10.221332": using fit without validation
# "2018-06-18 18:40:10.228122": start predicting on day 2
# "2018-06-18 18:40:10.229141": saveing results
# "2018-06-18 18:40:10.229641": results saved
# "2018-06-18 18:40:10.229691": start predicting on day 6
# "2018-06-18 18:40:10.230685": saveing results
# "2018-06-18 18:40:10.231122": results saved
# "2018-06-18 18:40:10.231313": preprocesing started
# "2018-06-18 18:40:18.256688": train features shape: (22452, 19)
# "2018-06-18 18:40:18.256774": preprocesing finished
# "2018-06-18 18:40:18.256885": start training on days [1]
# "2018-06-18 18:40:18.256900": using fit without validation
# "2018-06-18 18:40:18.260945": start predicting on day 2
# "2018-06-18 18:40:18.261699": saveing results
# "2018-06-18 18:40:18.262178": results saved
# "2018-06-18 18:40:18.262234": start predicting on day 6
# "2018-06-18 18:40:18.262869": saveing results
# "2018-06-18 18:40:18.263320": results saved
# "2018-06-18 18:40:18.263543": preprocesing started
# "2018-06-18 18:40:26.432300": train features shape: (22452, 30)
# "2018-06-18 18:40:26.432385": preprocesing finished
# "2018-06-18 18:40:26.432552": start training on days [1]
# "2018-06-18 18:40:26.432569": using fit without validation
# "2018-06-18 18:40:26.522828": start predicting on day 2
# "2018-06-18 18:40:26.528306": saveing results
# "2018-06-18 18:40:26.528884": results saved
# "2018-06-18 18:40:26.528932": start predicting on day 6
# "2018-06-18 18:40:26.534387": saveing results
# "2018-06-18 18:40:26.534863": results saved
# "2018-06-18 18:40:26.535135": preprocesing started
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-18 18:40:34.678101": train features shape: (22452, 30)
# "2018-06-18 18:40:34.678186": preprocesing finished
# "2018-06-18 18:40:34.678209": start training on days [1]
# "2018-06-18 18:40:34.678314": using fit without validation
# "2018-06-18 18:40:34.770382": start predicting on day 2
# "2018-06-18 18:40:34.775900": saveing results
# "2018-06-18 18:40:34.776417": results saved
# "2018-06-18 18:40:34.776467": start predicting on day 6
# "2018-06-18 18:40:34.781935": saveing results
# "2018-06-18 18:40:34.782382": results saved
# "2018-06-18 18:40:34.782580": preprocesing started
# "2018-06-18 18:40:42.800954": train features shape: (22452, 19)
# "2018-06-18 18:40:42.801040": preprocesing finished
# "2018-06-18 18:40:42.801153": start training on days [1]
# "2018-06-18 18:40:42.801256": using fit without validation
# "2018-06-18 18:40:42.859823": start predicting on day 2
# "2018-06-18 18:40:42.863811": saveing results
# "2018-06-18 18:40:42.864323": results saved
# "2018-06-18 18:40:42.864373": start predicting on day 6
# "2018-06-18 18:40:42.868106": saveing results
# "2018-06-18 18:40:42.868597": results saved
# "2018-06-18 18:40:42.868792": preprocesing started
# "2018-06-18 18:40:51.037552": train features shape: (22452, 30)
# "2018-06-18 18:40:51.037638": preprocesing finished
# "2018-06-18 18:40:51.037824": start training on days [1]
# "2018-06-18 18:40:51.037840": using fit without validation
# "2018-06-18 18:40:52.221796": start predicting on day 2
# "2018-06-18 18:40:52.238169": saveing results
# "2018-06-18 18:40:52.238735": results saved
# "2018-06-18 18:40:52.238785": start predicting on day 6
# "2018-06-18 18:40:52.255347": saveing results
# "2018-06-18 18:40:52.255903": results saved
# "2018-06-18 18:40:52.256112": preprocesing started
# "2018-06-18 18:41:00.405469": train features shape: (22452, 30)
# "2018-06-18 18:41:00.405552": preprocesing finished
# "2018-06-18 18:41:00.405662": start training on days [1]
# "2018-06-18 18:41:00.405677": using fit without validation
# "2018-06-18 18:41:03.557703": start predicting on day 2
# "2018-06-18 18:41:03.593554": saveing results
# "2018-06-18 18:41:03.594125": results saved
# "2018-06-18 18:41:03.594176": start predicting on day 6
# "2018-06-18 18:41:03.629091": saveing results
# "2018-06-18 18:41:03.629671": results saved
# "2018-06-18 18:41:03.629870": preprocesing started
# "2018-06-18 18:41:11.671661": train features shape: (22452, 19)
# "2018-06-18 18:41:11.671747": preprocesing finished
# "2018-06-18 18:41:11.671859": start training on days [1]
# "2018-06-18 18:41:11.671876": using fit without validation
# "2018-06-18 18:41:12.492875": start predicting on day 2
# "2018-06-18 18:41:12.507199": saveing results
# "2018-06-18 18:41:12.507956": results saved
# "2018-06-18 18:41:12.508010": start predicting on day 6
# "2018-06-18 18:41:12.522645": saveing results
# "2018-06-18 18:41:12.523205": results saved
# "2018-06-18 18:41:12.523460": preprocesing started
# "2018-06-18 18:41:20.644300": train features shape: (22452, 30)
# "2018-06-18 18:41:20.644386": preprocesing finished
# "2018-06-18 18:41:20.644514": start training on days [1]
# "2018-06-18 18:41:20.644536": using fit without validation
# "2018-06-18 18:41:23.813204": start predicting on day 2
# "2018-06-18 18:41:23.839988": saveing results
# "2018-06-18 18:41:23.840511": results saved
# "2018-06-18 18:41:23.840567": start predicting on day 6
# "2018-06-18 18:41:23.867244": saveing results
# "2018-06-18 18:41:23.867805": results saved
# "2018-06-18 18:41:23.868043": preprocesing started
# "2018-06-18 18:41:32.049880": train features shape: (22452, 30)
# "2018-06-18 18:41:32.049953": preprocesing finished
# "2018-06-18 18:41:32.049975": start training on days [1]
# "2018-06-18 18:41:32.050088": using fit without validation
# "2018-06-18 18:41:36.453164": start predicting on day 2
# "2018-06-18 18:41:36.477852": saveing results
# "2018-06-18 18:41:36.478368": results saved
# "2018-06-18 18:41:36.478419": start predicting on day 6
# "2018-06-18 18:41:36.503171": saveing results
# "2018-06-18 18:41:36.503640": results saved
# "2018-06-18 18:41:36.503914": preprocesing started
# "2018-06-18 18:41:44.600340": train features shape: (22452, 19)
# "2018-06-18 18:41:44.600429": preprocesing finished
# "2018-06-18 18:41:44.600542": start training on days [1]
# "2018-06-18 18:41:44.600558": using fit without validation
# "2018-06-18 18:41:46.653274": start predicting on day 2
# "2018-06-18 18:41:46.677802": saveing results
# "2018-06-18 18:41:46.678347": results saved
# "2018-06-18 18:41:46.678397": start predicting on day 6
# "2018-06-18 18:41:46.702484": saveing results
# "2018-06-18 18:41:46.703052": results saved
# "2018-06-18 18:41:46.703293": preprocesing started
# "2018-06-18 18:41:54.865017": train features shape: (22452, 30)
# "2018-06-18 18:41:54.865115": preprocesing finished
# "2018-06-18 18:41:54.865368": start training on days [1]
# "2018-06-18 18:41:54.865392": using fit without validation
# "2018-06-18 18:41:58.194003": start predicting on day 2
# "2018-06-18 18:41:58.230574": saveing results
# "2018-06-18 18:41:58.231141": results saved
# "2018-06-18 18:41:58.231186": start predicting on day 6
# "2018-06-18 18:41:58.268042": saveing results
# "2018-06-18 18:41:58.268694": results saved
# "2018-06-18 18:41:58.268937": preprocesing started
# "2018-06-18 18:42:07.205173": train features shape: (22452, 30)
# "2018-06-18 18:42:07.205288": preprocesing finished
# "2018-06-18 18:42:07.205511": start training on days [1]
# "2018-06-18 18:42:07.205576": using fit without validation
# "2018-06-18 18:42:12.792978": start predicting on day 2
# "2018-06-18 18:42:12.834439": saveing results
# "2018-06-18 18:42:12.834961": results saved
# "2018-06-18 18:42:12.834995": start predicting on day 6
# "2018-06-18 18:42:12.876402": saveing results
# "2018-06-18 18:42:12.876962": results saved
# "2018-06-18 18:42:12.877260": preprocesing started
# "2018-06-18 18:42:21.719993": train features shape: (22452, 19)
# "2018-06-18 18:42:21.720070": preprocesing finished
# "2018-06-18 18:42:21.720169": start training on days [1]
# "2018-06-18 18:42:21.720300": using fit without validation
# "2018-06-18 18:42:24.337323": start predicting on day 2
# "2018-06-18 18:42:24.379012": saveing results
# "2018-06-18 18:42:24.379511": results saved
# "2018-06-18 18:42:24.379546": start predicting on day 6
# "2018-06-18 18:42:24.419669": saveing results
# "2018-06-18 18:42:24.420205": results saved
# "2018-06-18 18:42:24.420507": preprocesing started
# "2018-06-18 18:42:33.291928": train features shape: (22452, 30)
# "2018-06-18 18:42:33.292022": preprocesing finished
# "2018-06-18 18:42:33.292184": start training on days [1]
# "2018-06-18 18:42:33.292253": using fit without validation
# "2018-06-18 18:42:33.308758": start predicting on day 2
# "2018-06-18 18:42:33.309847": saveing results
# "2018-06-18 18:42:33.310436": results saved
# "2018-06-18 18:42:33.310475": start predicting on day 6
# "2018-06-18 18:42:33.311558": saveing results
# "2018-06-18 18:42:33.312001": results saved
# "2018-06-18 18:42:33.312171": preprocesing started
# "2018-06-18 18:42:41.848406": train features shape: (22452, 30)
# "2018-06-18 18:42:41.848505": preprocesing finished
# "2018-06-18 18:42:41.848633": start training on days [1]
# "2018-06-18 18:42:41.848685": using fit without validation
# "2018-06-18 18:42:41.863215": start predicting on day 2
# "2018-06-18 18:42:41.864239": saveing results
# "2018-06-18 18:42:41.864716": results saved
# "2018-06-18 18:42:41.864766": start predicting on day 6
# "2018-06-18 18:42:41.865757": saveing results
# "2018-06-18 18:42:41.866214": results saved
# "2018-06-18 18:42:41.866437": preprocesing started
# "2018-06-18 18:42:49.954342": train features shape: (22452, 19)
# "2018-06-18 18:42:49.954465": preprocesing finished
# "2018-06-18 18:42:49.954505": start training on days [1]
# "2018-06-18 18:42:49.954535": using fit without validation
# "2018-06-18 18:42:49.962334": start predicting on day 2
# "2018-06-18 18:42:49.962994": saveing results
# "2018-06-18 18:42:49.963505": results saved
# "2018-06-18 18:42:49.963566": start predicting on day 6
# "2018-06-18 18:42:49.964205": saveing results
# "2018-06-18 18:42:49.964644": results saved
# "2018-06-18 18:42:49.964794": preprocesing started
# "2018-06-18 18:42:58.248130": train features shape: (22452, 30)
# "2018-06-18 18:42:58.248216": preprocesing finished
# "2018-06-18 18:42:58.248422": start training on days [1]
# "2018-06-18 18:42:58.248439": using fit without validation
# "2018-06-18 18:42:58.255185": start predicting on day 2
# "2018-06-18 18:42:58.256204": saveing results
# "2018-06-18 18:42:58.256738": results saved
# "2018-06-18 18:42:58.256801": start predicting on day 6
# "2018-06-18 18:42:58.257717": saveing results
# "2018-06-18 18:42:58.258182": results saved
# "2018-06-18 18:42:58.258362": preprocesing started
# "2018-06-18 18:43:07.278754": train features shape: (22452, 30)
# "2018-06-18 18:43:07.278856": preprocesing finished
# "2018-06-18 18:43:07.279016": start training on days [1]
# "2018-06-18 18:43:07.279149": using fit without validation
# "2018-06-18 18:43:07.286514": start predicting on day 2
# "2018-06-18 18:43:07.287539": saveing results
# "2018-06-18 18:43:07.288022": results saved
# "2018-06-18 18:43:07.288073": start predicting on day 6
# "2018-06-18 18:43:07.289020": saveing results
# "2018-06-18 18:43:07.289446": results saved
# "2018-06-18 18:43:07.289621": preprocesing started
# "2018-06-18 18:43:16.677457": train features shape: (22452, 19)
# "2018-06-18 18:43:16.677562": preprocesing finished
# "2018-06-18 18:43:16.677696": start training on days [1]
# "2018-06-18 18:43:16.677718": using fit without validation
# "2018-06-18 18:43:16.683105": start predicting on day 2
# "2018-06-18 18:43:16.683840": saveing results
# "2018-06-18 18:43:16.684322": results saved
# "2018-06-18 18:43:16.684371": start predicting on day 6
# "2018-06-18 18:43:16.685346": saveing results
# "2018-06-18 18:43:16.685922": results saved
# "2018-06-18 18:43:16.686133": preprocesing started
# "2018-06-18 18:43:25.482823": train features shape: (22452, 30)
# "2018-06-18 18:43:25.482915": preprocesing finished
# "2018-06-18 18:43:25.482947": start training on days [1]
# "2018-06-18 18:43:25.482978": using fit without validation
# "2018-06-18 18:43:25.598825": start predicting on day 2
# "2018-06-18 18:43:25.604907": saveing results
# "2018-06-18 18:43:25.605539": results saved
# "2018-06-18 18:43:25.605604": start predicting on day 6
# "2018-06-18 18:43:25.611509": saveing results
# "2018-06-18 18:43:25.612171": results saved
# "2018-06-18 18:43:25.612532": preprocesing started
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-18 18:43:34.372266": train features shape: (22452, 30)
# "2018-06-18 18:43:34.372352": preprocesing finished
# "2018-06-18 18:43:34.372519": start training on days [1]
# "2018-06-18 18:43:34.372535": using fit without validation
# "2018-06-18 18:43:34.475292": start predicting on day 2
# "2018-06-18 18:43:34.481202": saveing results
# "2018-06-18 18:43:34.482019": results saved
# "2018-06-18 18:43:34.482113": start predicting on day 6
# "2018-06-18 18:43:34.487945": saveing results
# "2018-06-18 18:43:34.488450": results saved
# "2018-06-18 18:43:34.488668": preprocesing started
# "2018-06-18 18:43:42.934289": train features shape: (22452, 19)
# "2018-06-18 18:43:42.934392": preprocesing finished
# "2018-06-18 18:43:42.934544": start training on days [1]
# "2018-06-18 18:43:42.934560": using fit without validation
# "2018-06-18 18:43:42.994246": start predicting on day 2
# "2018-06-18 18:43:42.998020": saveing results
# "2018-06-18 18:43:42.998596": results saved
# "2018-06-18 18:43:42.998646": start predicting on day 6
# "2018-06-18 18:43:43.002946": saveing results
# "2018-06-18 18:43:43.003528": results saved
# "2018-06-18 18:43:43.003762": preprocesing started
# "2018-06-18 18:43:51.232215": train features shape: (22452, 30)
# "2018-06-18 18:43:51.232300": preprocesing finished
# "2018-06-18 18:43:51.232464": start training on days [1]
# "2018-06-18 18:43:51.232481": using fit without validation
# "2018-06-18 18:43:52.341654": start predicting on day 2
# "2018-06-18 18:43:52.357117": saveing results
# "2018-06-18 18:43:52.357677": results saved
# "2018-06-18 18:43:52.357727": start predicting on day 6
# "2018-06-18 18:43:52.373492": saveing results
# "2018-06-18 18:43:52.374083": results saved
# "2018-06-18 18:43:52.374304": preprocesing started
# "2018-06-18 18:44:00.516970": train features shape: (22452, 30)
# "2018-06-18 18:44:00.517068": preprocesing finished
# "2018-06-18 18:44:00.517091": start training on days [1]
# "2018-06-18 18:44:00.517199": using fit without validation
# "2018-06-18 18:44:02.758746": start predicting on day 2
# "2018-06-18 18:44:02.779800": saveing results
# "2018-06-18 18:44:02.780355": results saved
# "2018-06-18 18:44:02.780404": start predicting on day 6
# "2018-06-18 18:44:02.801028": saveing results
# "2018-06-18 18:44:02.801663": results saved
# "2018-06-18 18:44:02.801874": preprocesing started
# "2018-06-18 18:44:10.971437": train features shape: (22452, 19)
# "2018-06-18 18:44:10.971524": preprocesing finished
# "2018-06-18 18:44:10.971637": start training on days [1]
# "2018-06-18 18:44:10.971653": using fit without validation
# "2018-06-18 18:44:12.877437": start predicting on day 2
# "2018-06-18 18:44:12.929782": saveing results
# "2018-06-18 18:44:12.930327": results saved
# "2018-06-18 18:44:12.930377": start predicting on day 6
# "2018-06-18 18:44:12.983682": saveing results
# "2018-06-18 18:44:12.984258": results saved
# "2018-06-18 18:44:12.984526": preprocesing started
# "2018-06-18 18:44:21.205786": train features shape: (22452, 30)
# "2018-06-18 18:44:21.205872": preprocesing finished
# "2018-06-18 18:44:21.206032": start training on days [1]
# "2018-06-18 18:44:21.206048": using fit without validation
# "2018-06-18 18:44:24.531604": start predicting on day 2
# "2018-06-18 18:44:24.566524": saveing results
# "2018-06-18 18:44:24.567414": results saved
# "2018-06-18 18:44:24.567481": start predicting on day 6
# "2018-06-18 18:44:24.597275": saveing results
# "2018-06-18 18:44:24.597865": results saved
# "2018-06-18 18:44:24.598065": preprocesing started
# "2018-06-18 18:44:33.617653": train features shape: (22452, 30)
# "2018-06-18 18:44:33.617802": preprocesing finished
# "2018-06-18 18:44:33.617873": start training on days [1]
# "2018-06-18 18:44:33.617910": using fit without validation
# "2018-06-18 18:44:38.340817": start predicting on day 2
# "2018-06-18 18:44:38.367276": saveing results
# "2018-06-18 18:44:38.367842": results saved
# "2018-06-18 18:44:38.367893": start predicting on day 6
# "2018-06-18 18:44:38.395168": saveing results
# "2018-06-18 18:44:38.395729": results saved
# "2018-06-18 18:44:38.396036": preprocesing started
# "2018-06-18 18:44:46.864948": train features shape: (22452, 19)
# "2018-06-18 18:44:46.865022": preprocesing finished
# "2018-06-18 18:44:46.865124": start training on days [1]
# "2018-06-18 18:44:46.865240": using fit without validation
# "2018-06-18 18:44:49.118019": start predicting on day 2
# "2018-06-18 18:44:49.143765": saveing results
# "2018-06-18 18:44:49.144286": results saved
# "2018-06-18 18:44:49.144322": start predicting on day 6
# "2018-06-18 18:44:49.169700": saveing results
# "2018-06-18 18:44:49.170275": results saved
# "2018-06-18 18:44:49.170574": preprocesing started
# "2018-06-18 18:44:57.782394": train features shape: (22452, 30)
# "2018-06-18 18:44:57.782486": preprocesing finished
# "2018-06-18 18:44:57.782661": start training on days [1]
# "2018-06-18 18:44:57.782798": using fit without validation
# "2018-06-18 18:45:01.235063": start predicting on day 2
# "2018-06-18 18:45:01.275205": saveing results
# "2018-06-18 18:45:01.275835": results saved
# "2018-06-18 18:45:01.275865": start predicting on day 6
# "2018-06-18 18:45:01.315594": saveing results
# "2018-06-18 18:45:01.316238": results saved
# "2018-06-18 18:45:01.316515": preprocesing started
# "2018-06-18 18:45:10.008731": train features shape: (22452, 30)
# "2018-06-18 18:45:10.008876": preprocesing finished
# "2018-06-18 18:45:10.008930": start training on days [1]
# "2018-06-18 18:45:10.008958": using fit without validation
# "2018-06-18 18:45:15.423106": start predicting on day 2
# "2018-06-18 18:45:15.463504": saveing results
# "2018-06-18 18:45:15.464321": results saved
# "2018-06-18 18:45:15.464381": start predicting on day 6
# "2018-06-18 18:45:15.504659": saveing results
# "2018-06-18 18:45:15.505281": results saved
# "2018-06-18 18:45:15.505547": preprocesing started
# "2018-06-18 18:45:23.993457": train features shape: (22452, 19)
# "2018-06-18 18:45:23.993549": preprocesing finished
# "2018-06-18 18:45:23.993739": start training on days [1]
# "2018-06-18 18:45:23.993774": using fit without validation
# "2018-06-18 18:45:26.507534": start predicting on day 2
# "2018-06-18 18:45:26.546977": saveing results
# "2018-06-18 18:45:26.547530": results saved
# "2018-06-18 18:45:26.547581": start predicting on day 6
# "2018-06-18 18:45:26.586487": saveing results
# "2018-06-18 18:45:26.587037": results saved
# "2018-06-18 18:45:26.587420": preprocesing started
# "2018-06-18 18:45:35.181050": train features shape: (22452, 30)
# "2018-06-18 18:45:35.181140": preprocesing finished
# "2018-06-18 18:45:35.181284": start training on days [1]
# "2018-06-18 18:45:35.181369": using fit without validation
# "2018-06-18 18:45:35.196866": start predicting on day 2
# "2018-06-18 18:45:35.197883": saveing results
# "2018-06-18 18:45:35.198364": results saved
# "2018-06-18 18:45:35.198416": start predicting on day 6
# "2018-06-18 18:45:35.199792": saveing results
# "2018-06-18 18:45:35.200294": results saved
# "2018-06-18 18:45:35.200492": preprocesing started
# "2018-06-18 18:45:43.786058": train features shape: (22452, 30)
# "2018-06-18 18:45:43.786146": preprocesing finished
# "2018-06-18 18:45:43.786180": start training on days [1]
# "2018-06-18 18:45:43.786194": using fit without validation
# "2018-06-18 18:45:43.801811": start predicting on day 2
# "2018-06-18 18:45:43.802868": saveing results
# "2018-06-18 18:45:43.803709": results saved
# "2018-06-18 18:45:43.803765": start predicting on day 6
# "2018-06-18 18:45:43.804917": saveing results
# "2018-06-18 18:45:43.805537": results saved
# "2018-06-18 18:45:43.805720": preprocesing started
# "2018-06-18 18:45:52.241913": train features shape: (22452, 19)
# "2018-06-18 18:45:52.242004": preprocesing finished
# "2018-06-18 18:45:52.242174": start training on days [1]
# "2018-06-18 18:45:52.242190": using fit without validation
# "2018-06-18 18:45:52.250398": start predicting on day 2
# "2018-06-18 18:45:52.251132": saveing results
# "2018-06-18 18:45:52.251650": results saved
# "2018-06-18 18:45:52.251700": start predicting on day 6
# "2018-06-18 18:45:52.252440": saveing results
# "2018-06-18 18:45:52.252850": results saved
# "2018-06-18 18:45:52.253026": preprocesing started
# "2018-06-18 18:46:00.760102": train features shape: (22452, 30)
# "2018-06-18 18:46:00.760207": preprocesing finished
# "2018-06-18 18:46:00.760230": start training on days [1]
# "2018-06-18 18:46:00.760245": using fit without validation
# "2018-06-18 18:46:00.767255": start predicting on day 2
# "2018-06-18 18:46:00.768266": saveing results
# "2018-06-18 18:46:00.768931": results saved
# "2018-06-18 18:46:00.768982": start predicting on day 6
# "2018-06-18 18:46:00.769934": saveing results
# "2018-06-18 18:46:00.770364": results saved
# "2018-06-18 18:46:00.770593": preprocesing started
# "2018-06-18 18:46:09.363962": train features shape: (22452, 30)
# "2018-06-18 18:46:09.364048": preprocesing finished
# "2018-06-18 18:46:09.364085": start training on days [1]
# "2018-06-18 18:46:09.364179": using fit without validation
# "2018-06-18 18:46:09.371452": start predicting on day 2
# "2018-06-18 18:46:09.372473": saveing results
# "2018-06-18 18:46:09.372964": results saved
# "2018-06-18 18:46:09.373013": start predicting on day 6
# "2018-06-18 18:46:09.373952": saveing results
# "2018-06-18 18:46:09.374391": results saved
# "2018-06-18 18:46:09.374605": preprocesing started
# "2018-06-18 18:46:17.867871": train features shape: (22452, 19)
# "2018-06-18 18:46:17.867964": preprocesing finished
# "2018-06-18 18:46:17.868077": start training on days [1]
# "2018-06-18 18:46:17.868093": using fit without validation
# "2018-06-18 18:46:17.873030": start predicting on day 2
# "2018-06-18 18:46:17.873762": saveing results
# "2018-06-18 18:46:17.874277": results saved
# "2018-06-18 18:46:17.874325": start predicting on day 6
# "2018-06-18 18:46:17.875004": saveing results
# "2018-06-18 18:46:17.875453": results saved
# "2018-06-18 18:46:17.875675": preprocesing started
# "2018-06-18 18:46:26.448128": train features shape: (22452, 30)
# "2018-06-18 18:46:26.448214": preprocesing finished
# "2018-06-18 18:46:26.448324": start training on days [1]
# "2018-06-18 18:46:26.448401": using fit without validation
# "2018-06-18 18:46:26.555953": start predicting on day 2
# "2018-06-18 18:46:26.562185": saveing results
# "2018-06-18 18:46:26.562743": results saved
# "2018-06-18 18:46:26.562793": start predicting on day 6
# "2018-06-18 18:46:26.568649": saveing results
# "2018-06-18 18:46:26.569144": results saved
# "2018-06-18 18:46:26.569418": preprocesing started
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-18 18:46:35.178335": train features shape: (22452, 30)
# "2018-06-18 18:46:35.178422": preprocesing finished
# "2018-06-18 18:46:35.178457": start training on days [1]
# "2018-06-18 18:46:35.178551": using fit without validation
# "2018-06-18 18:46:35.290747": start predicting on day 2
# "2018-06-18 18:46:35.296443": saveing results
# "2018-06-18 18:46:35.296972": results saved
# "2018-06-18 18:46:35.297021": start predicting on day 6
# "2018-06-18 18:46:35.303114": saveing results
# "2018-06-18 18:46:35.303671": results saved
# "2018-06-18 18:46:35.303876": preprocesing started
# "2018-06-18 18:46:43.815632": train features shape: (22452, 19)
# "2018-06-18 18:46:43.815746": preprocesing finished
# "2018-06-18 18:46:43.815768": start training on days [1]
# "2018-06-18 18:46:43.815898": using fit without validation
# "2018-06-18 18:46:43.883427": start predicting on day 2
# "2018-06-18 18:46:43.887678": saveing results
# "2018-06-18 18:46:43.888347": results saved
# "2018-06-18 18:46:43.888400": start predicting on day 6
# "2018-06-18 18:46:43.892442": saveing results
# "2018-06-18 18:46:43.892977": results saved
# "2018-06-18 18:46:43.893180": preprocesing started
# "2018-06-18 18:46:52.505215": train features shape: (22452, 30)
# "2018-06-18 18:46:52.505319": preprocesing finished
# "2018-06-18 18:46:52.505342": start training on days [1]
# "2018-06-18 18:46:52.505437": using fit without validation
# "2018-06-18 18:46:53.660597": start predicting on day 2
# "2018-06-18 18:46:53.677723": saveing results
# "2018-06-18 18:46:53.678361": results saved
# "2018-06-18 18:46:53.678411": start predicting on day 6
# "2018-06-18 18:46:53.694979": saveing results
# "2018-06-18 18:46:53.695525": results saved
# "2018-06-18 18:46:53.695796": preprocesing started
# "2018-06-18 18:47:02.346192": train features shape: (22452, 30)
# "2018-06-18 18:47:02.346312": preprocesing finished
# "2018-06-18 18:47:02.346370": start training on days [1]
# "2018-06-18 18:47:02.346624": using fit without validation
# "2018-06-18 18:47:07.501741": start predicting on day 2
# "2018-06-18 18:47:07.568027": saveing results
# "2018-06-18 18:47:07.568612": results saved
# "2018-06-18 18:47:07.568663": start predicting on day 6
# "2018-06-18 18:47:07.638889": saveing results
# "2018-06-18 18:47:07.639446": results saved
# "2018-06-18 18:47:07.639727": preprocesing started
# "2018-06-18 18:47:16.646079": train features shape: (22452, 19)
# "2018-06-18 18:47:16.646202": preprocesing finished
# "2018-06-18 18:47:16.646371": start training on days [1]
# "2018-06-18 18:47:16.646556": using fit without validation
# "2018-06-18 18:47:17.578121": start predicting on day 2
# "2018-06-18 18:47:17.595537": saveing results
# "2018-06-18 18:47:17.596162": results saved
# "2018-06-18 18:47:17.596236": start predicting on day 6
# "2018-06-18 18:47:17.614121": saveing results
# "2018-06-18 18:47:17.614868": results saved
# "2018-06-18 18:47:17.615126": preprocesing started
# "2018-06-18 18:47:26.897224": train features shape: (22452, 30)
# "2018-06-18 18:47:26.897310": preprocesing finished
# "2018-06-18 18:47:26.897348": start training on days [1]
# "2018-06-18 18:47:26.897441": using fit without validation
# "2018-06-18 18:47:30.691895": start predicting on day 2
# "2018-06-18 18:47:30.722641": saveing results
# "2018-06-18 18:47:30.723193": results saved
# "2018-06-18 18:47:30.723234": start predicting on day 6
# "2018-06-18 18:47:30.757588": saveing results
# "2018-06-18 18:47:30.758106": results saved
# "2018-06-18 18:47:30.758316": preprocesing started
# "2018-06-18 18:47:40.359419": train features shape: (22452, 30)
# "2018-06-18 18:47:40.359493": preprocesing finished
# "2018-06-18 18:47:40.359594": start training on days [1]
# "2018-06-18 18:47:40.359674": using fit without validation
# "2018-06-18 18:47:45.435703": start predicting on day 2
# "2018-06-18 18:47:45.463832": saveing results
# "2018-06-18 18:47:45.464408": results saved
# "2018-06-18 18:47:45.464457": start predicting on day 6
# "2018-06-18 18:47:45.492921": saveing results
# "2018-06-18 18:47:45.493465": results saved
# "2018-06-18 18:47:45.493652": preprocesing started
# "2018-06-18 18:47:54.464275": train features shape: (22452, 19)
# "2018-06-18 18:47:54.464369": preprocesing finished
# "2018-06-18 18:47:54.464481": start training on days [1]
# "2018-06-18 18:47:54.464496": using fit without validation
# "2018-06-18 18:47:56.854184": start predicting on day 2
# "2018-06-18 18:47:56.877750": saveing results
# "2018-06-18 18:47:56.878554": results saved
# "2018-06-18 18:47:56.878596": start predicting on day 6
# "2018-06-18 18:47:56.902504": saveing results
# "2018-06-18 18:47:56.903061": results saved
# "2018-06-18 18:47:56.903348": preprocesing started
# "2018-06-18 18:48:05.744791": train features shape: (22452, 30)
# "2018-06-18 18:48:05.744928": preprocesing finished
# "2018-06-18 18:48:05.745180": start training on days [1]
# "2018-06-18 18:48:05.745215": using fit without validation
# "2018-06-18 18:48:09.339437": start predicting on day 2
# "2018-06-18 18:48:09.377235": saveing results
# "2018-06-18 18:48:09.377778": results saved
# "2018-06-18 18:48:09.377828": start predicting on day 6
# "2018-06-18 18:48:09.417606": saveing results
# "2018-06-18 18:48:09.418170": results saved
# "2018-06-18 18:48:09.418399": preprocesing started
# "2018-06-18 18:48:18.033141": train features shape: (22452, 30)
# "2018-06-18 18:48:18.033241": preprocesing finished
# "2018-06-18 18:48:18.033448": start training on days [1]
# "2018-06-18 18:48:18.033466": using fit without validation
# "2018-06-18 18:48:23.322880": start predicting on day 2
# "2018-06-18 18:48:23.361786": saveing results
# "2018-06-18 18:48:23.362548": results saved
# "2018-06-18 18:48:23.362622": start predicting on day 6
# "2018-06-18 18:48:23.402074": saveing results
# "2018-06-18 18:48:23.402614": results saved
# "2018-06-18 18:48:23.402887": preprocesing started
# "2018-06-18 18:48:31.716835": train features shape: (22452, 19)
# "2018-06-18 18:48:31.716925": preprocesing finished
# "2018-06-18 18:48:31.717038": start training on days [1]
# "2018-06-18 18:48:31.717054": using fit without validation
# "2018-06-18 18:48:34.201075": start predicting on day 2
# "2018-06-18 18:48:34.239934": saveing results
# "2018-06-18 18:48:34.240470": results saved
# "2018-06-18 18:48:34.240520": start predicting on day 6
# "2018-06-18 18:48:34.279826": saveing results
# "2018-06-18 18:48:34.280459": results saved
# "2018-06-18 18:48:34.280867": preprocesing started
# "2018-06-18 18:48:42.669050": train features shape: (22452, 30)
# "2018-06-18 18:48:42.669139": preprocesing finished
# "2018-06-18 18:48:42.669175": start training on days [1]
# "2018-06-18 18:48:42.669361": using fit without validation
# "2018-06-18 18:48:42.686039": start predicting on day 2
# "2018-06-18 18:48:42.687066": saveing results
# "2018-06-18 18:48:42.687556": results saved
# "2018-06-18 18:48:42.687607": start predicting on day 6
# "2018-06-18 18:48:42.688593": saveing results
# "2018-06-18 18:48:42.689035": results saved
# "2018-06-18 18:48:42.689215": preprocesing started
# "2018-06-18 18:48:51.210735": train features shape: (22452, 30)
# "2018-06-18 18:48:51.210822": preprocesing finished
# "2018-06-18 18:48:51.210943": start training on days [1]
# "2018-06-18 18:48:51.210958": using fit without validation
# "2018-06-18 18:48:51.227650": start predicting on day 2
# "2018-06-18 18:48:51.228879": saveing results
# "2018-06-18 18:48:51.229453": results saved
# "2018-06-18 18:48:51.229506": start predicting on day 6
# "2018-06-18 18:48:51.230533": saveing results
# "2018-06-18 18:48:51.231164": results saved
# "2018-06-18 18:48:51.231400": preprocesing started
# "2018-06-18 18:48:59.415498": train features shape: (22452, 19)
# "2018-06-18 18:48:59.415588": preprocesing finished
# "2018-06-18 18:48:59.415753": start training on days [1]
# "2018-06-18 18:48:59.415770": using fit without validation
# "2018-06-18 18:48:59.423864": start predicting on day 2
# "2018-06-18 18:48:59.424534": saveing results
# "2018-06-18 18:48:59.425035": results saved
# "2018-06-18 18:48:59.425084": start predicting on day 6
# "2018-06-18 18:48:59.425785": saveing results
# "2018-06-18 18:48:59.426200": results saved
# "2018-06-18 18:48:59.426448": preprocesing started
# "2018-06-18 18:49:08.002681": train features shape: (22452, 30)
# "2018-06-18 18:49:08.002774": preprocesing finished
# "2018-06-18 18:49:08.002811": start training on days [1]
# "2018-06-18 18:49:08.002953": using fit without validation
# "2018-06-18 18:49:08.009814": start predicting on day 2
# "2018-06-18 18:49:08.010913": saveing results
# "2018-06-18 18:49:08.011532": results saved
# "2018-06-18 18:49:08.011569": start predicting on day 6
# "2018-06-18 18:49:08.012585": saveing results
# "2018-06-18 18:49:08.013084": results saved
# "2018-06-18 18:49:08.013323": preprocesing started
# "2018-06-18 18:49:16.576100": train features shape: (22452, 30)
# "2018-06-18 18:49:16.576221": preprocesing finished
# "2018-06-18 18:49:16.576260": start training on days [1]
# "2018-06-18 18:49:16.576403": using fit without validation
# "2018-06-18 18:49:16.586301": start predicting on day 2
# "2018-06-18 18:49:16.587466": saveing results
# "2018-06-18 18:49:16.588479": results saved
# "2018-06-18 18:49:16.588602": start predicting on day 6
# "2018-06-18 18:49:16.589722": saveing results
# "2018-06-18 18:49:16.590196": results saved
# "2018-06-18 18:49:16.590479": preprocesing started
# "2018-06-18 18:49:25.215676": train features shape: (22452, 19)
# "2018-06-18 18:49:25.215764": preprocesing finished
# "2018-06-18 18:49:25.215880": start training on days [1]
# "2018-06-18 18:49:25.215896": using fit without validation
# "2018-06-18 18:49:25.220280": start predicting on day 2
# "2018-06-18 18:49:25.220984": saveing results
# "2018-06-18 18:49:25.221577": results saved
# "2018-06-18 18:49:25.221634": start predicting on day 6
# "2018-06-18 18:49:25.222279": saveing results
# "2018-06-18 18:49:25.222702": results saved
# "2018-06-18 18:49:25.222880": preprocesing started
# "2018-06-18 18:49:34.076932": train features shape: (22452, 30)
# "2018-06-18 18:49:34.077026": preprocesing finished
# "2018-06-18 18:49:34.077146": start training on days [1]
# "2018-06-18 18:49:34.077162": using fit without validation
# "2018-06-18 18:49:34.206894": start predicting on day 2
# "2018-06-18 18:49:34.212922": saveing results
# "2018-06-18 18:49:34.213771": results saved
# "2018-06-18 18:49:34.213835": start predicting on day 6
# "2018-06-18 18:49:34.219638": saveing results
# "2018-06-18 18:49:34.220145": results saved
# "2018-06-18 18:49:34.220389": preprocesing started
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-18 18:49:43.167703": train features shape: (22452, 30)
# "2018-06-18 18:49:43.167804": preprocesing finished
# "2018-06-18 18:49:43.167900": start training on days [1]
# ...
# "2018-06-18 19:23:18.300962": saveing results
# "2018-06-18 19:23:18.301678": results saved
# "2018-06-18 19:23:18.301923": preprocesing started
# "2018-06-18 19:23:26.766762": train features shape: (22452, 19)
# "2018-06-18 19:23:26.766853": preprocesing finished
# "2018-06-18 19:23:26.766892": start training on days [1]
# "2018-06-18 19:23:26.766991": using fit without validation
# "2018-06-18 19:23:26.827828": start predicting on day 2
# "2018-06-18 19:23:26.831869": saveing results
# "2018-06-18 19:23:26.832392": results saved
# "2018-06-18 19:23:26.832442": start predicting on day 6
# "2018-06-18 19:23:26.836180": saveing results
# "2018-06-18 19:23:26.836679": results saved
# "2018-06-18 19:23:26.836858": preprocesing started
# "2018-06-18 19:23:35.459283": train features shape: (22452, 30)
# "2018-06-18 19:23:35.459379": preprocesing finished
# "2018-06-18 19:23:35.459499": start training on days [1]
# "2018-06-18 19:23:35.459602": using fit without validation
# "2018-06-18 19:23:37.733396": start predicting on day 2
# "2018-06-18 19:23:37.777224": saveing results
# "2018-06-18 19:23:37.778035": results saved
# "2018-06-18 19:23:37.778095": start predicting on day 6
# "2018-06-18 19:23:37.824908": saveing results
# "2018-06-18 19:23:37.825770": results saved
# "2018-06-18 19:23:37.825990": preprocesing started
# "2018-06-18 19:23:46.346050": train features shape: (22452, 30)
# "2018-06-18 19:23:46.346149": preprocesing finished
# "2018-06-18 19:23:46.346299": start training on days [1]
# "2018-06-18 19:23:46.346314": using fit without validation
# "2018-06-18 19:23:50.920321": start predicting on day 2
# "2018-06-18 19:23:50.983396": saveing results
# "2018-06-18 19:23:50.984069": results saved
# "2018-06-18 19:23:50.984122": start predicting on day 6
# "2018-06-18 19:23:51.052523": saveing results
# "2018-06-18 19:23:51.053288": results saved
# "2018-06-18 19:23:51.053579": preprocesing started
# "2018-06-18 19:23:59.539930": train features shape: (22452, 19)
# "2018-06-18 19:23:59.540020": preprocesing finished
# "2018-06-18 19:23:59.540134": start training on days [1]
# "2018-06-18 19:23:59.540149": using fit without validation
# "2018-06-18 19:24:00.910015": start predicting on day 2
# "2018-06-18 19:24:00.942301": saveing results
# "2018-06-18 19:24:00.942840": results saved
# "2018-06-18 19:24:00.942891": start predicting on day 6
# "2018-06-18 19:24:00.974788": saveing results
# "2018-06-18 19:24:00.975540": results saved
# "2018-06-18 19:24:00.975833": preprocesing started
# "2018-06-18 19:24:09.449511": train features shape: (22452, 30)
# "2018-06-18 19:24:09.449673": preprocesing finished
# "2018-06-18 19:24:09.449804": start training on days [1]
# "2018-06-18 19:24:09.449822": using fit without validation
# "2018-06-18 19:24:12.804446": start predicting on day 2
# "2018-06-18 19:24:12.831537": saveing results
# "2018-06-18 19:24:12.832294": results saved
# "2018-06-18 19:24:12.832347": start predicting on day 6
# "2018-06-18 19:24:12.859362": saveing results
# "2018-06-18 19:24:12.859970": results saved
# "2018-06-18 19:24:12.860229": preprocesing started
# "2018-06-18 19:24:21.399682": train features shape: (22452, 30)
# "2018-06-18 19:24:21.399768": preprocesing finished
# "2018-06-18 19:24:21.399883": start training on days [1]
# "2018-06-18 19:24:21.399898": using fit without validation
# "2018-06-18 19:24:26.027730": start predicting on day 2
# "2018-06-18 19:24:26.057107": saveing results
# "2018-06-18 19:24:26.057837": results saved
# "2018-06-18 19:24:26.057890": start predicting on day 6
# "2018-06-18 19:24:26.086257": saveing results
# "2018-06-18 19:24:26.086831": results saved
# "2018-06-18 19:24:26.087030": preprocesing started
# "2018-06-18 19:24:34.507780": train features shape: (22452, 19)
# "2018-06-18 19:24:34.507872": preprocesing finished
# "2018-06-18 19:24:34.507989": start training on days [1]
# "2018-06-18 19:24:34.508004": using fit without validation
# "2018-06-18 19:24:36.698962": start predicting on day 2
# "2018-06-18 19:24:36.722454": saveing results
# "2018-06-18 19:24:36.723010": results saved
# "2018-06-18 19:24:36.723059": start predicting on day 6
# "2018-06-18 19:24:36.746599": saveing results
# "2018-06-18 19:24:36.747099": results saved
# "2018-06-18 19:24:36.747286": preprocesing started
# "2018-06-18 19:24:45.378273": train features shape: (22452, 30)
# "2018-06-18 19:24:45.378373": preprocesing finished
# "2018-06-18 19:24:45.378473": start training on days [1]
# "2018-06-18 19:24:45.378488": using fit without validation
# "2018-06-18 19:24:48.903060": start predicting on day 2
# "2018-06-18 19:24:48.941686": saveing results
# "2018-06-18 19:24:48.942234": results saved
# "2018-06-18 19:24:48.942285": start predicting on day 6
# "2018-06-18 19:24:48.982447": saveing results
# "2018-06-18 19:24:48.983000": results saved
# "2018-06-18 19:24:48.983254": preprocesing started
# "2018-06-18 19:24:57.489731": train features shape: (22452, 30)
# "2018-06-18 19:24:57.489818": preprocesing finished
# "2018-06-18 19:24:57.489930": start training on days [1]
# "2018-06-18 19:24:57.489945": using fit without validation
# "2018-06-18 19:25:02.753053": start predicting on day 2
# "2018-06-18 19:25:02.791155": saveing results
# "2018-06-18 19:25:02.791720": results saved
# "2018-06-18 19:25:02.791771": start predicting on day 6
# "2018-06-18 19:25:02.830687": saveing results
# "2018-06-18 19:25:02.831254": results saved
# "2018-06-18 19:25:02.831504": preprocesing started
# "2018-06-18 19:25:11.266417": train features shape: (22452, 19)
# "2018-06-18 19:25:11.266506": preprocesing finished
# "2018-06-18 19:25:11.266543": start training on days [1]
# "2018-06-18 19:25:11.266637": using fit without validation
# "2018-06-18 19:25:13.676773": start predicting on day 2
# "2018-06-18 19:25:13.716015": saveing results
# "2018-06-18 19:25:13.716657": results saved
# "2018-06-18 19:25:13.716708": start predicting on day 6
# "2018-06-18 19:25:13.756182": saveing results
# "2018-06-18 19:25:13.756728": results saved
# "2018-06-18 19:25:13.757097": preprocesing started
# "2018-06-18 19:25:22.393087": train features shape: (22452, 30)
# "2018-06-18 19:25:22.393176": preprocesing finished
# "2018-06-18 19:25:22.393197": start training on days [1]
# "2018-06-18 19:25:22.393225": using fit without validation
# "2018-06-18 19:25:22.409761": start predicting on day 2
# "2018-06-18 19:25:22.410740": saveing results
# "2018-06-18 19:25:22.411236": results saved
# "2018-06-18 19:25:22.411287": start predicting on day 6
# "2018-06-18 19:25:22.412502": saveing results
# "2018-06-18 19:25:22.413096": results saved
# "2018-06-18 19:25:22.413283": preprocesing started
# "2018-06-18 19:25:30.938160": train features shape: (22452, 30)
# "2018-06-18 19:25:30.938248": preprocesing finished
# "2018-06-18 19:25:30.938359": start training on days [1]
# "2018-06-18 19:25:30.938437": using fit without validation
# "2018-06-18 19:25:30.954546": start predicting on day 2
# "2018-06-18 19:25:30.955609": saveing results
# "2018-06-18 19:25:30.956083": results saved
# "2018-06-18 19:25:30.956134": start predicting on day 6
# "2018-06-18 19:25:30.957022": saveing results
# "2018-06-18 19:25:30.957449": results saved
# "2018-06-18 19:25:30.957656": preprocesing started
# "2018-06-18 19:25:39.541707": train features shape: (22452, 19)
# "2018-06-18 19:25:39.541798": preprocesing finished
# "2018-06-18 19:25:39.542062": start training on days [1]
# "2018-06-18 19:25:39.542168": using fit without validation
# "2018-06-18 19:25:39.550372": start predicting on day 2
# "2018-06-18 19:25:39.551048": saveing results
# "2018-06-18 19:25:39.551545": results saved
# "2018-06-18 19:25:39.551594": start predicting on day 6
# "2018-06-18 19:25:39.552478": saveing results
# "2018-06-18 19:25:39.553001": results saved
# "2018-06-18 19:25:39.553205": preprocesing started
# "2018-06-18 19:25:48.177132": train features shape: (22452, 30)
# "2018-06-18 19:25:48.177219": preprocesing finished
# "2018-06-18 19:25:48.177414": start training on days [1]
# "2018-06-18 19:25:48.177431": using fit without validation
# "2018-06-18 19:25:48.184883": start predicting on day 2
# "2018-06-18 19:25:48.185890": saveing results
# "2018-06-18 19:25:48.186404": results saved
# "2018-06-18 19:25:48.186436": start predicting on day 6
# "2018-06-18 19:25:48.187536": saveing results
# "2018-06-18 19:25:48.188279": results saved
# "2018-06-18 19:25:48.188546": preprocesing started
# "2018-06-18 19:25:56.739858": train features shape: (22452, 30)
# "2018-06-18 19:25:56.739943": preprocesing finished
# "2018-06-18 19:25:56.739978": start training on days [1]
# "2018-06-18 19:25:56.739994": using fit without validation
# "2018-06-18 19:25:56.746892": start predicting on day 2
# "2018-06-18 19:25:56.747908": saveing results
# "2018-06-18 19:25:56.748444": results saved
# "2018-06-18 19:25:56.748492": start predicting on day 6
# "2018-06-18 19:25:56.749424": saveing results
# "2018-06-18 19:25:56.749853": results saved
# "2018-06-18 19:25:56.750110": preprocesing started
# "2018-06-18 19:26:05.285757": train features shape: (22452, 19)
# "2018-06-18 19:26:05.285848": preprocesing finished
# "2018-06-18 19:26:05.285983": start training on days [1]
# "2018-06-18 19:26:05.285998": using fit without validation
# "2018-06-18 19:26:05.290114": start predicting on day 2
# "2018-06-18 19:26:05.290799": saveing results
# "2018-06-18 19:26:05.291274": results saved
# "2018-06-18 19:26:05.291317": start predicting on day 6
# "2018-06-18 19:26:05.291988": saveing results
# "2018-06-18 19:26:05.292408": results saved
# "2018-06-18 19:26:05.292576": preprocesing started
# "2018-06-18 19:26:13.910234": train features shape: (22452, 30)
# "2018-06-18 19:26:13.910322": preprocesing finished
# "2018-06-18 19:26:13.910552": start training on days [1]
# "2018-06-18 19:26:13.910588": using fit without validation
# "2018-06-18 19:26:14.024495": start predicting on day 2
# "2018-06-18 19:26:14.030611": saveing results
# "2018-06-18 19:26:14.069383": results saved
# "2018-06-18 19:26:14.069472": start predicting on day 6
# "2018-06-18 19:26:14.078997": saveing results
# "2018-06-18 19:26:14.079838": results saved
# "2018-06-18 19:26:14.080120": preprocesing started
# /usr/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# "2018-06-18 19:26:22.776384": train features shape: (22452, 30)
# "2018-06-18 19:26:22.776456": preprocesing finished
# "2018-06-18 19:26:22.776554": start training on days [1]
# "2018-06-18 19:26:22.776653": using fit without validation
# "2018-06-18 19:26:22.869925": start predicting on day 2
# "2018-06-18 19:26:22.875359": saveing results
# "2018-06-18 19:26:22.875836": results saved
# "2018-06-18 19:26:22.875874": start predicting on day 6
# "2018-06-18 19:26:22.881799": saveing results
# "2018-06-18 19:26:22.882427": results saved
# "2018-06-18 19:26:22.882608": preprocesing started
# "2018-06-18 19:26:31.560281": train features shape: (22452, 19)
# "2018-06-18 19:26:31.560359": preprocesing finished
# "2018-06-18 19:26:31.560515": start training on days [1]
# "2018-06-18 19:26:31.560581": using fit without validation
# "2018-06-18 19:26:31.625595": start predicting on day 2
# "2018-06-18 19:26:31.629590": saveing results
# "2018-06-18 19:26:31.630099": results saved
# "2018-06-18 19:26:31.630136": start predicting on day 6
# "2018-06-18 19:26:31.633994": saveing results
# "2018-06-18 19:26:31.634533": results saved
# "2018-06-18 19:26:31.634784": preprocesing started
# "2018-06-18 19:26:40.371963": train features shape: (22452, 30)
# "2018-06-18 19:26:40.372073": preprocesing finished
# "2018-06-18 19:26:40.372260": start training on days [1]
# "2018-06-18 19:26:40.372333": using fit without validation
# "2018-06-18 19:26:43.602485": start predicting on day 2
# "2018-06-18 19:26:43.684264": saveing results
# "2018-06-18 19:26:43.684775": results saved
# "2018-06-18 19:26:43.684810": start predicting on day 6
# "2018-06-18 19:26:43.769854": saveing results
# "2018-06-18 19:26:43.770362": results saved
# "2018-06-18 19:26:43.770568": preprocesing started
# "2018-06-18 19:26:52.466694": train features shape: (22452, 30)
# "2018-06-18 19:26:52.466774": preprocesing finished
# "2018-06-18 19:26:52.466803": start training on days [1]
# "2018-06-18 19:26:52.466825": using fit without validation
# "2018-06-18 19:26:57.706771": start predicting on day 2
# "2018-06-18 19:26:57.784415": saveing results
# "2018-06-18 19:26:57.784954": results saved
# "2018-06-18 19:26:57.784990": start predicting on day 6
# "2018-06-18 19:26:57.863849": saveing results
# "2018-06-18 19:26:57.864368": results saved
# "2018-06-18 19:26:57.864562": preprocesing started
# "2018-06-18 19:27:06.301351": train features shape: (22452, 19)
# "2018-06-18 19:27:06.301445": preprocesing finished
# "2018-06-18 19:27:06.301614": start training on days [1]
# "2018-06-18 19:27:06.301680": using fit without validation
# "2018-06-18 19:27:07.088347": start predicting on day 2
# "2018-06-18 19:27:07.103034": saveing results
# "2018-06-18 19:27:07.103733": results saved
# "2018-06-18 19:27:07.103800": start predicting on day 6
# "2018-06-18 19:27:07.117833": saveing results
# "2018-06-18 19:27:07.118475": results saved
# "2018-06-18 19:27:07.118787": preprocesing started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-25457e8afa8a> in <module>()
#       1 for i in range(30):
# ----> 2     get_stacking_metric(i)
#
# <ipython-input-4-3fef6592806b> in get_stacking_metric(i)
#      52             if not os.path.exists(args.out_folder):
#      53                 clear(args.out_folder)
# ---> 54                 calculate_predictions(args)
#      55             args.first_feature += args.step
#      56             args.last_feature += args.step
#
# ~/code/counterfactual-learning/code/python/calculating_predictions/calculate_predictions.py in calculate_predictions(args)
#      51                 add_positions=need_position_feature
#      52             )
# ---> 53
#      54     train_features = np.concatenate([get_features(day) for day in args.train_days], axis=0)
#      55     test_features = [get_features(test_day) for test_day in args.test_days]
#
# ~/code/counterfactual-learning/code/python/calculating_predictions/calculate_predictions.py in <listcomp>(.0)
#      51                 add_positions=need_position_feature
#      52             )
# ---> 53
#      54     train_features = np.concatenate([get_features(day) for day in args.train_days], axis=0)
#      55     test_features = [get_features(test_day) for test_day in args.test_days]
#
# ~/code/counterfactual-learning/code/python/utils/json_tools.py in get_linear_stacked_features(pool_iterator, results_list, first_feature, last_feature, add_positions)
#      50     results = [np.load(filename) for filename in results_list]
#      51     features = []
# ---> 52     for i, item in enumerate(pool_iterator):
#      53         feature = make_feature(item, add_positions, first_feature, last_feature)
#      54         for result in results:
#
# ~/code/counterfactual-learning/code/python/utils/pool_iterator.py in pool_iterator(pool_path)
#       5     with open(pool_path) as handler:
#       6         for line in handler:
# ----> 7             yield json_from_string(line.strip())
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# KeyboardInterrupt:
