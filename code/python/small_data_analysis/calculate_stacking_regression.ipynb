# %%
import numpy as np
import shutil
import os

import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *
from argparse import Namespace
from catboost import CatBoostRegressor, CatBoostClassifier

# %reload_ext autoreload
# %autoreload 2

# %%
def clear(folder):
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

def get_regression_stacking_metric(i):
    args = Namespace()
    args.verbose = True
    args.first_feature = 0
    args.last_feature = -1
    args.data_folder = "../../../data/best_features_days_data/"
    out_folder = "regression_predictions"
    args.type = "regression"
    args.need_position_feature = True
    args.labels_to_substruct = None
    args.metric_folder = "metrics"
    args.model_constructor = lambda verbose: CatBoostRegressor(verbose=False)
    args.additional_features = {
        day: [
            os.path.join("features_models_with_pos", str(i), filename)
            for filename in os.listdir(os.path.join("features_models_with_pos", str(i)))
        ]
        for day in [3, 6]
    }
    args.validation_day = None
    args.train_days = [3]
    args.test_days = [6]
    
    args.out_folder = os.path.join(out_folder, str(i))

    clear(args.out_folder)
    clear(args.metric_folder)
    
    calculate_predictions(args)
    evaluate(args.out_folder, args.data_folder, args.metric_folder, argmax_positions)
    
    with open("metrics/metrics.txt") as handler:
        metric = float(next(handler).strip().split()[0])
        return metric

# %%
# %%time
metrics = [get_regression_stacking_metric(i) for i in range(15)]
# Out:
# "2018-06-21 12:48:14.764440": preprocesing started
# "2018-06-21 12:48:15.523908":     base features shape: (20203, 80)
# "2018-06-21 12:48:16.569804":     28 features added
# "2018-06-21 12:48:16.569911":     result shape: (20203, 108)
# "2018-06-21 12:48:16.573656": train features shape: (20203, 108)
# "2018-06-21 12:48:17.153490": preprocesing finished
# "2018-06-21 12:48:17.153576": start training on days [3]
# "2018-06-21 12:48:17.153690": using fit without validation
# "2018-06-21 12:48:39.485175": built 1000 trees
# "2018-06-21 12:48:41.513654":     base features shape: (247423, 80)
# "2018-06-21 12:48:46.465870":     28 features added
# "2018-06-21 12:48:46.465957":     result shape: (247423, 108)
# "2018-06-21 12:48:46.466941": days to predict: [6]
# "2018-06-21 12:48:46.466976": features shape: (247423, 108)
# "2018-06-21 12:48:46.467244": start predicting on day 6
# "2018-06-21 12:48:48.255299": predictions shape: (22493, 11)
# "2018-06-21 12:48:48.255488": saveing results to regression_predictions/0/train_3_test_6
# "2018-06-21 12:48:48.257291": results saved
# "2018-06-21 12:48:50.202974": preprocesing started
# "2018-06-21 12:48:50.917335":     base features shape: (20203, 80)
# "2018-06-21 12:48:51.478703":     28 features added
# "2018-06-21 12:48:51.478809":     result shape: (20203, 108)
# "2018-06-21 12:48:51.480383": train features shape: (20203, 108)
# "2018-06-21 12:48:52.035479": preprocesing finished
# "2018-06-21 12:48:52.035552": start training on days [3]
# "2018-06-21 12:48:52.035654": using fit without validation
# "2018-06-21 12:49:13.967943": built 1000 trees
# "2018-06-21 12:49:16.104443":     base features shape: (247423, 80)
# "2018-06-21 12:49:21.443387":     28 features added
# "2018-06-21 12:49:21.443493":     result shape: (247423, 108)
# "2018-06-21 12:49:21.446773": days to predict: [6]
# "2018-06-21 12:49:21.446905": features shape: (247423, 108)
# "2018-06-21 12:49:21.446926": start predicting on day 6
# "2018-06-21 12:49:23.162228": predictions shape: (22493, 11)
# "2018-06-21 12:49:23.162328": saveing results to regression_predictions/1/train_3_test_6
# "2018-06-21 12:49:23.163916": results saved
# "2018-06-21 12:49:25.001511": preprocesing started
# "2018-06-21 12:49:25.780210":     base features shape: (20203, 80)
# "2018-06-21 12:49:26.342599":     28 features added
# "2018-06-21 12:49:26.342704":     result shape: (20203, 108)
# "2018-06-21 12:49:26.344150": train features shape: (20203, 108)
# "2018-06-21 12:49:26.896742": preprocesing finished
# "2018-06-21 12:49:26.896825": start training on days [3]
# "2018-06-21 12:49:26.896845": using fit without validation
# "2018-06-21 12:49:49.204899": built 1000 trees
# "2018-06-21 12:49:51.407177":     base features shape: (247423, 80)
# "2018-06-21 12:49:56.503493":     28 features added
# "2018-06-21 12:49:56.503616":     result shape: (247423, 108)
# "2018-06-21 12:49:56.504406": days to predict: [6]
# "2018-06-21 12:49:56.504550": features shape: (247423, 108)
# "2018-06-21 12:49:56.504568": start predicting on day 6
# "2018-06-21 12:49:58.251581": predictions shape: (22493, 11)
# "2018-06-21 12:49:58.251739": saveing results to regression_predictions/2/train_3_test_6
# "2018-06-21 12:49:58.253136": results saved
# "2018-06-21 12:50:00.314822": preprocesing started
# "2018-06-21 12:50:01.120676":     base features shape: (20203, 80)
# "2018-06-21 12:50:01.616055":     28 features added
# "2018-06-21 12:50:01.616162":     result shape: (20203, 108)
# "2018-06-21 12:50:01.618050": train features shape: (20203, 108)
# "2018-06-21 12:50:02.237589": preprocesing finished
# "2018-06-21 12:50:02.237658": start training on days [3]
# "2018-06-21 12:50:02.237673": using fit without validation
# "2018-06-21 12:50:25.156179": built 1000 trees
# "2018-06-21 12:50:27.311749":     base features shape: (247423, 80)
# "2018-06-21 12:50:32.083287":     28 features added
# "2018-06-21 12:50:32.083380":     result shape: (247423, 108)
# "2018-06-21 12:50:32.085172": days to predict: [6]
# "2018-06-21 12:50:32.085301": features shape: (247423, 108)
# "2018-06-21 12:50:32.085417": start predicting on day 6
# "2018-06-21 12:50:34.006064": predictions shape: (22493, 11)
# "2018-06-21 12:50:34.006227": saveing results to regression_predictions/3/train_3_test_6
# "2018-06-21 12:50:34.008199": results saved
# "2018-06-21 12:50:35.961728": preprocesing started
# "2018-06-21 12:50:36.705994":     base features shape: (20203, 80)
# "2018-06-21 12:50:37.238515":     28 features added
# "2018-06-21 12:50:37.238604":     result shape: (20203, 108)
# "2018-06-21 12:50:37.240180": train features shape: (20203, 108)
# "2018-06-21 12:50:37.837995": preprocesing finished
# "2018-06-21 12:50:37.838223": start training on days [3]
# "2018-06-21 12:50:37.838344": using fit without validation
# "2018-06-21 12:51:00.974929": built 1000 trees
# "2018-06-21 12:51:04.295765":     base features shape: (247423, 80)
# "2018-06-21 12:51:11.591915":     28 features added
# "2018-06-21 12:51:11.592032":     result shape: (247423, 108)
# "2018-06-21 12:51:11.599782": days to predict: [6]
# "2018-06-21 12:51:11.610134": features shape: (247423, 108)
# "2018-06-21 12:51:11.610251": start predicting on day 6
# "2018-06-21 12:51:15.154447": predictions shape: (22493, 11)
# "2018-06-21 12:51:15.154846": saveing results to regression_predictions/4/train_3_test_6
# "2018-06-21 12:51:15.156869": results saved
# "2018-06-21 12:51:18.436826": preprocesing started
# "2018-06-21 12:51:19.652409":     base features shape: (20203, 80)
# "2018-06-21 12:51:20.498147":     28 features added
# "2018-06-21 12:51:20.498268":     result shape: (20203, 108)
# "2018-06-21 12:51:20.500162": train features shape: (20203, 108)
# "2018-06-21 12:51:21.506741": preprocesing finished
# "2018-06-21 12:51:21.506842": start training on days [3]
# "2018-06-21 12:51:21.506974": using fit without validation
# "2018-06-21 12:52:25.228342": built 1000 trees
# "2018-06-21 12:52:28.830813":     base features shape: (247423, 80)
# "2018-06-21 12:52:36.941009":     28 features added
# "2018-06-21 12:52:36.941125":     result shape: (247423, 108)
# "2018-06-21 12:52:36.945541": days to predict: [6]
# "2018-06-21 12:52:36.945609": features shape: (247423, 108)
# "2018-06-21 12:52:36.945628": start predicting on day 6
# "2018-06-21 12:52:40.572639": predictions shape: (22493, 11)
# "2018-06-21 12:52:40.572921": saveing results to regression_predictions/5/train_3_test_6
# "2018-06-21 12:52:40.575044": results saved
# "2018-06-21 12:52:43.877453": preprocesing started
# "2018-06-21 12:52:45.086905":     base features shape: (20203, 80)
# "2018-06-21 12:52:45.849446":     28 features added
# "2018-06-21 12:52:45.849569":     result shape: (20203, 108)
# "2018-06-21 12:52:45.851497": train features shape: (20203, 108)
# "2018-06-21 12:52:46.868411": preprocesing finished
# "2018-06-21 12:52:46.868501": start training on days [3]
# "2018-06-21 12:52:46.868625": using fit without validation
# "2018-06-21 12:53:50.273565": built 1000 trees
# "2018-06-21 12:53:53.983104":     base features shape: (247423, 80)
# "2018-06-21 12:53:59.914668":     28 features added
# "2018-06-21 12:53:59.914908":     result shape: (247423, 108)
# "2018-06-21 12:53:59.919636": days to predict: [6]
# "2018-06-21 12:53:59.919840": features shape: (247423, 108)
# "2018-06-21 12:53:59.919935": start predicting on day 6
# "2018-06-21 12:54:02.061336": predictions shape: (22493, 11)
# "2018-06-21 12:54:02.061460": saveing results to regression_predictions/6/train_3_test_6
# "2018-06-21 12:54:02.063454": results saved
# "2018-06-21 12:54:04.280276": preprocesing started
# "2018-06-21 12:54:05.102271":     base features shape: (20203, 80)
# "2018-06-21 12:54:05.639195":     28 features added
# "2018-06-21 12:54:05.639425":     result shape: (20203, 108)
# "2018-06-21 12:54:05.642204": train features shape: (20203, 108)
# "2018-06-21 12:54:06.450968": preprocesing finished
# "2018-06-21 12:54:06.451075": start training on days [3]
# "2018-06-21 12:54:06.451112": using fit without validation
# "2018-06-21 12:55:06.047616": built 1000 trees
# "2018-06-21 12:55:09.686875":     base features shape: (247423, 80)
# "2018-06-21 12:55:16.197339":     28 features added
# "2018-06-21 12:55:16.197451":     result shape: (247423, 108)
# "2018-06-21 12:55:16.204489": days to predict: [6]
# "2018-06-21 12:55:16.204605": features shape: (247423, 108)
# "2018-06-21 12:55:16.204638": start predicting on day 6
# "2018-06-21 12:55:20.004720": predictions shape: (22493, 11)
# "2018-06-21 12:55:20.004837": saveing results to regression_predictions/7/train_3_test_6
# "2018-06-21 12:55:20.007102": results saved
# "2018-06-21 12:55:23.600901": preprocesing started
# "2018-06-21 12:55:24.930192":     base features shape: (20203, 80)
# "2018-06-21 12:55:25.720880":     28 features added
# "2018-06-21 12:55:25.721062":     result shape: (20203, 108)
# "2018-06-21 12:55:25.724989": train features shape: (20203, 108)
# "2018-06-21 12:55:26.817452": preprocesing finished
# "2018-06-21 12:55:26.817574": start training on days [3]
# "2018-06-21 12:55:26.819856": using fit without validation
# "2018-06-21 12:56:37.704065": built 1000 trees
# "2018-06-21 12:56:41.274871":     base features shape: (247423, 80)
# "2018-06-21 12:56:48.130634":     28 features added
# "2018-06-21 12:56:48.130759":     result shape: (247423, 108)
# "2018-06-21 12:56:48.139279": days to predict: [6]
# "2018-06-21 12:56:48.139452": features shape: (247423, 108)
# "2018-06-21 12:56:48.139491": start predicting on day 6
# "2018-06-21 12:56:51.807298": predictions shape: (22493, 11)
# "2018-06-21 12:56:51.807682": saveing results to regression_predictions/8/train_3_test_6
# "2018-06-21 12:56:51.809801": results saved
# "2018-06-21 12:56:55.307857": preprocesing started
# "2018-06-21 12:56:56.571599":     base features shape: (20203, 80)
# "2018-06-21 12:56:57.322474":     28 features added
# "2018-06-21 12:56:57.322595":     result shape: (20203, 108)
# "2018-06-21 12:56:57.324284": train features shape: (20203, 108)
# "2018-06-21 12:56:58.375501": preprocesing finished
# "2018-06-21 12:56:58.375627": start training on days [3]
# "2018-06-21 12:56:58.375678": using fit without validation
# "2018-06-21 12:57:41.206998": built 1000 trees
# "2018-06-21 12:57:43.684702":     base features shape: (247423, 80)
# "2018-06-21 12:57:50.694951":     28 features added
# "2018-06-21 12:57:50.695078":     result shape: (247423, 108)
# "2018-06-21 12:57:50.704482": days to predict: [6]
# "2018-06-21 12:57:50.705936": features shape: (247423, 108)
# "2018-06-21 12:57:50.705977": start predicting on day 6
# "2018-06-21 12:57:54.375602": predictions shape: (22493, 11)
# "2018-06-21 12:57:54.375764": saveing results to regression_predictions/9/train_3_test_6
# "2018-06-21 12:57:54.377836": results saved
# "2018-06-21 12:57:57.963274": preprocesing started
# "2018-06-21 12:57:59.359348":     base features shape: (20203, 80)
# "2018-06-21 12:58:00.246359":     28 features added
# "2018-06-21 12:58:00.246554":     result shape: (20203, 108)
# "2018-06-21 12:58:00.248182": train features shape: (20203, 108)
# "2018-06-21 12:58:01.304300": preprocesing finished
# "2018-06-21 12:58:01.304421": start training on days [3]
# "2018-06-21 12:58:01.304570": using fit without validation
# "2018-06-21 12:59:10.559020": built 1000 trees
# "2018-06-21 12:59:14.157790":     base features shape: (247423, 80)
# "2018-06-21 12:59:22.940518":     28 features added
# "2018-06-21 12:59:22.941676":     result shape: (247423, 108)
# "2018-06-21 12:59:22.949631": days to predict: [6]
# "2018-06-21 12:59:22.949771": features shape: (247423, 108)
# "2018-06-21 12:59:22.949808": start predicting on day 6
# "2018-06-21 12:59:26.699488": predictions shape: (22493, 11)
# "2018-06-21 12:59:26.699596": saveing results to regression_predictions/10/train_3_test_6
# "2018-06-21 12:59:26.701763": results saved
# "2018-06-21 12:59:30.100784": preprocesing started
# "2018-06-21 12:59:31.423144":     base features shape: (20203, 80)
# "2018-06-21 12:59:32.214995":     28 features added
# "2018-06-21 12:59:32.215100":     result shape: (20203, 108)
# "2018-06-21 12:59:32.216948": train features shape: (20203, 108)
# "2018-06-21 12:59:33.221703": preprocesing finished
# "2018-06-21 12:59:33.221979": start training on days [3]
# "2018-06-21 12:59:33.222050": using fit without validation
# "2018-06-21 13:00:44.649827": built 1000 trees
# "2018-06-21 13:00:48.191862":     base features shape: (247423, 80)
# "2018-06-21 13:00:55.171881":     28 features added
# "2018-06-21 13:00:55.171984":     result shape: (247423, 108)
# "2018-06-21 13:00:55.180746": days to predict: [6]
# "2018-06-21 13:00:55.180815": features shape: (247423, 108)
# "2018-06-21 13:00:55.180836": start predicting on day 6
# "2018-06-21 13:00:57.069520": predictions shape: (22493, 11)
# "2018-06-21 13:00:57.069597": saveing results to regression_predictions/11/train_3_test_6
# "2018-06-21 13:00:57.071703": results saved
# "2018-06-21 13:00:59.149165": preprocesing started
# "2018-06-21 13:00:59.939222":     base features shape: (20203, 80)
# "2018-06-21 13:01:00.600901":     28 features added
# "2018-06-21 13:01:00.600993":     result shape: (20203, 108)
# "2018-06-21 13:01:00.602438": train features shape: (20203, 108)
# "2018-06-21 13:01:01.244743": preprocesing finished
# "2018-06-21 13:01:01.244815": start training on days [3]
# "2018-06-21 13:01:01.244831": using fit without validation
# "2018-06-21 13:01:57.472520": built 1000 trees
# "2018-06-21 13:02:01.071649":     base features shape: (247423, 80)
# "2018-06-21 13:02:09.394029":     28 features added
# "2018-06-21 13:02:09.394150":     result shape: (247423, 108)
# "2018-06-21 13:02:09.406568": days to predict: [6]
# "2018-06-21 13:02:09.406783": features shape: (247423, 108)
# "2018-06-21 13:02:09.406832": start predicting on day 6
# "2018-06-21 13:02:13.060604": predictions shape: (22493, 11)
# "2018-06-21 13:02:13.060703": saveing results to regression_predictions/12/train_3_test_6
# "2018-06-21 13:02:13.065004": results saved
# "2018-06-21 13:02:16.489603": preprocesing started
# "2018-06-21 13:02:17.806499":     base features shape: (20203, 80)
# "2018-06-21 13:02:18.529760":     28 features added
# "2018-06-21 13:02:18.529854":     result shape: (20203, 108)
# "2018-06-21 13:02:18.531465": train features shape: (20203, 108)
# "2018-06-21 13:02:19.567290": preprocesing finished
# "2018-06-21 13:02:19.567368": start training on days [3]
# "2018-06-21 13:02:19.567386": using fit without validation
# "2018-06-21 13:03:27.545806": built 1000 trees
# "2018-06-21 13:03:31.226122":     base features shape: (247423, 80)
# "2018-06-21 13:03:38.036699":     28 features added
# "2018-06-21 13:03:38.036805":     result shape: (247423, 108)
# "2018-06-21 13:03:38.046959": days to predict: [6]
# "2018-06-21 13:03:38.047168": features shape: (247423, 108)
# "2018-06-21 13:03:38.047276": start predicting on day 6
# "2018-06-21 13:03:41.746676": predictions shape: (22493, 11)
# "2018-06-21 13:03:41.746781": saveing results to regression_predictions/13/train_3_test_6
# "2018-06-21 13:03:41.749064": results saved
# "2018-06-21 13:03:45.233923": preprocesing started
# "2018-06-21 13:03:46.524066":     base features shape: (20203, 80)
# "2018-06-21 13:03:47.341986":     28 features added
# "2018-06-21 13:03:47.342114":     result shape: (20203, 108)
# "2018-06-21 13:03:47.343839": train features shape: (20203, 108)
# "2018-06-21 13:03:48.377805": preprocesing finished
# "2018-06-21 13:03:48.377899": start training on days [3]
# "2018-06-21 13:03:48.378072": using fit without validation
# "2018-06-21 13:04:34.197966": built 1000 trees
# "2018-06-21 13:04:36.990140":     base features shape: (247423, 80)
# "2018-06-21 13:04:44.623292":     28 features added
# "2018-06-21 13:04:44.623489":     result shape: (247423, 108)
# "2018-06-21 13:04:44.632593": days to predict: [6]
# "2018-06-21 13:04:44.632728": features shape: (247423, 108)
# "2018-06-21 13:04:44.632791": start predicting on day 6
# "2018-06-21 13:04:48.429515": predictions shape: (22493, 11)
# "2018-06-21 13:04:48.429629": saveing results to regression_predictions/14/train_3_test_6
# "2018-06-21 13:04:48.431744": results saved
# CPU times: user 46min 46s, sys: 2min 21s, total: 49min 7s
# Wall time: 16min 37s

# %%
np.mean(metrics), np.std(metrics) / np.sqrt(15)
# Out:
# (0.6252553925171769, 0.004246191562662895)

# %%
metrics
# Out:
# [0.5987401087500452,
#  0.6000036806370098,
#  0.6203009932308671,
#  0.628834717659364,
#  0.6198430810073711,
#  0.6344424637022905,
#  0.6151145886251218,
#  0.6283846820140015,
#  0.65703237714631,
#  0.6199507936402507,
#  0.6540612834895604,
#  0.6070102348604651,
#  0.623445917715271,
#  0.6323140458465449,
#  0.6393519194331805]
