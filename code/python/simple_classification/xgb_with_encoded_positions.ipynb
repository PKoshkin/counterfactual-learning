# %%
import numpy as np

import sys
sys.path.append('../general')
from pool import Pool

from test import test_classification
    
import xgboost as xgb

# %%
pool = Pool('../data')

# %%
scores = test_classification(xgb.XGBClassifier(), pool, runs=100)

# %%
np.mean(scores)
# Out:
# -0.029705212473804258

# %%
scores
# Out:
# [-0.024596948143444115,
#  -0.03871995062443349,
#  -0.05713553614675166,
#  -0.04216544205025806,
#  -0.03219556992476619,
#  -0.044655395825429864,
#  -0.02708254165945557,
#  -0.05378045459971518,
#  -0.034169507880378494,
#  0.005292183514437505,
#  -0.03453194968690224,
#  -0.010289179563295925,
#  -0.03506418936229952,
#  -0.00287034149033858,
#  -0.058400239930267744,
#  -0.008769128398087982,
#  -0.012145291590498262,
#  0.02339993216486037,
#  -0.02482903282160231,
#  -0.016079632280231508,
#  -0.057811118478559874,
#  -0.029677300285690968,
#  -0.015399075812784683,
#  -0.049722009750323745,
#  -0.03823393118488799,
#  -0.047929999960696,
#  -0.0361390307298634,
#  -0.029529118235990203,
#  -0.023495071603507008,
#  -0.02622594998077828,
#  -0.03727120884055244,
#  -0.02803622779973517,
#  -0.02578801650859342,
#  -0.027115691717581422,
#  -0.004993036048714852,
#  -0.03190996419787585,
#  -0.01502282199365586,
#  -0.04720014832378344,
#  -0.00842437474766373,
# ...
