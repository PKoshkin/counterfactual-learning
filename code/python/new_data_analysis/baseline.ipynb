# %%
import numpy as np
import shutil
import os

import sys
sys.path.append("../utils/")
sys.path.append("../calculating_predictions")
sys.path.append("../evaluation/")
from calculate_predictions import calculate_predictions
from evaluate import evaluate
from run_evaluation import *
from argparse import Namespace
from catboost import CatBoostRegressor

# %reload_ext autoreload
# %autoreload 2

# %%
def get_baseline_metric():
    args = Namespace()
    args.verbose = True
    args.first_feature = 0
    args.last_feature = -1
    args.data_folder = "../../../data/new_days_data_best_features"
    args.out_folder = "res"
    args.type = "regression"
    args.need_position_feature = True
    args.labels_to_substruct = None
    args.metric_folder = "metrics"
    args.model_constructor = lambda verbose: CatBoostRegressor(verbose=False)
    args.additional_features = None
    args.add_base_features = True
    args.train_days = [3]
    args.validation_day = None
    args.test_days = [6]
    
    def clear(folder):
        if os.path.exists(folder):
            shutil.rmtree(folder)
        os.mkdir(folder)
    
    clear(args.out_folder)
    clear(args.metric_folder)
    
    calculate_predictions(args)
    evaluate(args.out_folder, args.data_folder, args.metric_folder, argmax_positions)
    
    with open("metrics/metrics.txt") as handler:
        metric = float(next(handler).strip().split()[0])
        return metric

# %%
# %%time
metrics = [get_baseline_metric() for i in range(10)]
# Out:
# "2018-06-21 18:59:17.713411": preprocesing started
# "2018-06-21 18:59:23.092224":     base features shape: (142298, 129)
# "2018-06-21 18:59:23.123102":     0 features added
# "2018-06-21 18:59:23.123202":     base features not included
# "2018-06-21 18:59:23.123352":     result shape: (142298, 129)
# "2018-06-21 18:59:23.151133": train features shape: (142298, 129)
# "2018-06-21 18:59:26.493187": preprocesing finished
# "2018-06-21 18:59:26.493289": start training on days [3]
# "2018-06-21 18:59:26.493317": using fit without validation
# "2018-06-21 19:00:49.373101": built 1000 trees
# "2018-06-21 19:01:08.955206":     base features shape: (1565278, 129)
# "2018-06-21 19:01:09.599343":     0 features added
# "2018-06-21 19:01:09.599424":     base features not included
# "2018-06-21 19:01:09.599659":     result shape: (1565278, 129)
# "2018-06-21 19:01:09.633277": days to predict: [6]
# "2018-06-21 19:01:09.633427": features shape: (1565278, 129)
# "2018-06-21 19:01:09.633511": start predicting on day 6
# "2018-06-21 19:01:23.546918": predictions shape: (142298, 11)
# "2018-06-21 19:01:23.546976": saveing results to res/train_3_test_6
# "2018-06-21 19:01:23.554566": results saved
# "2018-06-21 19:01:32.822718": preprocesing started
# "2018-06-21 19:01:37.701388":     base features shape: (142298, 129)
# "2018-06-21 19:01:37.714692":     0 features added
# "2018-06-21 19:01:37.714758":     base features not included
# "2018-06-21 19:01:37.714781":     result shape: (142298, 129)
# "2018-06-21 19:01:37.727761": train features shape: (142298, 129)
# "2018-06-21 19:01:40.847640": preprocesing finished
# "2018-06-21 19:01:40.847742": start training on days [3]
# "2018-06-21 19:01:40.847761": using fit without validation
# "2018-06-21 19:03:00.287766": built 1000 trees
# "2018-06-21 19:03:19.518258":     base features shape: (1565278, 129)
# "2018-06-21 19:03:20.164867":     0 features added
# "2018-06-21 19:03:20.164942":     base features not included
# "2018-06-21 19:03:20.164968":     result shape: (1565278, 129)
# "2018-06-21 19:03:20.197314": days to predict: [6]
# "2018-06-21 19:03:20.197429": features shape: (1565278, 129)
# "2018-06-21 19:03:20.197449": start predicting on day 6
# "2018-06-21 19:03:33.669231": predictions shape: (142298, 11)
# "2018-06-21 19:03:33.669312": saveing results to res/train_3_test_6
# "2018-06-21 19:03:33.676986": results saved
# "2018-06-21 19:03:42.620448": preprocesing started
# "2018-06-21 19:03:47.144539":     base features shape: (142298, 129)
# "2018-06-21 19:03:47.158090":     0 features added
# "2018-06-21 19:03:47.158181":     base features not included
# "2018-06-21 19:03:47.158311":     result shape: (142298, 129)
# "2018-06-21 19:03:47.170316": train features shape: (142298, 129)
# "2018-06-21 19:03:50.161334": preprocesing finished
# "2018-06-21 19:03:50.161445": start training on days [3]
# "2018-06-21 19:03:50.161561": using fit without validation
# "2018-06-21 19:05:07.769668": built 1000 trees
# "2018-06-21 19:05:26.269761":     base features shape: (1565278, 129)
# "2018-06-21 19:05:26.916055":     0 features added
# "2018-06-21 19:05:26.916130":     base features not included
# "2018-06-21 19:05:26.916297":     result shape: (1565278, 129)
# "2018-06-21 19:05:26.940790": days to predict: [6]
# "2018-06-21 19:05:26.940903": features shape: (1565278, 129)
# "2018-06-21 19:05:26.941001": start predicting on day 6
# "2018-06-21 19:05:40.589953": predictions shape: (142298, 11)
# "2018-06-21 19:05:40.590055": saveing results to res/train_3_test_6
# "2018-06-21 19:05:40.597329": results saved
# "2018-06-21 19:05:49.642892": preprocesing started
# "2018-06-21 19:05:54.188793":     base features shape: (142298, 129)
# "2018-06-21 19:05:54.201378":     0 features added
# "2018-06-21 19:05:54.201441":     base features not included
# "2018-06-21 19:05:54.201582":     result shape: (142298, 129)
# "2018-06-21 19:05:54.213012": train features shape: (142298, 129)
# "2018-06-21 19:05:57.199191": preprocesing finished
# "2018-06-21 19:05:57.199317": start training on days [3]
# "2018-06-21 19:05:57.199355": using fit without validation
# "2018-06-21 19:07:16.019114": built 1000 trees
# "2018-06-21 19:07:35.074219":     base features shape: (1565278, 129)
# "2018-06-21 19:07:35.746597":     0 features added
# "2018-06-21 19:07:35.746692":     base features not included
# "2018-06-21 19:07:35.747041":     result shape: (1565278, 129)
# "2018-06-21 19:07:35.772774": days to predict: [6]
# "2018-06-21 19:07:35.772957": features shape: (1565278, 129)
# "2018-06-21 19:07:35.773011": start predicting on day 6
# "2018-06-21 19:07:49.692668": predictions shape: (142298, 11)
# "2018-06-21 19:07:49.692848": saveing results to res/train_3_test_6
# "2018-06-21 19:07:49.700327": results saved
# "2018-06-21 19:07:59.110408": preprocesing started
# "2018-06-21 19:08:03.994968":     base features shape: (142298, 129)
# "2018-06-21 19:08:04.008769":     0 features added
# "2018-06-21 19:08:04.008874":     base features not included
# "2018-06-21 19:08:04.008945":     result shape: (142298, 129)
# "2018-06-21 19:08:04.022053": train features shape: (142298, 129)
# "2018-06-21 19:08:07.334406": preprocesing finished
# "2018-06-21 19:08:07.334513": start training on days [3]
# "2018-06-21 19:08:07.334642": using fit without validation
# "2018-06-21 19:09:33.064599": built 1000 trees
# "2018-06-21 19:09:52.898085":     base features shape: (1565278, 129)
# "2018-06-21 19:09:53.677289":     0 features added
# "2018-06-21 19:09:53.677381":     base features not included
# "2018-06-21 19:09:53.677409":     result shape: (1565278, 129)
# "2018-06-21 19:09:53.705071": days to predict: [6]
# "2018-06-21 19:09:53.705136": features shape: (1565278, 129)
# "2018-06-21 19:09:53.705252": start predicting on day 6
# "2018-06-21 19:10:09.239293": predictions shape: (142298, 11)
# "2018-06-21 19:10:09.239481": saveing results to res/train_3_test_6
# "2018-06-21 19:10:09.248956": results saved
# "2018-06-21 19:10:20.103950": preprocesing started
# "2018-06-21 19:10:25.619950":     base features shape: (142298, 129)
# "2018-06-21 19:10:25.635813":     0 features added
# "2018-06-21 19:10:25.635897":     base features not included
# "2018-06-21 19:10:25.635925":     result shape: (142298, 129)
# "2018-06-21 19:10:25.651458": train features shape: (142298, 129)
# "2018-06-21 19:10:28.724146": preprocesing finished
# "2018-06-21 19:10:28.724244": start training on days [3]
# "2018-06-21 19:10:28.724359": using fit without validation
# "2018-06-21 19:11:53.397782": built 1000 trees
# "2018-06-21 19:12:15.289869":     base features shape: (1565278, 129)
# "2018-06-21 19:12:16.071472":     0 features added
# "2018-06-21 19:12:16.071562":     base features not included
# "2018-06-21 19:12:16.071589":     result shape: (1565278, 129)
# "2018-06-21 19:12:16.107153": days to predict: [6]
# "2018-06-21 19:12:16.107348": features shape: (1565278, 129)
# "2018-06-21 19:12:16.107466": start predicting on day 6
# "2018-06-21 19:12:31.289588": predictions shape: (142298, 11)
# "2018-06-21 19:12:31.289828": saveing results to res/train_3_test_6
# "2018-06-21 19:12:31.297173": results saved
# "2018-06-21 19:12:40.935779": preprocesing started
# "2018-06-21 19:12:46.232465":     base features shape: (142298, 129)
# "2018-06-21 19:12:46.249909":     0 features added
# "2018-06-21 19:12:46.250001":     base features not included
# "2018-06-21 19:12:46.250149":     result shape: (142298, 129)
# "2018-06-21 19:12:46.267006": train features shape: (142298, 129)
# "2018-06-21 19:12:49.774135": preprocesing finished
# "2018-06-21 19:12:49.774269": start training on days [3]
# "2018-06-21 19:12:49.774336": using fit without validation
# "2018-06-21 19:14:12.888296": built 1000 trees
# "2018-06-21 19:14:32.109604":     base features shape: (1565278, 129)
# "2018-06-21 19:14:32.786992":     0 features added
# "2018-06-21 19:14:32.787064":     base features not included
# "2018-06-21 19:14:32.787088":     result shape: (1565278, 129)
# "2018-06-21 19:14:32.811211": days to predict: [6]
# "2018-06-21 19:14:32.811271": features shape: (1565278, 129)
# "2018-06-21 19:14:32.811379": start predicting on day 6
# "2018-06-21 19:14:46.836806": predictions shape: (142298, 11)
# "2018-06-21 19:14:46.836943": saveing results to res/train_3_test_6
# "2018-06-21 19:14:46.844717": results saved
# "2018-06-21 19:14:56.239460": preprocesing started
# "2018-06-21 19:15:01.132184":     base features shape: (142298, 129)
# "2018-06-21 19:15:01.145388":     0 features added
# "2018-06-21 19:15:01.145478":     base features not included
# "2018-06-21 19:15:01.145612":     result shape: (142298, 129)
# "2018-06-21 19:15:01.160128": train features shape: (142298, 129)
# "2018-06-21 19:15:04.280944": preprocesing finished
# "2018-06-21 19:15:04.281046": start training on days [3]
# "2018-06-21 19:15:04.281217": using fit without validation
# "2018-06-21 19:16:23.745924": built 1000 trees
# "2018-06-21 19:16:43.926298":     base features shape: (1565278, 129)
# "2018-06-21 19:16:44.592875":     0 features added
# "2018-06-21 19:16:44.592969":     base features not included
# "2018-06-21 19:16:44.593089":     result shape: (1565278, 129)
# "2018-06-21 19:16:44.627302": days to predict: [6]
# "2018-06-21 19:16:44.627389": features shape: (1565278, 129)
# "2018-06-21 19:16:44.627443": start predicting on day 6
# "2018-06-21 19:16:58.870396": predictions shape: (142298, 11)
# "2018-06-21 19:16:58.870462": saveing results to res/train_3_test_6
# "2018-06-21 19:16:58.878675": results saved
# "2018-06-21 19:17:08.587881": preprocesing started
# "2018-06-21 19:17:13.450621":     base features shape: (142298, 129)
# "2018-06-21 19:17:13.464609":     0 features added
# "2018-06-21 19:17:13.464686":     base features not included
# "2018-06-21 19:17:13.464811":     result shape: (142298, 129)
# "2018-06-21 19:17:13.477513": train features shape: (142298, 129)
# "2018-06-21 19:17:16.527941": preprocesing finished
# "2018-06-21 19:17:16.528028": start training on days [3]
# "2018-06-21 19:17:16.528189": using fit without validation
# "2018-06-21 19:18:36.464813": built 1000 trees
# "2018-06-21 19:18:56.502999":     base features shape: (1565278, 129)
# "2018-06-21 19:18:57.180911":     0 features added
# "2018-06-21 19:18:57.181004":     base features not included
# "2018-06-21 19:18:57.181127":     result shape: (1565278, 129)
# "2018-06-21 19:18:57.208905": days to predict: [6]
# "2018-06-21 19:18:57.209019": features shape: (1565278, 129)
# "2018-06-21 19:18:57.209182": start predicting on day 6
# "2018-06-21 19:19:11.322217": predictions shape: (142298, 11)
# "2018-06-21 19:19:11.322287": saveing results to res/train_3_test_6
# "2018-06-21 19:19:11.330263": results saved
# "2018-06-21 19:19:20.628292": preprocesing started
# "2018-06-21 19:19:25.281323":     base features shape: (142298, 129)
# "2018-06-21 19:19:25.295085":     0 features added
# "2018-06-21 19:19:25.295157":     base features not included
# "2018-06-21 19:19:25.295182":     result shape: (142298, 129)
# "2018-06-21 19:19:25.308261": train features shape: (142298, 129)
# "2018-06-21 19:19:28.413657": preprocesing finished
# "2018-06-21 19:19:28.413750": start training on days [3]
# "2018-06-21 19:19:28.413890": using fit without validation
# "2018-06-21 19:21:06.383908": built 1000 trees
# "2018-06-21 19:21:25.631518":     base features shape: (1565278, 129)
# "2018-06-21 19:21:26.298954":     0 features added
# "2018-06-21 19:21:26.299124":     base features not included
# "2018-06-21 19:21:26.299157":     result shape: (1565278, 129)
# "2018-06-21 19:21:26.332716": days to predict: [6]
# "2018-06-21 19:21:26.332837": features shape: (1565278, 129)
# "2018-06-21 19:21:26.332964": start predicting on day 6
# "2018-06-21 19:21:41.293618": predictions shape: (142298, 11)
# "2018-06-21 19:21:41.293828": saveing results to res/train_3_test_6
# "2018-06-21 19:21:41.302812": results saved
# CPU times: user 1h 31min 56s, sys: 1min 24s, total: 1h 33min 20s
# Wall time: 22min 33s

# %%
print(metrics)
print(np.mean(metrics))
print(np.std(metrics) / np.sqrt(10))
# Out:
# [0.620166229080817, 0.6280713781472671, 0.6177104194402271, 0.6194118966362879, 0.6203237210919406, 0.6252721195126272, 0.6186123034567165, 0.6180543019140391, 0.6259028030193531, 0.627145007268213]
# 0.6220670179567489
# 0.0012146723190276977

# %%
x = np.load("res/train_3_test_6.npy")

# %%
x
# Out:
# array([[0.80860991, 0.81449919, 0.81474932, ..., 0.81365689, 0.81416775,
#         0.81146317],
#        [0.79542404, 0.80147687, 0.8012288 , ..., 0.79878172, 0.80063883,
#         0.79449726],
#        [0.51033806, 0.51864286, 0.51889299, ..., 0.51931345, 0.51905381,
#         0.51559963],
#        ...,
#        [0.67678093, 0.68261088, 0.682861  , ..., 0.68339279, 0.68340295,
#         0.68188452],
#        [0.65341639, 0.65908118, 0.65861657, ..., 0.65999   , 0.65903578,
#         0.65864688],
#        [0.74294024, 0.74832096, 0.74857108, ..., 0.74807761, 0.74858847,
#         0.74639247]])

# %%
from collections import Counter
Counter(np.argmax(x, axis=1))
# Out:
# Counter({4: 94707,
#          5: 10265,
#          3: 7997,
#          7: 10477,
#          2: 1780,
#          10: 1449,
#          9: 7599,
#          1: 1811,
#          8: 3320,
#          0: 2893})
