# %%
import numpy as np

# %%
np.load('res/features_from_0_to_100/0-1.txt')
# Out:
# array([[ 2.15979862,  3.04746523,  3.93513185,  4.82279846,  5.71046508,
#          6.59813169,  7.48579831,  8.37346492,  9.26113154, 10.14879815],
#        [ 3.2263586 ,  4.11402521,  5.00169183,  5.88935844,  6.77702506,
#          7.66469167,  8.55235829,  9.4400249 , 10.32769151, 11.21535813],
#        [ 0.66224266,  1.54990928,  2.43757589,  3.32524251,  4.21290912,
#          5.10057574,  5.98824235,  6.87590897,  7.76357558,  8.6512422 ],
#        [ 1.23735711,  2.12502372,  3.01269034,  3.90035695,  4.78802356,
#          5.67569018,  6.56335679,  7.45102341,  8.33869002,  9.22635664],
#        [ 0.59941794,  1.48708455,  2.37475117,  3.26241778,  4.1500844 ,
#          5.03775101,  5.92541763,  6.81308424,  7.70075086,  8.58841747],
#        [-0.9606193 , -0.07295268,  0.81471393,  1.70238055,  2.59004716,
#          3.47771378,  4.36538039,  5.25304701,  6.14071362,  7.02838023],
#        [ 1.84552417,  2.73319078,  3.6208574 ,  4.50852401,  5.39619063,
# ...

# %%
np.load('stacking_res/0_1-2.txt')
# Out:
# array([[[0.00600152, 0.96373703, 0.00625537, 0.00600152, 0.00600152,
#          0.00600152, 0.00600152],
#         [0.00600152, 0.96373703, 0.00625537, 0.00600152, 0.00600152,
#          0.00600152, 0.00600152],
#         [0.00600152, 0.96373703, 0.00625537, 0.00600152, 0.00600152,
#          0.00600152, 0.00600152],
#         [0.00600152, 0.96373703, 0.00625537, 0.00600152, 0.00600152,
#          0.00600152, 0.00600152],
#         [0.00600152, 0.96373703, 0.00625537, 0.00600152, 0.00600152,
#          0.00600152, 0.00600152],
#         [0.00614903, 0.96284555, 0.0064093 , 0.00614903, 0.00614903,
#          0.00614903, 0.00614903],
#         [0.00614903, 0.96284555, 0.0064093 , 0.00614903, 0.00614903,
#          0.00614903, 0.00614903],
#         [0.00614903, 0.96284555, 0.0064093 , 0.00614903, 0.00614903,
#          0.00614903, 0.00614903],
#         [0.00614903, 0.96284555, 0.0064093 , 0.00614903, 0.00614903,
#          0.00614903, 0.00614903],
# ...
